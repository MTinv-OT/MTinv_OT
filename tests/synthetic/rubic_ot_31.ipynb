# %% [markdown]
# # 棋盘格（Checkerboard）模型 MSE 反演
#
# 使用 `MT2DTrueModels.create_true_checkerboard` 生成高低阻交替棋盘格真实模型，并执行 2D MT 反演（MSE 损失）。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

current_path = os.path.abspath("")
root_path = os.path.abspath(os.path.join(current_path, "..", ".."))
if root_path not in sys.path:
    sys.path.insert(0, root_path)
os.environ["CUDA_VISIBLE_DEVICES"] = "0" 
from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger

logger = ExperimentLogger(
    model_tag="rubic",#need define
    output_root=Path("test_results") #去掉parent生成test_results套ccm2d1
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
# Out:
# Running on cuda

# %%
import os
from pathlib import Path

print(f"当前目录: {Path.cwd()}")
print(f"目录内容: {list(Path.cwd().iterdir())}")

# 检查 src 在哪里
for p in [Path.cwd(), Path.cwd().parent, Path.cwd().parent.parent]:
    if (p / "src").exists():
        print(f"找到 src 在: {p}")
# Out:
# 当前目录: /home/liuxr/MTinv_OT3/tests/synthetic
# 目录内容: [PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_ot_21.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/.ipynb_checkpoints'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.15.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.2.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.2.ipynb.invalid'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_ot_31.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_mse_31.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/test_results'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.1.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_mse_21.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.15.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.1.ipynb')]
# 找到 src 在: /home/liuxr/MTinv_OT3

# %%
yn_np, zn_np, nza = MT2DTrueModels._default_grid(nza=10)

# 2) 生成真实的交替棋盘格
sig_true = MT2DTrueModels.create_true_checkerboard(
    yn=yn_np,
    zn=zn_np,
    nza=nza,
    device=device,
    bg_rho=100.0,               # 背景电阻率
    rho_1=10.0,                 # 低阻块 (10 Ohm.m)
    rho_2=1000.0,               # 高阻块 (1000 Ohm.m)
    y_bounds=(-15000.0, 15000.0), # 横向范围匹配 stations
    dy_block=10000.0,           # 约 3×3 棋盘格：每块宽 10 km
    z_bounds=(2000.0, 22000.0),   # 深度 2 km 开始，向下延伸到 22 km
    dz_block=6667.0,            # 约 3×3 棋盘格：每块高约 6.7 km
)

# 转换为 tensor 以备正反演使用
yn = torch.tensor(yn_np, device=device)
zn = torch.tensor(zn_np, device=device)

# 3) Survey setup
freqs = torch.logspace(0, -5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 31, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")

PLOT_KWARGS = dict(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 31, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=20,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.01,
                        noise_type="gaussian",
                        static_shift_std=0.15,   # 0.15 会导致电阻率发生约半个量级的剧烈上下平移
                        shift_modes=("xy", "yx"),# 作用于双极化模式 (TM 模式通常对畸变最敏感)
                        shift_stations="random",
                        shift_ratio = 0)
inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(**PLOT_KWARGS)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# /tmp/ipykernel_3894220/1031935545.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   yn=torch.tensor(yn, dtype=torch.float64, device=device),
# /tmp/ipykernel_3894220/1031935545.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   zn=torch.tensor(zn, dtype=torch.float64, device=device),
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.843704e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 1.0% (gaussian)
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4) Run inversion
final_sigma = inv.run_inversion(
    n_epochs=300,
    mode="6dot",
    progress_interval=20,
    current_lambda=0.1,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing = False
)
print("Inversion done")
print(final_sigma.min().item(), final_sigma.max().item())
# Out:
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:02 | Remaining: ~0:08:03 | ETA: 13:13:39
#   Epoch time: 1.62s | Avg: 1.62s
#   Total: 5.1095e-01 | Data(6dot): 5.1095e-01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 43.630 | Rough: 0.00e+00 | Lam: 0.1000000
#   OT-distance(6D, view-only): 5.109505e-01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e-01 -> 2.06e-02 (ratio=4.227e-02)
#  [Auto-Lambda] Epoch 20: Adjusted 2.06e-02 -> 9.43e-03 (ratio=2.106e-01)
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:38 | Remaining: ~0:08:19 | ETA: 13:14:31
#   Epoch time: 2.25s | Avg: 1.79s
#   Total: 2.6423e-01 | Data(6dot): 2.4528e-01
#   Misfit(RMS χ²): 26.928 | Rough: 2.01e+00 | Lam: 0.0094348
#   OT-distance(6D, view-only): 2.452786e-01
#   GradNorms: |g_d|=1.062e-03 | |λ·g_m|=1.164e-03
#  [Auto-Lambda] Epoch 30: Adjusted 9.43e-03 -> 4.85e-03 (ratio=2.637e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 4.85e-03 -> 2.88e-03 (ratio=3.540e-01)
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:15 | Remaining: ~0:07:48 | ETA: 13:14:35
#   Epoch time: 2.21s | Avg: 1.81s
#   Total: 1.4365e-01 | Data(6dot): 1.2687e-01
#   Misfit(RMS χ²): 19.214 | Rough: 5.82e+00 | Lam: 0.0028830
#   OT-distance(6D, view-only): 1.268717e-01
#   GradNorms: |g_d|=4.661e-04 | |λ·g_m|=3.881e-04
#  [Auto-Lambda] Epoch 50: Adjusted 2.88e-03 -> 2.57e-03 (ratio=7.977e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 2.57e-03 -> 2.27e-03 (ratio=7.772e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:51 | Remaining: ~0:07:12 | ETA: 13:14:36
#   Epoch time: 2.26s | Avg: 1.81s
#   Total: 9.4130e-02 | Data(6dot): 7.2959e-02
#   Misfit(RMS χ²): 14.931 | Rough: 9.33e+00 | Lam: 0.0022700
#   OT-distance(6D, view-only): 7.295863e-02
#   GradNorms: |g_d|=2.961e-04 | |λ·g_m|=1.689e-04
#  [Auto-Lambda] Epoch 70: Adjusted 2.27e-03 -> 2.12e-03 (ratio=8.720e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 2.12e-03 -> 1.95e-03 (ratio=8.454e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:30 | Remaining: ~0:06:43 | ETA: 13:14:45
#   Epoch time: 2.64s | Avg: 1.84s
#   Total: 6.9286e-02 | Data(6dot): 4.6414e-02
#   Misfit(RMS χ²): 11.985 | Rough: 1.17e+01 | Lam: 0.0019491
#   OT-distance(6D, view-only): 4.641394e-02
#   GradNorms: |g_d|=2.127e-04 | |λ·g_m|=1.170e-04
#  [Auto-Lambda] Epoch 90: Adjusted 1.95e-03 -> 1.76e-03 (ratio=8.111e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 1.76e-03 -> 1.55e-03 (ratio=7.780e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:03:08 | Remaining: ~0:06:09 | ETA: 13:14:50
#   Epoch time: 2.25s | Avg: 1.86s
#   Total: 5.4062e-02 | Data(6dot): 3.2876e-02
#   Misfit(RMS χ²): 9.964 | Rough: 1.37e+01 | Lam: 0.0015483
#   OT-distance(6D, view-only): 3.287556e-02
#   GradNorms: |g_d|=1.620e-04 | |λ·g_m|=9.323e-05
#  [Auto-Lambda] Epoch 110: Adjusted 1.55e-03 -> 1.34e-03 (ratio=7.515e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 1.34e-03 -> 1.15e-03 (ratio=7.358e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:44 | Remaining: ~0:05:31 | ETA: 13:14:49
#   Epoch time: 2.23s | Avg: 1.85s
#   Total: 4.2815e-02 | Data(6dot): 2.4898e-02
#   Misfit(RMS χ²): 8.463 | Rough: 1.56e+01 | Lam: 0.0011513
#   OT-distance(6D, view-only): 2.489833e-02
#   GradNorms: |g_d|=1.259e-04 | |λ·g_m|=7.456e-05
#  [Auto-Lambda] Epoch 130: Adjusted 1.15e-03 -> 9.80e-04 (ratio=7.245e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 9.80e-04 -> 8.29e-04 (ratio=7.161e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:04:22 | Remaining: ~0:04:55 | ETA: 13:14:50
#   Epoch time: 2.45s | Avg: 1.86s
#   Total: 3.4214e-02 | Data(6dot): 1.9751e-02
#   Misfit(RMS χ²): 7.309 | Rough: 1.74e+01 | Lam: 0.0008293
#   OT-distance(6D, view-only): 1.975114e-02
#   GradNorms: |g_d|=9.731e-05 | |λ·g_m|=5.844e-05
#  [Auto-Lambda] Epoch 150: Adjusted 8.29e-04 -> 6.99e-04 (ratio=7.105e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 6.99e-04 -> 5.88e-04 (ratio=7.083e-01)
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:59 | Remaining: ~0:04:17 | ETA: 13:14:50
#   Epoch time: 2.24s | Avg: 1.85s
#   Total: 2.7632e-02 | Data(6dot): 1.6273e-02
#   Misfit(RMS χ²): 6.406 | Rough: 1.93e+01 | Lam: 0.0005883
#   OT-distance(6D, view-only): 1.627325e-02
#   GradNorms: |g_d|=7.486e-05 | |λ·g_m|=4.519e-05
#  [Auto-Lambda] Epoch 170: Adjusted 5.88e-04 -> 4.96e-04 (ratio=7.108e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 4.96e-04 -> 4.20e-04 (ratio=7.185e-01)
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:05:35 | Remaining: ~0:03:40 | ETA: 13:14:48
#   Epoch time: 2.29s | Avg: 1.85s
#   Total: 2.2716e-02 | Data(6dot): 1.3827e-02
#   Misfit(RMS χ²): 5.708 | Rough: 2.11e+01 | Lam: 0.0004204
#   OT-distance(6D, view-only): 1.382744e-02
#   GradNorms: |g_d|=5.876e-05 | |λ·g_m|=3.516e-05
#  [Auto-Lambda] Epoch 190: Adjusted 4.20e-04 -> 3.59e-04 (ratio=7.307e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 3.59e-04 -> 3.10e-04 (ratio=7.460e-01)
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:06:13 | Remaining: ~0:03:03 | ETA: 13:14:49
#   Epoch time: 2.69s | Avg: 1.85s
#   Total: 1.9141e-02 | Data(6dot): 1.2022e-02
#   Misfit(RMS χ²): 5.168 | Rough: 2.29e+01 | Lam: 0.0003104
#   OT-distance(6D, view-only): 1.202181e-02
#   GradNorms: |g_d|=4.814e-05 | |λ·g_m|=2.821e-05
#  [Auto-Lambda] Epoch 210: Adjusted 3.10e-04 -> 2.71e-04 (ratio=7.623e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 2.71e-04 -> 2.39e-04 (ratio=7.779e-01)
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:06:49 | Remaining: ~0:02:26 | ETA: 13:14:48
#   Epoch time: 2.25s | Avg: 1.85s
#   Total: 1.6528e-02 | Data(6dot): 1.0629e-02
#   Misfit(RMS χ²): 4.742 | Rough: 2.47e+01 | Lam: 0.0002390
#   OT-distance(6D, view-only): 1.062860e-02
#   GradNorms: |g_d|=4.112e-05 | |λ·g_m|=2.356e-05
#  [Auto-Lambda] Epoch 230: Adjusted 2.39e-04 -> 2.13e-04 (ratio=7.919e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 2.13e-04 -> 1.91e-04 (ratio=8.043e-01)
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:07:26 | Remaining: ~0:01:49 | ETA: 13:14:48
#   Epoch time: 2.45s | Avg: 1.85s
#   Total: 1.4555e-02 | Data(6dot): 9.5267e-03
#   Misfit(RMS χ²): 4.401 | Rough: 2.64e+01 | Lam: 0.0001908
#   OT-distance(6D, view-only): 9.526684e-03
#   GradNorms: |g_d|=3.604e-05 | |λ·g_m|=2.028e-05
#  [Auto-Lambda] Epoch 250: Adjusted 1.91e-04 -> 1.72e-04 (ratio=8.155e-01)
#  [Auto-Lambda] Epoch 260: Adjusted 1.72e-04 -> 1.57e-04 (ratio=8.257e-01)
# Epoch 261/300 [  87.0%]
#   Elapsed: 0:08:03 | Remaining: ~0:01:12 | ETA: 13:14:48
#   Epoch time: 2.26s | Avg: 1.85s
#   Total: 1.3015e-02 | Data(6dot): 8.6395e-03
#   Misfit(RMS χ²): 4.123 | Rough: 2.80e+01 | Lam: 0.0001565
#   OT-distance(6D, view-only): 8.639524e-03
#   GradNorms: |g_d|=3.208e-05 | |λ·g_m|=1.780e-05
#  [Auto-Lambda] Epoch 270: Adjusted 1.57e-04 -> 1.43e-04 (ratio=8.351e-01)
#  [Auto-Lambda] Epoch 280: Adjusted 1.43e-04 -> 1.31e-04 (ratio=8.438e-01)
# Epoch 281/300 [  93.7%]
#   Elapsed: 0:08:39 | Remaining: ~0:00:35 | ETA: 13:14:47
#   Epoch time: 2.25s | Avg: 1.85s
#   Total: 1.1782e-02 | Data(6dot): 7.9068e-03
#   Misfit(RMS χ²): 3.891 | Rough: 2.95e+01 | Lam: 0.0001314
#   OT-distance(6D, view-only): 7.906836e-03
#   GradNorms: |g_d|=2.887e-05 | |λ·g_m|=1.583e-05
#  [Auto-Lambda] Epoch 290: Adjusted 1.31e-04 -> 1.21e-04 (ratio=8.517e-01)
# Epoch 300/300 [ 100.0%]
#   Elapsed: 0:09:13 | Remaining: ~0:00:00 | ETA: 13:14:45
#   Epoch time: 2.20s | Avg: 1.84s
#   Total: 1.1064e-02 | Data(6dot): 7.3124e-03
#   Misfit(RMS χ²): 3.699 | Rough: 3.09e+01 | Lam: 0.0001213
#   OT-distance(6D, view-only): 7.312421e-03
#   GradNorms: |g_d|=2.634e-05 | |λ·g_m|=1.534e-05
# Inversion completed.
# Inversion done
# 1e-10 0.43662485718247407

# %%
# 5) Plot results
inv.plot_loss_history()
inv.plot_model_comparison(**PLOT_KWARGS)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.7915

# %%
logger.save_from_inverter(
    inv,
    run_name="rubic_ot",
    plot_kwargs=PLOT_KWARGS,
)
# Out:
# ============================================================
# Saving results to: test_results/rubic/2026-07-06_13-15-17_rubic_ot
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.7915
# /home/liuxr/MTinv_OT3/src/mt2d_inv/plotting/inversion.py:682: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   for batch_start in range(0, len(station_indices), stations_per_figure):
#   ✓ data_fitting: 31 plots saved to test_results/rubic/2026-07-06_13-15-17_rubic_ot/figures/data_fitting (31 stations)
#   ✓ Figures saved to test_results/rubic/2026-07-06_13-15-17_rubic_ot/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/rubic/2026-07-06_13-15-17_rubic_ot
#   Final RMS χ²: 3.6994
#   RMSE: 0.5266
#   MAPE: 19.76%
# ============================================================
# PosixPath('test_results/rubic/2026-07-06_13-15-17_rubic_ot')
