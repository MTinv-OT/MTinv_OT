# %% [markdown]
# # 棋盘格（Checkerboard）模型 MSE 反演
#
# 使用 `MT2DTrueModels.create_true_checkerboard` 生成高低阻交替棋盘格真实模型，并执行 2D MT 反演（MSE 损失）。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

current_path = os.path.abspath("")
root_path = os.path.abspath(os.path.join(current_path, "..", ".."))
if root_path not in sys.path:
    sys.path.insert(0, root_path)
os.environ["CUDA_VISIBLE_DEVICES"] = "0" 
from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger

logger = ExperimentLogger(
    model_tag="rubic",#need define
    output_root=Path("test_results") #去掉parent生成test_results套ccm2d1
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
# Out:
# Running on cuda

# %%
import os
from pathlib import Path

print(f"当前目录: {Path.cwd()}")
print(f"目录内容: {list(Path.cwd().iterdir())}")

# 检查 src 在哪里
for p in [Path.cwd(), Path.cwd().parent, Path.cwd().parent.parent]:
    if (p / "src").exists():
        print(f"找到 src 在: {p}")
# Out:
# 当前目录: /home/liuxr/MTinv_OT3/tests/synthetic
# 目录内容: [PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/.ipynb_checkpoints'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_ot_sparse_21_shift.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/test_results'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_mse_21.ipynb')]
# 找到 src 在: /home/liuxr/MTinv_OT3

# %%
yn_np, zn_np, nza = MT2DTrueModels._default_grid(nza=10)

# 2) 生成真实的交替棋盘格
sig_true = MT2DTrueModels.create_true_checkerboard(
    yn=yn_np,
    zn=zn_np,
    nza=nza,
    device=device,
    bg_rho=100.0,               # 背景电阻率
    rho_1=10.0,                 # 低阻块 (10 Ohm.m)
    rho_2=1000.0,               # 高阻块 (1000 Ohm.m)
    y_bounds=(-15000.0, 15000.0), # 横向范围匹配 stations
    dy_block=10000.0,           # 约 3×3 棋盘格：每块宽 10 km
    z_bounds=(2000.0, 22000.0),   # 深度 2 km 开始，向下延伸到 22 km
    dz_block=6667.0,            # 约 3×3 棋盘格：每块高约 6.7 km
)

# 转换为 tensor 以备正反演使用
yn = torch.tensor(yn_np, device=device)
zn = torch.tensor(zn_np, device=device)

# 3) Survey setup
freqs = torch.logspace(0, -5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")

PLOT_KWARGS = dict(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=20,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.01,
                        noise_type="gaussian",
                        static_shift_std=0.15,   # 0.15 会导致电阻率发生约半个量级的剧烈上下平移
                        shift_modes=("xy", "yx"),# 作用于双极化模式 (TM 模式通常对畸变最敏感)
                        shift_stations="middle",
                        shift_ratio = 0)
inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(**PLOT_KWARGS)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# /tmp/ipykernel_3334433/2159404610.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   yn=torch.tensor(yn, dtype=torch.float64, device=device),
# /tmp/ipykernel_3334433/2159404610.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   zn=torch.tensor(zn, dtype=torch.float64, device=device),
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.843286e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 1.0% (gaussian)
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4) Run inversion
final_sigma = inv.run_inversion(
    n_epochs=300,
    mode="mse",
    progress_interval=20,
    current_lambda=0.1,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing = False
)
print("Inversion done")
print(final_sigma.min().item(), final_sigma.max().item())
# Out:
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:02 | Remaining: ~0:07:07 | ETA: 22:32:54
#   Epoch time: 1.43s | Avg: 1.43s
#   Total: 1.0784e+01 | Data(mse): 1.0784e+01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 42.908 | Rough: 0.00e+00 | Lam: 0.1000000
#   OT-distance(6D, view-only): 4.981412e-01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 20: Adjusted 1.00e-01 -> 8.98e-02 (ratio=8.073e-01)
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:35 | Remaining: ~0:07:40 | ETA: 22:34:00
#   Epoch time: 1.97s | Avg: 1.65s
#   Total: 2.8969e+00 | Data(mse): 2.4727e+00
#   Misfit(RMS χ²): 20.546 | Rough: 4.72e+00 | Lam: 0.0898483
#   OT-distance(6D, view-only): 2.478875e-01
#   GradNorms: |g_d|=1.360e-02 | |λ·g_m|=7.752e-03
#  [Auto-Lambda] Epoch 30: Adjusted 8.98e-02 -> 7.23e-02 (ratio=6.480e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 7.23e-02 -> 6.18e-02 (ratio=7.296e-01)
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:06 | Remaining: ~0:06:57 | ETA: 22:33:48
#   Epoch time: 1.98s | Avg: 1.61s
#   Total: 1.6251e+00 | Data(mse): 1.2343e+00
#   Misfit(RMS χ²): 14.516 | Rough: 6.32e+00 | Lam: 0.0617778
#   OT-distance(6D, view-only): 1.636798e-01
#   GradNorms: |g_d|=4.849e-03 | |λ·g_m|=2.775e-03
#  [Auto-Lambda] Epoch 50: Adjusted 6.18e-02 -> 5.80e-02 (ratio=8.829e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 5.80e-02 -> 5.33e-02 (ratio=8.420e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:37 | Remaining: ~0:06:18 | ETA: 22:33:41
#   Epoch time: 1.88s | Avg: 1.58s
#   Total: 1.2024e+00 | Data(mse): 8.6525e-01
#   Misfit(RMS χ²): 12.154 | Rough: 6.33e+00 | Lam: 0.0532655
#   OT-distance(6D, view-only): 1.206465e-01
#   GradNorms: |g_d|=3.424e-03 | |λ·g_m|=1.889e-03
#  [Auto-Lambda] Epoch 70: Adjusted 5.33e-02 -> 4.99e-02 (ratio=8.771e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 4.99e-02 -> 4.66e-02 (ratio=8.721e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:07 | Remaining: ~0:05:43 | ETA: 22:33:36
#   Epoch time: 1.88s | Avg: 1.57s
#   Total: 9.6367e-01 | Data(mse): 6.4906e-01
#   Misfit(RMS χ²): 10.527 | Rough: 6.75e+00 | Lam: 0.0465855
#   OT-distance(6D, view-only): 9.236069e-02
#   GradNorms: |g_d|=2.877e-03 | |λ·g_m|=1.552e-03
#  [Auto-Lambda] Epoch 90: Adjusted 4.66e-02 -> 4.30e-02 (ratio=8.519e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 4.30e-02 -> 3.93e-02 (ratio=8.334e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:02:38 | Remaining: ~0:05:10 | ETA: 22:33:33
#   Epoch time: 1.84s | Avg: 1.56s
#   Total: 7.9885e-01 | Data(mse): 5.0234e-01
#   Misfit(RMS χ²): 9.261 | Rough: 7.55e+00 | Lam: 0.0392531
#   OT-distance(6D, view-only): 7.249571e-02
#   GradNorms: |g_d|=2.459e-03 | |λ·g_m|=1.359e-03
#  [Auto-Lambda] Epoch 110: Adjusted 3.93e-02 -> 3.56e-02 (ratio=8.215e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 3.56e-02 -> 3.20e-02 (ratio=8.090e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:08 | Remaining: ~0:04:38 | ETA: 22:33:31
#   Epoch time: 1.93s | Avg: 1.55s
#   Total: 6.6968e-01 | Data(mse): 3.9590e-01
#   Misfit(RMS χ²): 8.221 | Rough: 8.56e+00 | Lam: 0.0320010
#   OT-distance(6D, view-only): 5.790538e-02
#   GradNorms: |g_d|=2.137e-03 | |λ·g_m|=1.201e-03
#  [Auto-Lambda] Epoch 130: Adjusted 3.20e-02 -> 2.86e-02 (ratio=7.981e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 2.86e-02 -> 2.54e-02 (ratio=7.872e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:03:40 | Remaining: ~0:04:07 | ETA: 22:33:32
#   Epoch time: 2.04s | Avg: 1.56s
#   Total: 5.6074e-01 | Data(mse): 3.1364e-01
#   Misfit(RMS χ²): 7.317 | Rough: 9.74e+00 | Lam: 0.0253652
#   OT-distance(6D, view-only): 4.684523e-02
#   GradNorms: |g_d|=1.833e-03 | |λ·g_m|=1.046e-03
#  [Auto-Lambda] Epoch 150: Adjusted 2.54e-02 -> 2.24e-02 (ratio=7.775e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 2.24e-02 -> 1.96e-02 (ratio=7.694e-01)
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:12 | Remaining: ~0:03:36 | ETA: 22:33:34
#   Epoch time: 2.02s | Avg: 1.56s
#   Total: 4.6669e-01 | Data(mse): 2.4973e-01
#   Misfit(RMS χ²): 6.530 | Rough: 1.11e+01 | Lam: 0.0196181
#   OT-distance(6D, view-only): 3.837328e-02
#   GradNorms: |g_d|=1.545e-03 | |λ·g_m|=8.920e-04
#  [Auto-Lambda] Epoch 170: Adjusted 1.96e-02 -> 1.71e-02 (ratio=7.624e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 1.71e-02 -> 1.49e-02 (ratio=7.563e-01)
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:04:43 | Remaining: ~0:03:05 | ETA: 22:33:34
#   Epoch time: 1.94s | Avg: 1.56s
#   Total: 3.8626e-01 | Data(mse): 2.0034e-01
#   Misfit(RMS χ²): 5.848 | Rough: 1.25e+01 | Lam: 0.0148968
#   OT-distance(6D, view-only): 3.175603e-02
#   GradNorms: |g_d|=1.280e-03 | |λ·g_m|=7.464e-04
#  [Auto-Lambda] Epoch 190: Adjusted 1.49e-02 -> 1.29e-02 (ratio=7.512e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 1.29e-02 -> 1.12e-02 (ratio=7.469e-01)
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:05:14 | Remaining: ~0:02:34 | ETA: 22:33:33
#   Epoch time: 1.89s | Avg: 1.56s
#   Total: 3.1826e-01 | Data(mse): 1.6211e-01
#   Misfit(RMS χ²): 5.261 | Rough: 1.40e+01 | Lam: 0.0111587
#   OT-distance(6D, view-only): 2.639959e-02
#   GradNorms: |g_d|=1.048e-03 | |λ·g_m|=6.154e-04
#  [Auto-Lambda] Epoch 210: Adjusted 1.12e-02 -> 9.62e-03 (ratio=7.432e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 9.62e-03 -> 8.27e-03 (ratio=7.399e-01)
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:05:45 | Remaining: ~0:02:03 | ETA: 22:33:34
#   Epoch time: 2.01s | Avg: 1.56s
#   Total: 2.6122e-01 | Data(mse): 1.3208e-01
#   Misfit(RMS χ²): 4.749 | Rough: 1.56e+01 | Lam: 0.0082747
#   OT-distance(6D, view-only): 2.193416e-02
#   GradNorms: |g_d|=8.519e-04 | |λ·g_m|=5.027e-04
#  [Auto-Lambda] Epoch 230: Adjusted 8.27e-03 -> 7.10e-03 (ratio=7.371e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 7.10e-03 -> 6.09e-03 (ratio=7.349e-01)
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:06:17 | Remaining: ~0:01:32 | ETA: 22:33:35
#   Epoch time: 1.95s | Avg: 1.56s
#   Total: 2.1359e-01 | Data(mse): 1.0803e-01
#   Misfit(RMS χ²): 4.295 | Rough: 1.73e+01 | Lam: 0.0060904
#   OT-distance(6D, view-only): 1.819086e-02
#   GradNorms: |g_d|=6.896e-04 | |λ·g_m|=4.084e-04
#  [Auto-Lambda] Epoch 250: Adjusted 6.09e-03 -> 5.22e-03 (ratio=7.336e-01)
#  [Auto-Lambda] Epoch 260: Adjusted 5.22e-03 -> 4.47e-03 (ratio=7.336e-01)
# Epoch 261/300 [  87.0%]
#   Elapsed: 0:06:48 | Remaining: ~0:01:00 | ETA: 22:33:34
#   Epoch time: 1.91s | Avg: 1.56s
#   Total: 1.7421e-01 | Data(mse): 8.8529e-02
#   Misfit(RMS χ²): 3.888 | Rough: 1.92e+01 | Lam: 0.0044679
#   OT-distance(6D, view-only): 1.509865e-02
#   GradNorms: |g_d|=5.596e-04 | |λ·g_m|=3.317e-04
#  [Auto-Lambda] Epoch 270: Adjusted 4.47e-03 -> 3.83e-03 (ratio=7.346e-01)
#  [Auto-Lambda] Epoch 280: Adjusted 3.83e-03 -> 3.29e-03 (ratio=7.370e-01)
# Epoch 281/300 [  93.7%]
#   Elapsed: 0:07:20 | Remaining: ~0:00:29 | ETA: 22:33:35
#   Epoch time: 2.08s | Avg: 1.57s
#   Total: 1.4218e-01 | Data(mse): 7.2781e-02
#   Misfit(RMS χ²): 3.525 | Rough: 2.11e+01 | Lam: 0.0032876
#   OT-distance(6D, view-only): 1.262853e-02
#   GradNorms: |g_d|=4.575e-04 | |λ·g_m|=2.703e-04
#  [Auto-Lambda] Epoch 290: Adjusted 3.29e-03 -> 2.83e-03 (ratio=7.409e-01)
# Epoch 300/300 [ 100.0%]
#   Elapsed: 0:07:51 | Remaining: ~0:00:00 | ETA: 22:33:36
#   Epoch time: 1.98s | Avg: 1.57s
#   Total: 1.2587e-01 | Data(mse): 6.0927e-02
#   Misfit(RMS χ²): 3.225 | Rough: 2.29e+01 | Lam: 0.0028299
#   OT-distance(6D, view-only): 1.084223e-02
#   GradNorms: |g_d|=3.810e-04 | |λ·g_m|=2.552e-04
# Inversion completed.
# Inversion done
# 1e-10 0.3187537636331771

# %%
# 5) Plot results
inv.plot_loss_history()
inv.plot_model_comparison(**PLOT_KWARGS)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.7655

# %%
logger.save_from_inverter(
    inv,
    run_name="rubic_mse",
    plot_kwargs=PLOT_KWARGS,
)
# Out:
# ============================================================
# Saving results to: test_results/rubic/2026-07-05_22-33-41_rubic_mse
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.7655
#   ✓ Figures saved to test_results/rubic/2026-07-05_22-33-41_rubic_mse/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/rubic/2026-07-05_22-33-41_rubic_mse
#   Final RMS χ²: 3.2251
#   RMSE: 0.5618
#   MAPE: 23.47%
# ============================================================
# PosixPath('test_results/rubic/2026-07-05_22-33-41_rubic_mse')
