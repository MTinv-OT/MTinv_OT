# %% [markdown]
# # COMMEMI 2D-4：固定静位移（TE 和 TM 有相同静位移） OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d4` 生成标准模型，
# **通过新接口固定静位移**（`static_shift_log` + `shift_station_indices`）施加静位移。
# xy 和 yx（TE/TM）在相同指定台站施加相同固定 log10 乘子 0.15。
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演，并对比。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "2"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d4",
    output_root=Path("test_results"),
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/MTinv_OT3

# %%
import os
from pathlib import Path

print(f"当前目录: {Path.cwd()}")
print(f"目录内容: {list(Path.cwd().iterdir())}")

# 检查 src 在哪里
for p in [Path.cwd(), Path.cwd().parent, Path.cwd().parent.parent]:
    if (p / "src").exists():
        print(f"找到 src 在: {p}")
# Out:
# 当前目录: /home/liuxr/MTinv_OT3/tests/synthetic
# 目录内容: [PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_ot_21.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/.ipynb_checkpoints'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.15.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.15.ipynb.invalid'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.2.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.2.ipynb.invalid'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_ot_31.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_mse_31.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/test_results'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.1.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_mse_21.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.ipynb.invalid'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.15.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.1.ipynb')]
# 找到 src 在: /home/liuxr/MTinv_OT3

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d4(
    nza=10,
    device=device, 
)

# 2) Survey setup
freqs = torch.logspace(0, -5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=10,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.01,
                        noise_type="gaussian",
                        static_shift_std=0.0,
                        shift_station_indices=[3, 10, 18],  # 显式指定台站
                        static_shift_log={"xy": 0.15, "yx": 0.15},  # 固定强度（新接口）
                        # 说明：未出现在 static_shift_log 中的模式不会被施加静位移
)

inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0],synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.843092e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 1.0% (gaussian)
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4a) OT 反演 (6dot)
inv.initialize_model(initial_sigma=0.01)
final_sigma_ot = inv.run_inversion(
    n_epochs=300,
    mode="6dot",
    progress_interval=20,
    current_lambda=0.01,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("OT inversion done")
print(final_sigma_ot.min().item(), final_sigma_ot.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:02 | Remaining: ~0:09:04 | ETA: 13:20:05
#   Epoch time: 1.82s | Avg: 1.82s
#   Total: 5.5469e-01 | Data(6dot): 5.5469e-01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 63.234 | Rough: 0.00e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 5.546868e-01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e-02 -> 5.70e-03 (ratio=3.249e-01)
#  [Auto-Lambda] Epoch 20: Adjusted 5.70e-03 -> 4.63e-03 (ratio=6.603e-01)
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:39 | Remaining: ~0:08:36 | ETA: 13:20:14
#   Epoch time: 2.23s | Avg: 1.85s
#   Total: 2.5756e-01 | Data(6dot): 2.4081e-01
#   Misfit(RMS χ²): 44.449 | Rough: 3.62e+00 | Lam: 0.0046318
#   OT-distance(6D, view-only): 2.408122e-01
#   GradNorms: |g_d|=6.578e-04 | |λ·g_m|=4.008e-04
#  [Auto-Lambda] Epoch 40: Adjusted 4.63e-03 -> 4.36e-03 (ratio=8.864e-01)
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:17 | Remaining: ~0:08:01 | ETA: 13:20:16
#   Epoch time: 2.29s | Avg: 1.86s
#   Total: 1.4750e-01 | Data(6dot): 1.1352e-01
#   Misfit(RMS χ²): 35.188 | Rough: 7.79e+00 | Lam: 0.0043607
#   OT-distance(6D, view-only): 1.135234e-01
#   GradNorms: |g_d|=4.685e-04 | |λ·g_m|=2.475e-04
#  [Auto-Lambda] Epoch 50: Adjusted 4.36e-03 -> 3.80e-03 (ratio=7.576e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 3.80e-03 -> 3.26e-03 (ratio=7.400e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:53 | Remaining: ~0:07:22 | ETA: 13:20:15
#   Epoch time: 2.35s | Avg: 1.85s
#   Total: 9.8324e-02 | Data(6dot): 6.6371e-02
#   Misfit(RMS χ²): 28.670 | Rough: 9.79e+00 | Lam: 0.0032649
#   OT-distance(6D, view-only): 6.637092e-02
#   GradNorms: |g_d|=2.863e-04 | |λ·g_m|=1.683e-04
#  [Auto-Lambda] Epoch 70: Adjusted 3.26e-03 -> 2.78e-03 (ratio=7.269e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 2.78e-03 -> 2.42e-03 (ratio=7.583e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:30 | Remaining: ~0:06:45 | ETA: 13:20:14
#   Epoch time: 2.20s | Avg: 1.85s
#   Total: 7.1047e-02 | Data(6dot): 4.4365e-02
#   Misfit(RMS χ²): 23.804 | Rough: 1.10e+01 | Lam: 0.0024240
#   OT-distance(6D, view-only): 4.436518e-02
#   GradNorms: |g_d|=2.196e-04 | |λ·g_m|=1.270e-04
#  [Auto-Lambda] Epoch 90: Adjusted 2.42e-03 -> 2.15e-03 (ratio=7.841e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 2.15e-03 -> 1.88e-03 (ratio=7.667e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:03:06 | Remaining: ~0:06:06 | ETA: 13:20:11
#   Epoch time: 2.23s | Avg: 1.84s
#   Total: 5.4172e-02 | Data(6dot): 3.1502e-02
#   Misfit(RMS χ²): 19.899 | Rough: 1.21e+01 | Lam: 0.0018794
#   OT-distance(6D, view-only): 3.150234e-02
#   GradNorms: |g_d|=1.740e-04 | |λ·g_m|=1.007e-04
#  [Auto-Lambda] Epoch 110: Adjusted 1.88e-03 -> 1.63e-03 (ratio=7.531e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 1.63e-03 -> 1.41e-03 (ratio=7.465e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:42 | Remaining: ~0:05:28 | ETA: 13:20:10
#   Epoch time: 2.25s | Avg: 1.84s
#   Total: 4.1536e-02 | Data(6dot): 2.3178e-02
#   Misfit(RMS χ²): 16.700 | Rough: 1.30e+01 | Lam: 0.0014091
#   OT-distance(6D, view-only): 2.317828e-02
#   GradNorms: |g_d|=1.326e-04 | |λ·g_m|=7.774e-05
#  [Auto-Lambda] Epoch 130: Adjusted 1.41e-03 -> 1.22e-03 (ratio=7.481e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.22e-03 -> 1.06e-03 (ratio=7.498e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:04:19 | Remaining: ~0:04:51 | ETA: 13:20:09
#   Epoch time: 2.29s | Avg: 1.83s
#   Total: 3.2265e-02 | Data(6dot): 1.7537e-02
#   Misfit(RMS χ²): 14.155 | Rough: 1.40e+01 | Lam: 0.0010553
#   OT-distance(6D, view-only): 1.753702e-02
#   GradNorms: |g_d|=1.018e-04 | |λ·g_m|=5.948e-05
#  [Auto-Lambda] Epoch 150: Adjusted 1.06e-03 -> 9.16e-04 (ratio=7.530e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 9.16e-04 -> 7.98e-04 (ratio=7.590e-01)
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:54 | Remaining: ~0:04:13 | ETA: 13:20:06
#   Epoch time: 2.29s | Avg: 1.82s
#   Total: 2.5507e-02 | Data(6dot): 1.3707e-02
#   Misfit(RMS χ²): 12.204 | Rough: 1.48e+01 | Lam: 0.0007979
#   OT-distance(6D, view-only): 1.370694e-02
#   GradNorms: |g_d|=7.882e-05 | |λ·g_m|=4.573e-05
#  [Auto-Lambda] Epoch 170: Adjusted 7.98e-04 -> 6.99e-04 (ratio=7.685e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 6.99e-04 -> 6.17e-04 (ratio=7.794e-01)
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:05:29 | Remaining: ~0:03:36 | ETA: 13:20:04
#   Epoch time: 2.17s | Avg: 1.82s
#   Total: 2.0653e-02 | Data(6dot): 1.1077e-02
#   Misfit(RMS χ²): 10.724 | Rough: 1.55e+01 | Lam: 0.0006175
#   OT-distance(6D, view-only): 1.107673e-02
#   GradNorms: |g_d|=6.271e-05 | |λ·g_m|=3.585e-05
#  [Auto-Lambda] Epoch 190: Adjusted 6.17e-04 -> 5.49e-04 (ratio=7.911e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 5.49e-04 -> 4.92e-04 (ratio=8.036e-01)
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:06:05 | Remaining: ~0:02:59 | ETA: 13:20:03
#   Epoch time: 2.15s | Avg: 1.81s
#   Total: 1.7168e-02 | Data(6dot): 9.2323e-03
#   Misfit(RMS χ²): 9.598 | Rough: 1.61e+01 | Lam: 0.0004923
#   OT-distance(6D, view-only): 9.232265e-03
#   GradNorms: |g_d|=5.138e-05 | |λ·g_m|=2.888e-05
#  [Auto-Lambda] Epoch 210: Adjusted 4.92e-04 -> 4.45e-04 (ratio=8.168e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 4.45e-04 -> 4.05e-04 (ratio=8.299e-01)
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:06:40 | Remaining: ~0:02:22 | ETA: 13:20:02
#   Epoch time: 2.18s | Avg: 1.81s
#   Total: 1.4642e-02 | Data(6dot): 7.8996e-03
#   Misfit(RMS χ²): 8.730 | Rough: 1.66e+01 | Lam: 0.0004053
#   OT-distance(6D, view-only): 7.899640e-03
#   GradNorms: |g_d|=4.342e-05 | |λ·g_m|=2.398e-05
#  [Auto-Lambda] Epoch 230: Adjusted 4.05e-04 -> 3.72e-04 (ratio=8.428e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 3.72e-04 -> 3.44e-04 (ratio=8.553e-01)
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:07:16 | Remaining: ~0:01:46 | ETA: 13:20:02
#   Epoch time: 2.24s | Avg: 1.81s
#   Total: 1.2773e-02 | Data(6dot): 6.8999e-03
#   Misfit(RMS χ²): 8.039 | Rough: 1.71e+01 | Lam: 0.0003441
#   OT-distance(6D, view-only): 6.899867e-03
#   GradNorms: |g_d|=3.775e-05 | |λ·g_m|=2.051e-05
#  [Auto-Lambda] Epoch 250: Adjusted 3.44e-04 -> 3.21e-04 (ratio=8.675e-01)
#  [Auto-Lambda] Epoch 260: Adjusted 3.21e-04 -> 3.01e-04 (ratio=8.796e-01)
# Epoch 261/300 [  87.0%]
#   Elapsed: 0:07:51 | Remaining: ~0:01:10 | ETA: 13:20:00
#   Epoch time: 2.21s | Avg: 1.80s
#   Total: 1.1359e-02 | Data(6dot): 6.1170e-03
#   Misfit(RMS χ²): 7.462 | Rough: 1.74e+01 | Lam: 0.0003006
#   OT-distance(6D, view-only): 6.116999e-03
#   GradNorms: |g_d|=3.374e-05 | |λ·g_m|=1.805e-05
#  [Auto-Lambda] Epoch 270: Adjusted 3.01e-04 -> 2.84e-04 (ratio=8.915e-01)
# Epoch 281/300 [  93.7%]
#   Elapsed: 0:08:27 | Remaining: ~0:00:34 | ETA: 13:19:59
#   Epoch time: 2.35s | Avg: 1.80s
#   Total: 1.0518e-02 | Data(6dot): 5.4772e-03
#   Misfit(RMS χ²): 6.958 | Rough: 1.78e+01 | Lam: 0.0002838
#   OT-distance(6D, view-only): 5.477199e-03
#   GradNorms: |g_d|=3.097e-05 | |λ·g_m|=1.720e-05
#  [Auto-Lambda] Epoch 290: Adjusted 2.84e-04 -> 2.66e-04 (ratio=8.812e-01)
# Epoch 300/300 [ 100.0%]
#   Elapsed: 0:09:00 | Remaining: ~0:00:00 | ETA: 13:19:59
#   Epoch time: 2.24s | Avg: 1.80s
#   Total: 9.7652e-03 | Data(6dot): 4.9738e-03
#   Misfit(RMS χ²): 6.523 | Rough: 1.80e+01 | Lam: 0.0002664
#   OT-distance(6D, view-only): 4.973834e-03
#   GradNorms: |g_d|=2.936e-05 | |λ·g_m|=1.628e-05
# Inversion completed.
# OT inversion done
# 1e-10 0.12075254724815118

# %%
# 5a) OT 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.8383

# %%
# 6a) 保存 OT 结果
ot_run_dir = logger.save_from_inverter(inv, run_name="ot_21_4_both_same")
history_ot = list(inv.loss_history)
print(f"OT run saved: {ot_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d4/2026-07-06_13-20-20_ot_21_4shift0
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.8383
# /home/liuxr/MTinv_OT3/src/mt2d_inv/plotting/inversion.py:682: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   for batch_start in range(0, len(station_indices), stations_per_figure):
#   ✓ data_fitting: 21 plots saved to test_results/ccmm2d4/2026-07-06_13-20-20_ot_21_4shift0/figures/data_fitting (21 stations)
#   ✓ Figures saved to test_results/ccmm2d4/2026-07-06_13-20-20_ot_21_4shift0/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d4/2026-07-06_13-20-20_ot_21_4shift0
#   Final RMS χ²: 6.5226
#   RMSE: 0.5835
#   MAPE: 17.70%
# ============================================================
#
# OT run saved: test_results/ccmm2d4/2026-07-06_13-20-20_ot_21_4shift0

# %%
# 4b) MSE 反演（同一静位移观测数据，重置初模）
inv.initialize_model(initial_sigma=0.01)
final_sigma_mse = inv.run_inversion(
    n_epochs=300,
    mode="mse",
    progress_interval=20,
    current_lambda=1,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("MSE inversion done")
print(final_sigma_mse.min().item(), final_sigma_mse.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:01 | Remaining: ~0:07:33 | ETA: 13:28:23
#   Epoch time: 1.52s | Avg: 1.52s
#   Total: 1.1712e+01 | Data(mse): 1.1712e+01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 63.234 | Rough: 0.00e+00 | Lam: 1.0000000
#   OT-distance(6D, view-only): 5.546868e-01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e+00 -> 4.03e-01 (ratio=1.625e-01)
#  [Auto-Lambda] Epoch 20: Adjusted 4.03e-01 -> 3.05e-01 (ratio=5.730e-01)
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:35 | Remaining: ~0:07:55 | ETA: 13:29:19
#   Epoch time: 2.27s | Avg: 1.70s
#   Total: 5.8345e+00 | Data(mse): 5.4002e+00
#   Misfit(RMS χ²): 42.938 | Rough: 1.42e+00 | Lam: 0.3051375
#   OT-distance(6D, view-only): 3.911602e-01
#   GradNorms: |g_d|=3.757e-02 | |λ·g_m|=2.662e-02
#  [Auto-Lambda] Epoch 30: Adjusted 3.05e-01 -> 2.70e-01 (ratio=7.812e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 2.70e-01 -> 2.33e-01 (ratio=7.476e-01)
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:09 | Remaining: ~0:07:20 | ETA: 13:29:18
#   Epoch time: 2.06s | Avg: 1.70s
#   Total: 3.4014e+00 | Data(mse): 2.6185e+00
#   Misfit(RMS χ²): 29.900 | Rough: 3.36e+00 | Lam: 0.2332015
#   OT-distance(6D, view-only): 2.880136e-01
#   GradNorms: |g_d|=2.257e-02 | |λ·g_m|=1.330e-02
#  [Auto-Lambda] Epoch 50: Adjusted 2.33e-01 -> 1.93e-01 (ratio=6.876e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 1.93e-01 -> 1.52e-01 (ratio=6.181e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:43 | Remaining: ~0:06:43 | ETA: 13:29:14
#   Epoch time: 2.13s | Avg: 1.69s
#   Total: 2.2142e+00 | Data(mse): 1.5028e+00
#   Misfit(RMS χ²): 22.651 | Rough: 4.68e+00 | Lam: 0.1520237
#   OT-distance(6D, view-only): 2.219736e-01
#   GradNorms: |g_d|=1.560e-02 | |λ·g_m|=1.015e-02
#  [Auto-Lambda] Epoch 70: Adjusted 1.52e-01 -> 1.19e-01 (ratio=6.155e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 1.19e-01 -> 9.30e-02 (ratio=6.082e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:15 | Remaining: ~0:06:07 | ETA: 13:29:11
#   Epoch time: 2.06s | Avg: 1.68s
#   Total: 1.4845e+00 | Data(mse): 9.5171e-01
#   Misfit(RMS χ²): 18.026 | Rough: 5.73e+00 | Lam: 0.0930185
#   OT-distance(6D, view-only): 1.715277e-01
#   GradNorms: |g_d|=1.010e-02 | |λ·g_m|=6.619e-03
#  [Auto-Lambda] Epoch 90: Adjusted 9.30e-02 -> 7.26e-02 (ratio=6.086e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 7.26e-02 -> 5.65e-02 (ratio=6.062e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:02:49 | Remaining: ~0:05:33 | ETA: 13:29:11
#   Epoch time: 2.11s | Avg: 1.68s
#   Total: 1.0148e+00 | Data(mse): 6.2821e-01
#   Misfit(RMS χ²): 14.645 | Rough: 6.84e+00 | Lam: 0.0564999
#   OT-distance(6D, view-only): 1.293022e-01
#   GradNorms: |g_d|=6.230e-03 | |λ·g_m|=4.094e-03
#  [Auto-Lambda] Epoch 110: Adjusted 5.65e-02 -> 4.39e-02 (ratio=6.032e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 4.39e-02 -> 3.41e-02 (ratio=6.032e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:22 | Remaining: ~0:04:59 | ETA: 13:29:10
#   Epoch time: 2.09s | Avg: 1.67s
#   Total: 7.0540e-01 | Data(mse): 4.3105e-01
#   Misfit(RMS χ²): 12.131 | Rough: 8.05e+00 | Lam: 0.0340806
#   OT-distance(6D, view-only): 9.590665e-02
#   GradNorms: |g_d|=3.737e-03 | |λ·g_m|=2.461e-03
#  [Auto-Lambda] Epoch 130: Adjusted 3.41e-02 -> 2.67e-02 (ratio=6.128e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 2.67e-02 -> 2.13e-02 (ratio=6.378e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:03:55 | Remaining: ~0:04:25 | ETA: 13:29:08
#   Epoch time: 1.99s | Avg: 1.67s
#   Total: 5.0611e-01 | Data(mse): 3.0725e-01
#   Misfit(RMS χ²): 10.242 | Rough: 9.33e+00 | Lam: 0.0213062
#   OT-distance(6D, view-only): 7.087075e-02
#   GradNorms: |g_d|=2.388e-03 | |λ·g_m|=1.520e-03
#  [Auto-Lambda] Epoch 150: Adjusted 2.13e-02 -> 1.76e-02 (ratio=6.802e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 1.76e-02 -> 1.51e-02 (ratio=7.358e-01)
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:28 | Remaining: ~0:03:51 | ETA: 13:29:08
#   Epoch time: 2.00s | Avg: 1.67s
#   Total: 3.8803e-01 | Data(mse): 2.2889e-01
#   Misfit(RMS χ²): 8.840 | Rough: 1.06e+01 | Lam: 0.0150736
#   OT-distance(6D, view-only): 5.330954e-02
#   GradNorms: |g_d|=1.805e-03 | |λ·g_m|=1.061e-03
#  [Auto-Lambda] Epoch 170: Adjusted 1.51e-02 -> 1.34e-02 (ratio=7.947e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 1.34e-02 -> 1.24e-02 (ratio=8.465e-01)
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:05:01 | Remaining: ~0:03:18 | ETA: 13:29:07
#   Epoch time: 2.10s | Avg: 1.66s
#   Total: 3.2189e-01 | Data(mse): 1.7939e-01
#   Misfit(RMS χ²): 7.826 | Rough: 1.15e+01 | Lam: 0.0123633
#   OT-distance(6D, view-only): 4.179893e-02
#   GradNorms: |g_d|=1.576e-03 | |λ·g_m|=8.598e-04
#  [Auto-Lambda] Epoch 190: Adjusted 1.24e-02 -> 1.16e-02 (ratio=8.848e-01)
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:05:33 | Remaining: ~0:02:44 | ETA: 13:29:06
#   Epoch time: 2.02s | Avg: 1.66s
#   Total: 2.8873e-01 | Data(mse): 1.4719e-01
#   Misfit(RMS χ²): 7.089 | Rough: 1.22e+01 | Lam: 0.0116296
#   OT-distance(6D, view-only): 3.442656e-02
#   GradNorms: |g_d|=1.458e-03 | |λ·g_m|=8.048e-04
#  [Auto-Lambda] Epoch 210: Adjusted 1.16e-02 -> 1.10e-02 (ratio=8.876e-01)
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:06:06 | Remaining: ~0:02:10 | ETA: 13:29:05
#   Epoch time: 1.99s | Avg: 1.66s
#   Total: 2.6250e-01 | Data(mse): 1.2533e-01
#   Misfit(RMS χ²): 6.541 | Rough: 1.25e+01 | Lam: 0.0109564
#   OT-distance(6D, view-only): 2.965175e-02
#   GradNorms: |g_d|=1.373e-03 | |λ·g_m|=7.580e-04
#  [Auto-Lambda] Epoch 230: Adjusted 1.10e-02 -> 1.03e-02 (ratio=8.804e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 1.03e-02 -> 9.75e-03 (ratio=8.998e-01)
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:06:38 | Remaining: ~0:01:37 | ETA: 13:29:04
#   Epoch time: 2.02s | Avg: 1.66s
#   Total: 2.3311e-01 | Data(mse): 1.0859e-01
#   Misfit(RMS χ²): 6.089 | Rough: 1.28e+01 | Lam: 0.0097519
#   OT-distance(6D, view-only): 2.613940e-02
#   GradNorms: |g_d|=1.285e-03 | |λ·g_m|=6.805e-04
#  [Auto-Lambda] Epoch 250: Adjusted 9.75e-03 -> 9.26e-03 (ratio=9.024e-01)
# Epoch 261/300 [  87.0%]
#   Elapsed: 0:07:11 | Remaining: ~0:01:04 | ETA: 13:29:03
#   Epoch time: 1.94s | Avg: 1.65s
#   Total: 2.1527e-01 | Data(mse): 9.4294e-02
#   Misfit(RMS χ²): 5.674 | Rough: 1.31e+01 | Lam: 0.0092640
#   OT-distance(6D, view-only): 2.315538e-02
#   GradNorms: |g_d|=1.184e-03 | |λ·g_m|=6.569e-04
#  [Auto-Lambda] Epoch 270: Adjusted 9.26e-03 -> 8.65e-03 (ratio=8.717e-01)
#  [Auto-Lambda] Epoch 280: Adjusted 8.65e-03 -> 8.14e-03 (ratio=8.852e-01)
# Epoch 281/300 [  93.7%]
#   Elapsed: 0:07:42 | Remaining: ~0:00:31 | ETA: 13:29:02
#   Epoch time: 1.93s | Avg: 1.65s
#   Total: 1.9102e-01 | Data(mse): 8.3006e-02
#   Misfit(RMS χ²): 5.323 | Rough: 1.33e+01 | Lam: 0.0081373
#   OT-distance(6D, view-only): 2.086504e-02
#   GradNorms: |g_d|=1.093e-03 | |λ·g_m|=5.839e-04
#  [Auto-Lambda] Epoch 290: Adjusted 8.14e-03 -> 7.66e-03 (ratio=8.868e-01)
# Epoch 300/300 [ 100.0%]
#   Elapsed: 0:08:12 | Remaining: ~0:00:00 | ETA: 13:29:00
#   Epoch time: 1.92s | Avg: 1.64s
#   Total: 1.7721e-01 | Data(mse): 7.3546e-02
#   Misfit(RMS χ²): 5.011 | Rough: 1.35e+01 | Lam: 0.0076630
#   OT-distance(6D, view-only): 1.892158e-02
#   GradNorms: |g_d|=9.946e-04 | |λ·g_m|=5.598e-04
# Inversion completed.
# MSE inversion done
# 1e-10 0.095788350793046

# %%
# 5b) MSE 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.8457

# %%
# 6b) 保存 MSE 结果
mse_run_dir = logger.save_from_inverter(inv, run_name="mse21_4_both_same")
history_mse = list(inv.loss_history)
print(f"MSE run saved: {mse_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d4/2026-07-06_13-29-21_mse21_4shift0
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.8457
# /home/liuxr/MTinv_OT3/src/mt2d_inv/plotting/inversion.py:682: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   for batch_start in range(0, len(station_indices), stations_per_figure):
#   ✓ data_fitting: 21 plots saved to test_results/ccmm2d4/2026-07-06_13-29-21_mse21_4shift0/figures/data_fitting (21 stations)
#   ✓ Figures saved to test_results/ccmm2d4/2026-07-06_13-29-21_mse21_4shift0/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d4/2026-07-06_13-29-21_mse21_4shift0
#   Final RMS χ²: 5.0110
#   RMSE: 0.6171
#   MAPE: 20.01%
# ============================================================
#
# MSE run saved: test_results/ccmm2d4/2026-07-06_13-29-21_mse21_4shift0

# %%
# 7) OT vs MSE 对比（收敛曲线 + 视电阻率四线合一 + 伪断面）
plot_ot_mse_convergence(history_ot, history_mse, target_misfit=1.05)

plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=0,
    mode="xy",
)
plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=0,
    mode="yx",
)

plot_ot_mse_pseudosection_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    mode="xy",
)
# Out:
# /home/liuxr/MTinv_OT3/src/mt2d_inv/plotting/pseudosection.py:171: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# {'inversion_axes': array([[<Axes: title={'center': 'True'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#          <Axes: title={'center': 'OT inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#          <Axes: title={'center': 'MSE inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>]],
#        dtype=object),
#  'observed_axes': <Axes: title={'center': 'Observed (rhoxy)'}, xlabel='Distance (km)', ylabel='Period (s)'>}
