# %% [markdown]
# # COMMEMI 2D-1：随机静位移（TE/TM 相同模式） OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d1` 生成标准模型。
# **随机选取部分台站**，在 xy/yx（TE/TM）上施加**随机 log10 静位移**（`static_shift_std=0.15`）。
# 合成观测只生成一次，OT 与 MSE **共用同一套 `obs_data`**。
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演并对比。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d1",
    output_root=Path("test_results"),
)
ot_run_name = "ot1_shift_0.1"
mse_run_name = "mse1_shift_0.1"

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/论文绘图

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d1(
    zn=None,
    yn=None,
    nza=10,
    device=device,
    rho_host=100.0,
    rho_block=10.0,
    y_half_width_m=2000.0,
    z_top_m=10000.0,
    z_bottom_m=30000.0,
)

# 2) Survey setup
freqs = torch.logspace(0, -3.5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data（OT/MSE 共用，只生成一次）
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=10000,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(
    noise_level=0.01,
    noise_type="gaussian",
    static_shift_std=0.15,   # 对数域标准差 σ：每台站独立抽取 s~N(0,σ²)，乘子 10^s
    shift_modes=("xy", "yx"),
    shift_stations="random",
    shift_ratio=0.1,
)

# 保存 OT/MSE 共用观测快照
shared_obs_snapshot = {
    "obs_data": {k: v.clone() for k, v in inv.obs_data.items()},
    "data_std": {k: v.clone() if torch.is_tensor(v) else v for k, v in inv.data_std.items()},
}
shared_shift_meta = {
    "shift_mask": inv.shift_mask.clone(),
    "shift_station_ids": list(inv.shift_station_ids),
    "n_shift_stations": inv.n_shift_stations,
    "shift_fraction_actual": inv.shift_fraction_actual,
    "static_shift_std": inv.static_shift_std,
    "shift_ratio": inv.shift_ratio,
    "shift_modes": inv.shift_modes,
    "shift_stations": inv.shift_stations,
    "static_shift_log": {k: v.clone() for k, v in inv.static_shift_log.items()},
    "static_shift_factors": {k: v.clone() for k, v in inv.static_shift_factors.items()},
    "true_data_no_shift": {k: v.clone() for k, v in inv.true_data_no_shift.items()},
    "noise_level": inv.noise_level,
}

print(f"随机静位移受影响台站: {inv.shift_station_ids}")

inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0], synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.844943e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 1.0% (gaussian)
# 随机静位移受影响台站: [8, 17]
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4a) OT 反演 (6dot)
inv.initialize_model(initial_sigma=0.01)
final_sigma_ot = inv.run_inversion(
    n_epochs=250,
    mode="6dot",
    progress_interval=20,
    current_lambda=3,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("OT inversion done")
print(final_sigma_ot.min().item(), final_sigma_ot.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/250 [   0.4%]
#   Elapsed: 0:00:02 | Remaining: ~0:05:52 | ETA: 04:02:22
#   Epoch time: 1.42s | Avg: 1.42s
#   Total: 1.5131e+01 | Data(6dot): 1.5131e+01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 10.605 | Rough: 0.00e+00 | Lam: 3.0000000
#   OT-distance(6D, view-only): 1.513147e+00
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 3.00e+00 -> 1.13e+00 (ratio=1.415e-01)
#  [Auto-Lambda] Epoch 20: Adjusted 1.13e+00 -> 4.61e-01 (ratio=1.670e-01)
# Epoch 21/250 [   8.4%]
#   Elapsed: 0:00:35 | Remaining: ~0:06:13 | ETA: 04:03:16
#   Epoch time: 2.10s | Avg: 1.63s
#   Total: 6.2969e+00 | Data(6dot): 5.9367e+00
#   Misfit(RMS χ²): 9.378 | Rough: 7.81e-01 | Lam: 0.4611559
#   OT-distance(6D, view-only): 5.936654e-01
#   GradNorms: |g_d|=2.662e-02 | |λ·g_m|=2.696e-02
#  [Auto-Lambda] Epoch 30: Adjusted 4.61e-01 -> 2.49e-01 (ratio=2.918e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 2.49e-01 -> 1.86e-01 (ratio=5.596e-01)
# Epoch 41/250 [  16.4%]
#   Elapsed: 0:01:08 | Remaining: ~0:05:44 | ETA: 04:03:20
#   Epoch time: 2.10s | Avg: 1.65s
#   Total: 5.3155e+00 | Data(6dot): 5.0409e+00
#   Misfit(RMS χ²): 8.961 | Rough: 1.47e+00 | Lam: 0.1863403
#   OT-distance(6D, view-only): 5.040923e-01
#   GradNorms: |g_d|=9.818e-03 | |λ·g_m|=5.904e-03
#  [Auto-Lambda] Epoch 50: Adjusted 1.86e-01 -> 1.50e-01 (ratio=6.523e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 1.50e-01 -> 1.18e-01 (ratio=6.165e-01)
# Epoch 61/250 [  24.4%]
#   Elapsed: 0:01:41 | Remaining: ~0:05:12 | ETA: 04:03:21
#   Epoch time: 2.16s | Avg: 1.65s
#   Total: 5.1190e+00 | Data(6dot): 4.9136e+00
#   Misfit(RMS χ²): 8.871 | Rough: 1.74e+00 | Lam: 0.1181696
#   OT-distance(6D, view-only): 4.913584e-01
#   GradNorms: |g_d|=4.880e-03 | |λ·g_m|=3.347e-03
#  [Auto-Lambda] Epoch 70: Adjusted 1.18e-01 -> 9.07e-02 (ratio=5.886e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 9.07e-02 -> 6.78e-02 (ratio=5.589e-01)
# Epoch 81/250 [  32.4%]
#   Elapsed: 0:02:14 | Remaining: ~0:04:39 | ETA: 04:03:21
#   Epoch time: 2.07s | Avg: 1.65s
#   Total: 4.9852e+00 | Data(6dot): 4.8349e+00
#   Misfit(RMS χ²): 8.824 | Rough: 2.22e+00 | Lam: 0.0677749
#   OT-distance(6D, view-only): 4.834868e-01
#   GradNorms: |g_d|=2.994e-03 | |λ·g_m|=2.177e-03
#  [Auto-Lambda] Epoch 90: Adjusted 6.78e-02 -> 5.10e-02 (ratio=5.661e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 5.10e-02 -> 3.87e-02 (ratio=5.754e-01)
# Epoch 101/250 [  40.4%]
#   Elapsed: 0:02:47 | Remaining: ~0:04:06 | ETA: 04:03:22
#   Epoch time: 2.12s | Avg: 1.65s
#   Total: 4.8885e+00 | Data(6dot): 4.7758e+00
#   Misfit(RMS χ²): 8.791 | Rough: 2.91e+00 | Lam: 0.0386797
#   OT-distance(6D, view-only): 4.775760e-01
#   GradNorms: |g_d|=2.168e-03 | |λ·g_m|=1.461e-03
#  [Auto-Lambda] Epoch 110: Adjusted 3.87e-02 -> 2.96e-02 (ratio=5.852e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 2.96e-02 -> 2.29e-02 (ratio=6.012e-01)
# Epoch 121/250 [  48.4%]
#   Elapsed: 0:03:21 | Remaining: ~0:03:33 | ETA: 04:03:22
#   Epoch time: 2.14s | Avg: 1.66s
#   Total: 4.8108e+00 | Data(6dot): 4.7207e+00
#   Misfit(RMS χ²): 8.771 | Rough: 3.93e+00 | Lam: 0.0229427
#   OT-distance(6D, view-only): 4.720658e-01
#   GradNorms: |g_d|=1.586e-03 | |λ·g_m|=1.031e-03
#  [Auto-Lambda] Epoch 130: Adjusted 2.29e-02 -> 1.83e-02 (ratio=6.336e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.83e-02 -> 1.50e-02 (ratio=6.727e-01)
# Epoch 141/250 [  56.4%]
#   Elapsed: 0:03:55 | Remaining: ~0:03:01 | ETA: 04:03:23
#   Epoch time: 2.09s | Avg: 1.66s
#   Total: 4.7312e+00 | Data(6dot): 4.6453e+00
#   Misfit(RMS χ²): 8.761 | Rough: 5.74e+00 | Lam: 0.0149789
#   OT-distance(6D, view-only): 4.645272e-01
#   GradNorms: |g_d|=1.326e-03 | |λ·g_m|=8.180e-04
#  [Auto-Lambda] Epoch 150: Adjusted 1.50e-02 -> 1.26e-02 (ratio=7.092e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 1.26e-02 -> 1.02e-02 (ratio=6.591e-01)
# Epoch 161/250 [  64.4%]
#   Elapsed: 0:04:27 | Remaining: ~0:02:27 | ETA: 04:03:23
#   Epoch time: 2.04s | Avg: 1.66s
#   Total: 4.6440e+00 | Data(6dot): 4.5559e+00
#   Misfit(RMS χ²): 8.762 | Rough: 8.60e+00 | Lam: 0.0102404
#   OT-distance(6D, view-only): 4.555902e-01
#   GradNorms: |g_d|=1.089e-03 | |λ·g_m|=6.883e-04
#  [Auto-Lambda] Epoch 170: Adjusted 1.02e-02 -> 8.16e-03 (ratio=6.351e-01)
# Epoch 181/250 [  72.4%]
#   Elapsed: 0:05:00 | Remaining: ~0:01:54 | ETA: 04:03:22
#   Epoch time: 2.03s | Avg: 1.66s
#   Total: 4.5932e+00 | Data(6dot): 4.5004e+00
#   Misfit(RMS χ²): 8.762 | Rough: 1.14e+01 | Lam: 0.0081609
#   OT-distance(6D, view-only): 4.500420e-01
#   GradNorms: |g_d|=9.325e-04 | |λ·g_m|=6.461e-04
#  [Auto-Lambda] Epoch 190: Adjusted 8.16e-03 -> 6.66e-03 (ratio=6.658e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 6.66e-03 -> 5.31e-03 (ratio=6.355e-01)
# Epoch 201/250 [  80.4%]
#   Elapsed: 0:05:33 | Remaining: ~0:01:21 | ETA: 04:03:21
#   Epoch time: 2.06s | Avg: 1.65s
#   Total: 4.5446e+00 | Data(6dot): 4.4759e+00
#   Misfit(RMS χ²): 8.752 | Rough: 1.30e+01 | Lam: 0.0053083
#   OT-distance(6D, view-only): 4.475869e-01
#   GradNorms: |g_d|=7.243e-04 | |λ·g_m|=4.539e-04
#  [Auto-Lambda] Epoch 220: Adjusted 5.31e-03 -> 4.41e-03 (ratio=6.897e-01)
# Epoch 221/250 [  88.4%]
#   Elapsed: 0:06:05 | Remaining: ~0:00:47 | ETA: 04:03:20
#   Epoch time: 1.96s | Avg: 1.65s
#   Total: 4.5234e+00 | Data(6dot): 4.4604e+00
#   Misfit(RMS χ²): 8.743 | Rough: 1.43e+01 | Lam: 0.0044085
#   OT-distance(6D, view-only): 4.460367e-01
#   GradNorms: |g_d|=7.862e-04 | |λ·g_m|=4.018e-04
#  [Auto-Lambda] Epoch 230: Adjusted 4.41e-03 -> 3.57e-03 (ratio=6.547e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 3.57e-03 -> 3.06e-03 (ratio=7.358e-01)
# Epoch 241/250 [  96.4%]
#   Elapsed: 0:06:37 | Remaining: ~0:00:14 | ETA: 04:03:20
#   Epoch time: 2.05s | Avg: 1.65s
#   Total: 4.4964e+00 | Data(6dot): 4.4485e+00
#   Misfit(RMS χ²): 8.734 | Rough: 1.57e+01 | Lam: 0.0030599
#   OT-distance(6D, view-only): 4.448463e-01
#   GradNorms: |g_d|=5.088e-04 | |λ·g_m|=2.979e-04
# Epoch 250/250 [ 100.0%]
#   Elapsed: 0:06:52 | Remaining: ~0:00:00 | ETA: 04:03:19
#   Epoch time: 2.04s | Avg: 1.64s
#   Total: 4.4937e+00 | Data(6dot): 4.4436e+00
#   Misfit(RMS χ²): 8.731 | Rough: 1.64e+01 | Lam: 0.0030599
#   OT-distance(6D, view-only): 4.443558e-01
#   GradNorms: |g_d|=4.354e-04 | |λ·g_m|=3.085e-04
# Inversion completed.
# OT inversion done
# 1e-10 0.09161281824794851

# %%
# 5a) OT 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.2052

# %%
# 6a) 保存 OT 结果
ot_run_dir = logger.save_from_inverter(inv, run_name=ot_run_name)
history_ot = list(inv.loss_history)
print(f"OT run saved: {ot_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d1/2026-07-25_04-03-34_ot1_shift_0.1
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.2052
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d1/2026-07-25_04-03-34_ot1_shift_0.1/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d1/2026-07-25_04-03-34_ot1_shift_0.1/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d1/2026-07-25_04-03-34_ot1_shift_0.1
#   Final RMS χ²: 8.7305
#   RMSE: 0.1750
#   MAPE: 6.94%
# ============================================================
#
# OT run saved: test_results/ccmm2d1/2026-07-25_04-03-34_ot1_shift_0.1

# %%
# 4b) MSE 反演（共用 OT 的 obs_data，仅重置初模与损失尺度）
inv_mse = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    data_loss_scale=30,
)
inv_mse.set_forward_operator()
inv_mse.sig_true = sig_true
inv_mse.load_obs_data(shared_obs_snapshot, noise_floor=shared_shift_meta["noise_level"])
for key, val in shared_shift_meta.items():
    if isinstance(val, dict):
        setattr(inv_mse, key, {k: (v.clone() if torch.is_tensor(v) else v) for k, v in val.items()})
    elif torch.is_tensor(val):
        setattr(inv_mse, key, val.clone())
    else:
        setattr(inv_mse, key, val)

inv_mse.initialize_model(initial_sigma=0.01)
inv_mse.plot_initial_model(clip_to_stations=True, ylim=[50, 0], synthetic_figwidth_scale=2.0)

final_sigma_mse = inv_mse.run_inversion(
    n_epochs=400,
    mode="mse",
    progress_interval=20,
    current_lambda=0.1,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
inv = inv_mse  # 供后续 MSE 绘图/导出使用
print("MSE inversion done")
print(final_sigma_mse.min().item(), final_sigma_mse.max().item())
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.844943e+01
# ✓ Observed data loaded from file
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/400 [   0.2%]
#   Elapsed: 0:00:01 | Remaining: ~0:08:55 | ETA: 04:12:58
#   Epoch time: 1.34s | Avg: 1.34s
#   Total: 9.8764e-01 | Data(mse): 9.8764e-01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 10.605 | Rough: 0.00e+00 | Lam: 0.1000000
#   OT-distance(6D, view-only): 1.513147e+00
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e-01 -> 2.52e-02 (ratio=6.375e-02)
#  [Auto-Lambda] Epoch 20: Adjusted 2.52e-02 -> 1.07e-02 (ratio=1.796e-01)
# Epoch 21/400 [   5.2%]
#   Elapsed: 0:00:33 | Remaining: ~0:10:01 | ETA: 04:14:36
#   Epoch time: 1.97s | Avg: 1.59s
#   Total: 7.3174e-01 | Data(mse): 7.1979e-01
#   Misfit(RMS χ²): 9.054 | Rough: 1.12e+00 | Lam: 0.0106989
#   OT-distance(6D, view-only): 5.891132e-01
#   GradNorms: |g_d|=1.418e-03 | |λ·g_m|=1.286e-03
#  [Auto-Lambda] Epoch 30: Adjusted 1.07e-02 -> 8.92e-03 (ratio=6.944e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 8.92e-03 -> 6.10e-03 (ratio=4.688e-01)
# Epoch 41/400 [  10.2%]
#   Elapsed: 0:01:05 | Remaining: ~0:09:33 | ETA: 04:14:40
#   Epoch time: 1.93s | Avg: 1.60s
#   Total: 7.0264e-01 | Data(mse): 6.9329e-01
#   Misfit(RMS χ²): 8.885 | Rough: 1.53e+00 | Lam: 0.0061045
#   OT-distance(6D, view-only): 5.291059e-01
#   GradNorms: |g_d|=4.936e-04 | |λ·g_m|=3.557e-04
#  [Auto-Lambda] Epoch 50: Adjusted 6.10e-03 -> 4.81e-03 (ratio=6.212e-01)
# Epoch 61/400 [  15.2%]
#   Elapsed: 0:01:37 | Remaining: ~0:09:02 | ETA: 04:14:42
#   Epoch time: 1.95s | Avg: 1.60s
#   Total: 6.8829e-01 | Data(mse): 6.7821e-01
#   Misfit(RMS χ²): 8.788 | Rough: 2.10e+00 | Lam: 0.0048112
#   OT-distance(6D, view-only): 5.152693e-01
#   GradNorms: |g_d|=4.021e-04 | |λ·g_m|=2.156e-04
# Epoch 81/400 [  20.2%]
#   Elapsed: 0:02:10 | Remaining: ~0:08:34 | ETA: 04:14:46
#   Epoch time: 2.00s | Avg: 1.61s
#   Total: 6.8004e-01 | Data(mse): 6.6688e-01
#   Misfit(RMS χ²): 8.715 | Rough: 2.74e+00 | Lam: 0.0048112
#   OT-distance(6D, view-only): 5.209213e-01
#   GradNorms: |g_d|=3.509e-04 | |λ·g_m|=1.809e-04
#  [Auto-Lambda] Epoch 90: Adjusted 4.81e-03 -> 4.37e-03 (ratio=8.238e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 4.37e-03 -> 3.90e-03 (ratio=7.973e-01)
# Epoch 101/400 [  25.2%]
#   Elapsed: 0:02:42 | Remaining: ~0:08:01 | ETA: 04:14:46
#   Epoch time: 2.10s | Avg: 1.61s
#   Total: 6.7199e-01 | Data(mse): 6.5914e-01
#   Misfit(RMS χ²): 8.664 | Rough: 3.30e+00 | Lam: 0.0038992
#   OT-distance(6D, view-only): 5.363688e-01
#   GradNorms: |g_d|=2.698e-04 | |λ·g_m|=1.513e-04
#  [Auto-Lambda] Epoch 110: Adjusted 3.90e-03 -> 3.48e-03 (ratio=7.942e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 3.48e-03 -> 3.07e-03 (ratio=7.808e-01)
# Epoch 121/400 [  30.2%]
#   Elapsed: 0:03:15 | Remaining: ~0:07:30 | ETA: 04:14:47
#   Epoch time: 2.01s | Avg: 1.61s
#   Total: 6.6524e-01 | Data(mse): 6.5312e-01
#   Misfit(RMS χ²): 8.624 | Rough: 3.95e+00 | Lam: 0.0030706
#   OT-distance(6D, view-only): 5.475448e-01
#   GradNorms: |g_d|=2.278e-04 | |λ·g_m|=1.298e-04
#  [Auto-Lambda] Epoch 130: Adjusted 3.07e-03 -> 2.71e-03 (ratio=7.767e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 2.71e-03 -> 2.38e-03 (ratio=7.756e-01)
# Epoch 141/400 [  35.2%]
#   Elapsed: 0:03:47 | Remaining: ~0:06:57 | ETA: 04:14:47
#   Epoch time: 1.95s | Avg: 1.61s
#   Total: 6.5949e-01 | Data(mse): 6.4840e-01
#   Misfit(RMS χ²): 8.593 | Rough: 4.65e+00 | Lam: 0.0023832
#   OT-distance(6D, view-only): 5.575639e-01
#   GradNorms: |g_d|=1.918e-04 | |λ·g_m|=1.095e-04
#  [Auto-Lambda] Epoch 150: Adjusted 2.38e-03 -> 2.10e-03 (ratio=7.771e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 2.10e-03 -> 1.86e-03 (ratio=7.840e-01)
# Epoch 161/400 [  40.2%]
#   Elapsed: 0:04:19 | Remaining: ~0:06:25 | ETA: 04:14:47
#   Epoch time: 1.94s | Avg: 1.61s
#   Total: 6.5465e-01 | Data(mse): 6.4456e-01
#   Misfit(RMS χ²): 8.567 | Rough: 5.42e+00 | Lam: 0.0018603
#   OT-distance(6D, view-only): 5.685771e-01
#   GradNorms: |g_d|=1.644e-04 | |λ·g_m|=9.273e-05
#  [Auto-Lambda] Epoch 170: Adjusted 1.86e-03 -> 1.66e-03 (ratio=7.923e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 1.66e-03 -> 1.48e-03 (ratio=8.002e-01)
# Epoch 181/400 [  45.2%]
#   Elapsed: 0:04:52 | Remaining: ~0:05:53 | ETA: 04:14:47
#   Epoch time: 1.96s | Avg: 1.61s
#   Total: 6.5052e-01 | Data(mse): 6.4119e-01
#   Misfit(RMS χ²): 8.545 | Rough: 6.30e+00 | Lam: 0.0014812
#   OT-distance(6D, view-only): 5.790843e-01
#   GradNorms: |g_d|=1.435e-04 | |λ·g_m|=8.044e-05
#  [Auto-Lambda] Epoch 190: Adjusted 1.48e-03 -> 1.33e-03 (ratio=8.057e-01)
# Epoch 201/400 [  50.2%]
#   Elapsed: 0:05:24 | Remaining: ~0:05:21 | ETA: 04:14:48
#   Epoch time: 1.98s | Avg: 1.62s
#   Total: 6.4774e-01 | Data(mse): 6.3799e-01
#   Misfit(RMS χ²): 8.524 | Rough: 7.33e+00 | Lam: 0.0013295
#   OT-distance(6D, view-only): 5.887170e-01
#   GradNorms: |g_d|=1.612e-04 | |λ·g_m|=7.935e-05
#  [Auto-Lambda] Epoch 210: Adjusted 1.33e-03 -> 1.18e-03 (ratio=7.926e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 1.18e-03 -> 1.07e-03 (ratio=8.129e-01)
# Epoch 221/400 [  55.2%]
#   Elapsed: 0:05:57 | Remaining: ~0:04:49 | ETA: 04:14:49
#   Epoch time: 2.15s | Avg: 1.62s
#   Total: 6.4390e-01 | Data(mse): 6.3487e-01
#   Misfit(RMS χ²): 8.503 | Rough: 8.47e+00 | Lam: 0.0010671
#   OT-distance(6D, view-only): 5.970552e-01
#   GradNorms: |g_d|=1.221e-04 | |λ·g_m|=6.986e-05
#  [Auto-Lambda] Epoch 230: Adjusted 1.07e-03 -> 9.63e-04 (ratio=8.144e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 9.63e-04 -> 8.84e-04 (ratio=8.434e-01)
# Epoch 241/400 [  60.2%]
#   Elapsed: 0:06:30 | Remaining: ~0:04:17 | ETA: 04:14:49
#   Epoch time: 1.99s | Avg: 1.62s
#   Total: 6.4000e-01 | Data(mse): 6.3117e-01
#   Misfit(RMS χ²): 8.478 | Rough: 9.99e+00 | Lam: 0.0008844
#   OT-distance(6D, view-only): 6.071524e-01
#   GradNorms: |g_d|=1.185e-04 | |λ·g_m|=6.494e-05
#  [Auto-Lambda] Epoch 250: Adjusted 8.84e-04 -> 8.23e-04 (ratio=8.661e-01)
#  [Auto-Lambda] Epoch 260: Adjusted 8.23e-04 -> 7.81e-04 (ratio=8.996e-01)
# Epoch 261/400 [  65.2%]
#   Elapsed: 0:07:03 | Remaining: ~0:03:45 | ETA: 04:14:50
#   Epoch time: 1.99s | Avg: 1.62s
#   Total: 6.3572e-01 | Data(mse): 6.2636e-01
#   Misfit(RMS χ²): 8.446 | Rough: 1.20e+01 | Lam: 0.0007807
#   OT-distance(6D, view-only): 6.230988e-01
#   GradNorms: |g_d|=1.220e-04 | |λ·g_m|=6.452e-05
# Epoch 281/400 [  70.2%]
#   Elapsed: 0:07:35 | Remaining: ~0:03:12 | ETA: 04:14:50
#   Epoch time: 2.06s | Avg: 1.62s
#   Total: 6.3085e-01 | Data(mse): 6.1965e-01
#   Misfit(RMS χ²): 8.400 | Rough: 1.43e+01 | Lam: 0.0007807
#   OT-distance(6D, view-only): 6.522659e-01
#   GradNorms: |g_d|=1.402e-04 | |λ·g_m|=7.147e-05
# Epoch 301/400 [  75.2%]
#   Elapsed: 0:08:08 | Remaining: ~0:02:40 | ETA: 04:14:51
#   Epoch time: 2.09s | Avg: 1.62s
#   Total: 6.2132e-01 | Data(mse): 6.0844e-01
#   Misfit(RMS χ²): 8.324 | Rough: 1.65e+01 | Lam: 0.0007807
#   OT-distance(6D, view-only): 7.289683e-01
#   GradNorms: |g_d|=1.879e-04 | |λ·g_m|=7.639e-05
# Epoch 321/400 [  80.2%]
#   Elapsed: 0:08:41 | Remaining: ~0:02:08 | ETA: 04:14:51
#   Epoch time: 2.06s | Avg: 1.63s
#   Total: 6.1105e-01 | Data(mse): 5.9748e-01
#   Misfit(RMS χ²): 8.249 | Rough: 1.74e+01 | Lam: 0.0007807
#   OT-distance(6D, view-only): 9.183691e-01
#   GradNorms: |g_d|=1.913e-04 | |λ·g_m|=7.665e-05
#  [Auto-Lambda] Epoch 330: Adjusted 7.81e-04 -> 7.35e-04 (ratio=8.854e-01)
#  [Auto-Lambda] Epoch 340: Adjusted 7.35e-04 -> 6.54e-04 (ratio=7.938e-01)
# Epoch 341/400 [  85.2%]
#   Elapsed: 0:09:14 | Remaining: ~0:01:35 | ETA: 04:14:52
#   Epoch time: 2.05s | Avg: 1.63s
#   Total: 6.0518e-01 | Data(mse): 5.9291e-01
#   Misfit(RMS χ²): 8.217 | Rough: 1.87e+01 | Lam: 0.0006545
#   OT-distance(6D, view-only): 9.055829e-01
#   GradNorms: |g_d|=1.238e-04 | |λ·g_m|=6.787e-05
#  [Auto-Lambda] Epoch 350: Adjusted 6.54e-04 -> 5.69e-04 (ratio=7.564e-01)
#  [Auto-Lambda] Epoch 360: Adjusted 5.69e-04 -> 5.08e-04 (ratio=7.965e-01)
# Epoch 361/400 [  90.2%]
#   Elapsed: 0:09:47 | Remaining: ~0:01:03 | ETA: 04:14:52
#   Epoch time: 1.97s | Avg: 1.63s
#   Total: 6.0022e-01 | Data(mse): 5.8951e-01
#   Misfit(RMS χ²): 8.193 | Rough: 2.11e+01 | Lam: 0.0005080
#   OT-distance(6D, view-only): 9.131251e-01
#   GradNorms: |g_d|=1.010e-04 | |λ·g_m|=5.755e-05
#  [Auto-Lambda] Epoch 370: Adjusted 5.08e-04 -> 4.60e-04 (ratio=8.200e-01)
#  [Auto-Lambda] Epoch 380: Adjusted 4.60e-04 -> 4.21e-04 (ratio=8.388e-01)
# Epoch 381/400 [  95.2%]
#   Elapsed: 0:10:18 | Remaining: ~0:00:30 | ETA: 04:14:50
#   Epoch time: 1.90s | Avg: 1.62s
#   Total: 5.9628e-01 | Data(mse): 5.8616e-01
#   Misfit(RMS χ²): 8.170 | Rough: 2.40e+01 | Lam: 0.0004213
#   OT-distance(6D, view-only): 9.232945e-01
#   GradNorms: |g_d|=9.492e-05 | |λ·g_m|=5.209e-05
# Epoch 400/400 [ 100.0%]
#   Elapsed: 0:10:46 | Remaining: ~0:00:00 | ETA: 04:14:48
#   Epoch time: 1.86s | Avg: 1.62s
#   Total: 5.9449e-01 | Data(mse): 5.8308e-01
#   Misfit(RMS χ²): 8.149 | Rough: 2.71e+01 | Lam: 0.0004213
#   OT-distance(6D, view-only): 9.315696e-01
#   GradNorms: |g_d|=1.439e-04 | |λ·g_m|=5.575e-05
# Inversion completed.
# MSE inversion done
# 1e-10 0.550373444004214

# %%
# 5b) MSE 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.1208

# %%
# 6b) 保存 MSE 结果
mse_run_dir = logger.save_from_inverter(inv, run_name=mse_run_name)
history_mse = list(inv.loss_history)
print(f"MSE run saved: {mse_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d1/2026-07-25_04-15-02_mse1_shift_0.1
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.1208
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d1/2026-07-25_04-15-02_mse1_shift_0.1/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d1/2026-07-25_04-15-02_mse1_shift_0.1/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d1/2026-07-25_04-15-02_mse1_shift_0.1
#   Final RMS χ²: 8.1486
#   RMSE: 0.2767
#   MAPE: 10.85%
# ============================================================
#
# MSE run saved: test_results/ccmm2d1/2026-07-25_04-15-02_mse1_shift_0.1

# %%
# 7) OT vs MSE 对比（收敛曲线 + 视电阻率四线合一 + 伪断面）
plot_ot_mse_convergence(history_ot, history_mse, target_misfit=1.05)

plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=[8,9],
    mode="xy",
)
plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=[8,9],
    mode="yx",
)

plot_ot_mse_pseudosection_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    mode="xy",
)
# Out:
# /home/liuxr/论文绘图/src/mt2d_inv/plotting/pseudosection.py:176: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# {'inversion_axes': array([<Axes: title={'center': 'True'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#         <Axes: title={'center': 'OT inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#         <Axes: title={'center': 'MSE inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>],
#        dtype=object),
#  'observed_axes': <Axes: xlabel='Distance (km)', ylabel='Period (s)'>}
