# %% [markdown]
# # COMMEMI 2D-4：随机静位移（TE/TM 相同模式） OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d4` 生成标准模型。
# **随机选取部分台站**，在 xy/yx（TE/TM）上施加**随机 log10 静位移**（`static_shift_std=0.15`）。
# 合成观测只生成一次，OT 与 MSE **共用同一套 `obs_data`**。
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演并对比。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d4",
    output_root=Path("test_results"),
)
ot_run_name = "ot4_shift_0.15"
mse_run_name = "mse4_shift_0.15"

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/论文绘图

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d4(
    nza=10,
    device=device, 
)

# 2) Survey setup
freqs = torch.logspace(0, -3.5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data（OT/MSE 共用，只生成一次）
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=20000,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(
    noise_level=0.01,
    noise_type="gaussian",
    static_shift_std=0.15,   # 对数域标准差 σ：每台站独立抽取 s~N(0,σ²)，乘子 10^s
    shift_modes=("xy", "yx"),
    shift_stations="random",
    shift_ratio=0.15,
)

# 保存 OT/MSE 共用观测快照
shared_obs_snapshot = {
    "obs_data": {k: v.clone() for k, v in inv.obs_data.items()},
    "data_std": {k: v.clone() if torch.is_tensor(v) else v for k, v in inv.data_std.items()},
}
shared_shift_meta = {
    "shift_mask": inv.shift_mask.clone(),
    "shift_station_ids": list(inv.shift_station_ids),
    "n_shift_stations": inv.n_shift_stations,
    "shift_fraction_actual": inv.shift_fraction_actual,
    "static_shift_std": inv.static_shift_std,
    "shift_ratio": inv.shift_ratio,
    "shift_modes": inv.shift_modes,
    "shift_stations": inv.shift_stations,
    "static_shift_log": {k: v.clone() for k, v in inv.static_shift_log.items()},
    "static_shift_factors": {k: v.clone() for k, v in inv.static_shift_factors.items()},
    "true_data_no_shift": {k: v.clone() for k, v in inv.true_data_no_shift.items()},
    "noise_level": inv.noise_level,
}
print(f"随机静位移受影响台站: {inv.shift_station_ids}")

inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0], synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.844405e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 1.0% (gaussian)
# 随机静位移受影响台站: [8, 15, 17]
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4a) OT 反演 (6dot)
inv.initialize_model(initial_sigma=0.01)
final_sigma_ot = inv.run_inversion(
    n_epochs=300,
    mode="6dot",
    progress_interval=20,
    current_lambda=3,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("OT inversion done")
print(final_sigma_ot.min().item(), final_sigma_ot.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:02 | Remaining: ~0:07:14 | ETA: 12:56:29
#   Epoch time: 1.45s | Avg: 1.45s
#   Total: 1.3670e+03 | Data(6dot): 1.3670e+03
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 60.936 | Rough: 0.00e+00 | Lam: 3.0000000
#   OT-distance(6D, view-only): 6.835060e+01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:33 | Remaining: ~0:07:17 | ETA: 12:57:03
#   Epoch time: 1.97s | Avg: 1.57s
#   Total: 5.5021e+02 | Data(6dot): 5.3154e+02
#   Misfit(RMS χ²): 45.124 | Rough: 6.22e+00 | Lam: 3.0000000
#   OT-distance(6D, view-only): 2.657722e+01
#   GradNorms: |g_d|=1.201e+00 | |λ·g_m|=3.010e-01
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:05 | Remaining: ~0:06:47 | ETA: 12:57:05
#   Epoch time: 1.98s | Avg: 1.57s
#   Total: 2.1730e+02 | Data(6dot): 1.8032e+02
#   Misfit(RMS χ²): 33.506 | Rough: 1.23e+01 | Lam: 3.0000000
#   OT-distance(6D, view-only): 9.016005e+00
#   GradNorms: |g_d|=4.857e-01 | |λ·g_m|=2.093e-01
#  [Auto-Lambda] Epoch 50: Adjusted 3.00e+00 -> 2.77e+00 (ratio=8.507e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 2.77e+00 -> 1.94e+00 (ratio=4.935e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:37 | Remaining: ~0:06:17 | ETA: 12:57:07
#   Epoch time: 2.07s | Avg: 1.58s
#   Total: 8.7144e+01 | Data(6dot): 6.1296e+01
#   Misfit(RMS χ²): 20.912 | Rough: 1.33e+01 | Lam: 1.9437538
#   OT-distance(6D, view-only): 3.064812e+00
#   GradNorms: |g_d|=1.890e-01 | |λ·g_m|=1.506e-01
#  [Auto-Lambda] Epoch 70: Adjusted 1.94e+00 -> 1.30e+00 (ratio=4.440e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 1.30e+00 -> 8.87e-01 (ratio=4.694e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:08 | Remaining: ~0:05:46 | ETA: 12:57:07
#   Epoch time: 1.97s | Avg: 1.58s
#   Total: 3.8517e+01 | Data(6dot): 2.5674e+01
#   Misfit(RMS χ²): 13.355 | Rough: 1.45e+01 | Lam: 0.8873652
#   OT-distance(6D, view-only): 1.283692e+00
#   GradNorms: |g_d|=6.293e-02 | |λ·g_m|=4.875e-02
#  [Auto-Lambda] Epoch 90: Adjusted 8.87e-01 -> 6.50e-01 (ratio=5.366e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 6.50e-01 -> 4.91e-01 (ratio=5.709e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:02:40 | Remaining: ~0:05:15 | ETA: 12:57:08
#   Epoch time: 1.99s | Avg: 1.58s
#   Total: 2.2153e+01 | Data(6dot): 1.4162e+01
#   Misfit(RMS χ²): 10.596 | Rough: 1.63e+01 | Lam: 0.4911749
#   OT-distance(6D, view-only): 7.081216e-01
#   GradNorms: |g_d|=4.209e-02 | |λ·g_m|=2.722e-02
#  [Auto-Lambda] Epoch 110: Adjusted 4.91e-01 -> 3.51e-01 (ratio=5.115e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 3.51e-01 -> 2.44e-01 (ratio=4.828e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:11 | Remaining: ~0:04:42 | ETA: 12:57:07
#   Epoch time: 1.95s | Avg: 1.58s
#   Total: 1.5601e+01 | Data(6dot): 1.1024e+01
#   Misfit(RMS χ²): 9.538 | Rough: 1.88e+01 | Lam: 0.2440983
#   OT-distance(6D, view-only): 5.511793e-01
#   GradNorms: |g_d|=1.697e-02 | |λ·g_m|=1.269e-02
#  [Auto-Lambda] Epoch 130: Adjusted 2.44e-01 -> 1.78e-01 (ratio=5.317e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.78e-01 -> 1.40e-01 (ratio=6.157e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:03:43 | Remaining: ~0:04:11 | ETA: 12:57:07
#   Epoch time: 2.04s | Avg: 1.58s
#   Total: 1.3313e+01 | Data(6dot): 1.0487e+01
#   Misfit(RMS χ²): 9.351 | Rough: 2.02e+01 | Lam: 0.1396704
#   OT-distance(6D, view-only): 5.243511e-01
#   GradNorms: |g_d|=1.185e-02 | |λ·g_m|=7.385e-03
#  [Auto-Lambda] Epoch 150: Adjusted 1.40e-01 -> 1.24e-01 (ratio=7.901e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 1.24e-01 -> 1.06e-01 (ratio=7.243e-01)
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:15 | Remaining: ~0:03:39 | ETA: 12:57:07
#   Epoch time: 1.97s | Avg: 1.58s
#   Total: 1.2504e+01 | Data(6dot): 1.0263e+01
#   Misfit(RMS χ²): 9.221 | Rough: 2.12e+01 | Lam: 0.1056543
#   OT-distance(6D, view-only): 5.131633e-01
#   GradNorms: |g_d|=8.355e-03 | |λ·g_m|=5.798e-03
#  [Auto-Lambda] Epoch 180: Adjusted 1.06e-01 -> 9.53e-02 (ratio=8.142e-01)
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:04:47 | Remaining: ~0:03:08 | ETA: 12:57:07
#   Epoch time: 1.92s | Avg: 1.58s
#   Total: 1.2235e+01 | Data(6dot): 1.0159e+01
#   Misfit(RMS χ²): 9.176 | Rough: 2.18e+01 | Lam: 0.0953335
#   OT-distance(6D, view-only): 5.079379e-01
#   GradNorms: |g_d|=1.292e-02 | |λ·g_m|=5.278e-03
#  [Auto-Lambda] Epoch 200: Adjusted 9.53e-02 -> 7.83e-02 (ratio=6.752e-01)
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:05:18 | Remaining: ~0:02:36 | ETA: 12:57:07
#   Epoch time: 1.94s | Avg: 1.58s
#   Total: 1.1831e+01 | Data(6dot): 1.0091e+01
#   Misfit(RMS χ²): 9.148 | Rough: 2.22e+01 | Lam: 0.0783338
#   OT-distance(6D, view-only): 5.045366e-01
#   GradNorms: |g_d|=9.006e-03 | |λ·g_m|=4.396e-03
#  [Auto-Lambda] Epoch 210: Adjusted 7.83e-02 -> 6.87e-02 (ratio=7.683e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 6.87e-02 -> 5.05e-02 (ratio=5.408e-01)
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:05:50 | Remaining: ~0:02:04 | ETA: 12:57:08
#   Epoch time: 1.98s | Avg: 1.58s
#   Total: 1.1167e+01 | Data(6dot): 1.0004e+01
#   Misfit(RMS χ²): 9.104 | Rough: 2.30e+01 | Lam: 0.0504927
#   OT-distance(6D, view-only): 5.002032e-01
#   GradNorms: |g_d|=4.420e-03 | |λ·g_m|=2.979e-03
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:06:22 | Remaining: ~0:01:33 | ETA: 12:57:08
#   Epoch time: 1.99s | Avg: 1.58s
#   Total: 1.1135e+01 | Data(6dot): 9.9135e+00
#   Misfit(RMS χ²): 9.060 | Rough: 2.42e+01 | Lam: 0.0504927
#   OT-distance(6D, view-only): 4.956764e-01
#   GradNorms: |g_d|=1.840e-02 | |λ·g_m|=3.171e-03
#  [Auto-Lambda] Epoch 260: Adjusted 5.05e-02 -> 4.12e-02 (ratio=6.651e-01)
# Epoch 261/300 [  87.0%]
#   Elapsed: 0:06:54 | Remaining: ~0:01:01 | ETA: 12:57:08
#   Epoch time: 1.98s | Avg: 1.58s
#   Total: 1.0883e+01 | Data(6dot): 9.8623e+00
#   Misfit(RMS χ²): 9.046 | Rough: 2.48e+01 | Lam: 0.0411788
#   OT-distance(6D, view-only): 4.931156e-01
#   GradNorms: |g_d|=5.646e-03 | |λ·g_m|=2.613e-03
#  [Auto-Lambda] Epoch 270: Adjusted 4.12e-02 -> 3.28e-02 (ratio=6.333e-01)
# Epoch 281/300 [  93.7%]
#   Elapsed: 0:07:26 | Remaining: ~0:00:30 | ETA: 12:57:09
#   Epoch time: 1.95s | Avg: 1.59s
#   Total: 1.0646e+01 | Data(6dot): 9.7969e+00
#   Misfit(RMS χ²): 9.013 | Rough: 2.59e+01 | Lam: 0.0327692
#   OT-distance(6D, view-only): 4.898457e-01
#   GradNorms: |g_d|=8.297e-03 | |λ·g_m|=2.239e-03
# Epoch 300/300 [ 100.0%]
#   Elapsed: 0:07:56 | Remaining: ~0:00:00 | ETA: 12:57:08
#   Epoch time: 1.97s | Avg: 1.58s
#   Total: 1.0627e+01 | Data(6dot): 9.7443e+00
#   Misfit(RMS χ²): 8.997 | Rough: 2.69e+01 | Lam: 0.0327692
#   OT-distance(6D, view-only): 4.872128e-01
#   GradNorms: |g_d|=1.380e-02 | |λ·g_m|=2.319e-03
# Inversion completed.
# OT inversion done
# 1e-10 0.11877800929280334

# %%
# 5a) OT 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.3558

# %%
# 6a) 保存 OT 结果
ot_run_dir = logger.save_from_inverter(inv, run_name=ot_run_name)
history_ot = list(inv.loss_history)
print(f"OT run saved: {ot_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d4/2026-07-28_12-57-23_ot4_shift_0.15
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.3558
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d4/2026-07-28_12-57-23_ot4_shift_0.15/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d4/2026-07-28_12-57-23_ot4_shift_0.15/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d4/2026-07-28_12-57-23_ot4_shift_0.15
#   Final RMS χ²: 8.9974
#   RMSE: 0.4391
#   MAPE: 12.69%
# ============================================================
#
# OT run saved: test_results/ccmm2d4/2026-07-28_12-57-23_ot4_shift_0.15

# %%
# 4b) MSE 反演（共用 OT 的 obs_data，仅重置初模与损失尺度）
inv_mse = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    data_loss_scale=500,
)
inv_mse.set_forward_operator()
inv_mse.sig_true = sig_true
inv_mse.load_obs_data(shared_obs_snapshot, noise_floor=shared_shift_meta["noise_level"])
for key, val in shared_shift_meta.items():
    if isinstance(val, dict):
        setattr(inv_mse, key, {k: (v.clone() if torch.is_tensor(v) else v) for k, v in val.items()})
    elif torch.is_tensor(val):
        setattr(inv_mse, key, val.clone())
    else:
        setattr(inv_mse, key, val)

inv_mse.initialize_model(initial_sigma=0.01)
inv_mse.plot_initial_model(clip_to_stations=True, ylim=[50, 0], synthetic_figwidth_scale=2.0)

final_sigma_mse = inv_mse.run_inversion(
    n_epochs=400,
    mode="mse",
    progress_interval=20,
    current_lambda=1,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
inv = inv_mse
print("MSE inversion done")
print(final_sigma_mse.min().item(), final_sigma_mse.max().item())
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.844405e+01
# ✓ Observed data loaded from file
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/400 [   0.2%]
#   Elapsed: 0:00:01 | Remaining: ~0:08:47 | ETA: 13:06:40
#   Epoch time: 1.32s | Avg: 1.32s
#   Total: 5.4355e+02 | Data(mse): 5.4355e+02
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 60.936 | Rough: 0.00e+00 | Lam: 1.0000000
#   OT-distance(6D, view-only): 6.835060e+01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
# Epoch 21/400 [   5.2%]
#   Elapsed: 0:00:31 | Remaining: ~0:09:35 | ETA: 13:07:58
#   Epoch time: 1.94s | Avg: 1.52s
#   Total: 2.3065e+02 | Data(mse): 2.2583e+02
#   Misfit(RMS χ²): 39.278 | Rough: 4.82e+00 | Lam: 1.0000000
#   OT-distance(6D, view-only): 3.896037e+01
#   GradNorms: |g_d|=7.231e-01 | |λ·g_m|=1.098e-01
# Epoch 41/400 [  10.2%]
#   Elapsed: 0:01:03 | Remaining: ~0:09:14 | ETA: 13:08:09
#   Epoch time: 1.89s | Avg: 1.55s
#   Total: 9.6969e+01 | Data(mse): 8.8385e+01
#   Misfit(RMS χ²): 24.572 | Rough: 8.58e+00 | Lam: 1.0000000
#   OT-distance(6D, view-only): 1.975351e+01
#   GradNorms: |g_d|=4.175e-01 | |λ·g_m|=6.794e-02
#  [Auto-Lambda] Epoch 60: Adjusted 1.00e+00 -> 8.74e-01 (ratio=7.633e-01)
# Epoch 61/400 [  15.2%]
#   Elapsed: 0:01:33 | Remaining: ~0:08:42 | ETA: 13:08:07
#   Epoch time: 1.87s | Avg: 1.54s
#   Total: 4.3169e+01 | Data(mse): 3.5040e+01
#   Misfit(RMS χ²): 15.472 | Rough: 9.30e+00 | Lam: 0.8736906
#   OT-distance(6D, view-only): 8.995015e+00
#   GradNorms: |g_d|=1.140e-01 | |λ·g_m|=8.027e-02
#  [Auto-Lambda] Epoch 70: Adjusted 8.74e-01 -> 6.32e-01 (ratio=5.239e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 6.32e-01 -> 4.95e-01 (ratio=6.120e-01)
# Epoch 81/400 [  20.2%]
#   Elapsed: 0:02:04 | Remaining: ~0:08:10 | ETA: 13:08:06
#   Epoch time: 1.88s | Avg: 1.54s
#   Total: 2.4624e+01 | Data(mse): 1.9370e+01
#   Misfit(RMS χ²): 11.503 | Rough: 1.06e+01 | Lam: 0.4946871
#   OT-distance(6D, view-only): 3.949006e+00
#   GradNorms: |g_d|=5.207e-02 | |λ·g_m|=3.635e-02
#  [Auto-Lambda] Epoch 90: Adjusted 4.95e-01 -> 4.55e-01 (ratio=8.473e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 4.55e-01 -> 3.40e-01 (ratio=5.590e-01)
# Epoch 101/400 [  25.2%]
#   Elapsed: 0:02:35 | Remaining: ~0:07:39 | ETA: 13:08:06
#   Epoch time: 1.93s | Avg: 1.54s
#   Total: 1.8448e+01 | Data(mse): 1.4345e+01
#   Misfit(RMS χ²): 9.899 | Rough: 1.21e+01 | Lam: 0.3404531
#   OT-distance(6D, view-only): 2.143275e+00
#   GradNorms: |g_d|=3.326e-02 | |λ·g_m|=2.257e-02
#  [Auto-Lambda] Epoch 110: Adjusted 3.40e-01 -> 2.55e-01 (ratio=5.623e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 2.55e-01 -> 1.80e-01 (ratio=4.979e-01)
# Epoch 121/400 [  30.2%]
#   Elapsed: 0:03:06 | Remaining: ~0:07:09 | ETA: 13:08:06
#   Epoch time: 1.91s | Avg: 1.54s
#   Total: 1.5161e+01 | Data(mse): 1.2489e+01
#   Misfit(RMS χ²): 9.237 | Rough: 1.48e+01 | Lam: 0.1801426
#   OT-distance(6D, view-only): 1.464992e+00
#   GradNorms: |g_d|=1.537e-02 | |λ·g_m|=1.074e-02
#  [Auto-Lambda] Epoch 130: Adjusted 1.80e-01 -> 1.41e-01 (ratio=6.093e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.41e-01 -> 1.11e-01 (ratio=6.274e-01)
# Epoch 141/400 [  35.2%]
#   Elapsed: 0:03:39 | Remaining: ~0:06:42 | ETA: 13:08:13
#   Epoch time: 2.15s | Avg: 1.55s
#   Total: 1.3603e+01 | Data(mse): 1.1559e+01
#   Misfit(RMS χ²): 8.886 | Rough: 1.84e+01 | Lam: 0.1113771
#   OT-distance(6D, view-only): 1.120062e+00
#   GradNorms: |g_d|=1.150e-02 | |λ·g_m|=7.160e-03
#  [Auto-Lambda] Epoch 150: Adjusted 1.11e-01 -> 8.79e-02 (ratio=6.226e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 8.79e-02 -> 7.99e-02 (ratio=8.269e-01)
# Epoch 161/400 [  40.2%]
#   Elapsed: 0:04:10 | Remaining: ~0:06:11 | ETA: 13:08:13
#   Epoch time: 1.90s | Avg: 1.56s
#   Total: 1.2751e+01 | Data(mse): 1.0997e+01
#   Misfit(RMS χ²): 8.668 | Rough: 2.20e+01 | Lam: 0.0799150
#   OT-distance(6D, view-only): 9.755470e-01
#   GradNorms: |g_d|=1.104e-02 | |λ·g_m|=5.836e-03
#  [Auto-Lambda] Epoch 170: Adjusted 7.99e-02 -> 6.89e-02 (ratio=7.429e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 6.89e-02 -> 5.69e-02 (ratio=6.818e-01)
# Epoch 181/400 [  45.2%]
#   Elapsed: 0:04:41 | Remaining: ~0:05:40 | ETA: 13:08:13
#   Epoch time: 1.87s | Avg: 1.55s
#   Total: 1.2065e+01 | Data(mse): 1.0642e+01
#   Misfit(RMS χ²): 8.526 | Rough: 2.50e+01 | Lam: 0.0568761
#   OT-distance(6D, view-only): 9.272681e-01
#   GradNorms: |g_d|=6.838e-03 | |λ·g_m|=4.563e-03
#  [Auto-Lambda] Epoch 190: Adjusted 5.69e-02 -> 4.56e-02 (ratio=6.428e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 4.56e-02 -> 4.26e-02 (ratio=8.733e-01)
# Epoch 201/400 [  50.2%]
#   Elapsed: 0:05:11 | Remaining: ~0:05:08 | ETA: 13:08:12
#   Epoch time: 1.89s | Avg: 1.55s
#   Total: 1.1536e+01 | Data(mse): 1.0292e+01
#   Misfit(RMS χ²): 8.385 | Rough: 2.92e+01 | Lam: 0.0426154
#   OT-distance(6D, view-only): 9.104840e-01
#   GradNorms: |g_d|=8.208e-03 | |λ·g_m|=3.945e-03
# Epoch 221/400 [  55.2%]
#   Elapsed: 0:05:42 | Remaining: ~0:04:37 | ETA: 13:08:11
#   Epoch time: 1.92s | Avg: 1.55s
#   Total: 1.0969e+01 | Data(mse): 9.5300e+00
#   Misfit(RMS χ²): 8.069 | Rough: 3.38e+01 | Lam: 0.0426154
#   OT-distance(6D, view-only): 9.298919e-01
#   GradNorms: |g_d|=1.182e-02 | |λ·g_m|=4.519e-03
#  [Auto-Lambda] Epoch 240: Adjusted 4.26e-02 -> 3.56e-02 (ratio=6.976e-01)
# Epoch 241/400 [  60.2%]
#   Elapsed: 0:06:13 | Remaining: ~0:04:06 | ETA: 13:08:10
#   Epoch time: 1.89s | Avg: 1.55s
#   Total: 9.9431e+00 | Data(mse): 8.7427e+00
#   Misfit(RMS χ²): 7.728 | Rough: 3.37e+01 | Lam: 0.0355939
#   OT-distance(6D, view-only): 1.012445e+00
#   GradNorms: |g_d|=6.164e-03 | |λ·g_m|=3.624e-03
#  [Auto-Lambda] Epoch 260: Adjusted 3.56e-02 -> 3.15e-02 (ratio=7.827e-01)
# Epoch 261/400 [  65.2%]
#   Elapsed: 0:06:44 | Remaining: ~0:03:35 | ETA: 13:08:10
#   Epoch time: 1.88s | Avg: 1.55s
#   Total: 9.6908e+00 | Data(mse): 8.5677e+00
#   Misfit(RMS χ²): 7.650 | Rough: 3.57e+01 | Lam: 0.0314893
#   OT-distance(6D, view-only): 9.920071e-01
#   GradNorms: |g_d|=5.276e-03 | |λ·g_m|=3.338e-03
#  [Auto-Lambda] Epoch 270: Adjusted 3.15e-02 -> 2.58e-02 (ratio=6.687e-01)
#  [Auto-Lambda] Epoch 280: Adjusted 2.58e-02 -> 2.18e-02 (ratio=7.184e-01)
# Epoch 281/400 [  70.2%]
#   Elapsed: 0:07:14 | Remaining: ~0:03:04 | ETA: 13:08:10
#   Epoch time: 1.90s | Avg: 1.55s
#   Total: 9.2289e+00 | Data(mse): 8.3702e+00
#   Misfit(RMS χ²): 7.562 | Rough: 3.93e+01 | Lam: 0.0218257
#   OT-distance(6D, view-only): 1.004119e+00
#   GradNorms: |g_d|=4.766e-03 | |λ·g_m|=2.599e-03
# Epoch 301/400 [  75.2%]
#   Elapsed: 0:07:45 | Remaining: ~0:02:33 | ETA: 13:08:10
#   Epoch time: 1.90s | Avg: 1.55s
#   Total: 9.1511e+00 | Data(mse): 8.1850e+00
#   Misfit(RMS χ²): 7.478 | Rough: 4.43e+01 | Lam: 0.0218257
#   OT-distance(6D, view-only): 1.018027e+00
#   GradNorms: |g_d|=1.104e-02 | |λ·g_m|=2.948e-03
#  [Auto-Lambda] Epoch 320: Adjusted 2.18e-02 -> 2.03e-02 (ratio=8.652e-01)
# Epoch 321/400 [  80.2%]
#   Elapsed: 0:08:16 | Remaining: ~0:02:02 | ETA: 13:08:10
#   Epoch time: 1.97s | Avg: 1.55s
#   Total: 9.0422e+00 | Data(mse): 8.1006e+00
#   Misfit(RMS χ²): 7.439 | Rough: 4.64e+01 | Lam: 0.0203016
#   OT-distance(6D, view-only): 1.022045e+00
#   GradNorms: |g_d|=5.912e-03 | |λ·g_m|=2.819e-03
#  [Auto-Lambda] Epoch 330: Adjusted 2.03e-02 -> 1.69e-02 (ratio=6.897e-01)
#  [Auto-Lambda] Epoch 340: Adjusted 1.69e-02 -> 1.43e-02 (ratio=7.150e-01)
# Epoch 341/400 [  85.2%]
#   Elapsed: 0:08:48 | Remaining: ~0:01:31 | ETA: 13:08:11
#   Epoch time: 2.18s | Avg: 1.55s
#   Total: 8.7232e+00 | Data(mse): 8.0283e+00
#   Misfit(RMS χ²): 7.406 | Rough: 4.87e+01 | Lam: 0.0142560
#   OT-distance(6D, view-only): 1.026673e+00
#   GradNorms: |g_d|=3.995e-03 | |λ·g_m|=2.075e-03
#  [Auto-Lambda] Epoch 350: Adjusted 1.43e-02 -> 1.19e-02 (ratio=7.011e-01)
# Epoch 361/400 [  90.2%]
#   Elapsed: 0:09:21 | Remaining: ~0:01:00 | ETA: 13:08:13
#   Epoch time: 1.90s | Avg: 1.55s
#   Total: 8.5662e+00 | Data(mse): 7.9326e+00
#   Misfit(RMS χ²): 7.361 | Rough: 5.31e+01 | Lam: 0.0119365
#   OT-distance(6D, view-only): 1.039925e+00
#   GradNorms: |g_d|=4.289e-03 | |λ·g_m|=1.912e-03
# Epoch 381/400 [  95.2%]
#   Elapsed: 0:09:52 | Remaining: ~0:00:29 | ETA: 13:08:13
#   Epoch time: 1.89s | Avg: 1.55s
#   Total: 8.5396e+00 | Data(mse): 7.8677e+00
#   Misfit(RMS χ²): 7.331 | Rough: 5.63e+01 | Lam: 0.0119365
#   OT-distance(6D, view-only): 1.049393e+00
#   GradNorms: |g_d|=7.349e-03 | |λ·g_m|=2.005e-03
# Epoch 400/400 [ 100.0%]
#   Elapsed: 0:10:20 | Remaining: ~0:00:00 | ETA: 13:08:12
#   Epoch time: 1.88s | Avg: 1.55s
#   Total: 8.5230e+00 | Data(mse): 7.8326e+00
#   Misfit(RMS χ²): 7.315 | Rough: 5.78e+01 | Lam: 0.0119365
#   OT-distance(6D, view-only): 1.053099e+00
#   GradNorms: |g_d|=5.033e-03 | |λ·g_m|=2.026e-03
# Inversion completed.
# MSE inversion done
# 1e-10 1.4197447202304796

# %%
# 5b) MSE 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.2701

# %%
# 6b) 保存 MSE 结果
mse_run_dir = logger.save_from_inverter(inv, run_name=mse_run_name)
history_mse = list(inv.loss_history)
print(f"MSE run saved: {mse_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d4/2026-07-28_13-08-27_mse4_shift_0.15
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.2701
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d4/2026-07-28_13-08-27_mse4_shift_0.15/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d4/2026-07-28_13-08-27_mse4_shift_0.15/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d4/2026-07-28_13-08-27_mse4_shift_0.15
#   Final RMS χ²: 7.3149
#   RMSE: 0.5490
#   MAPE: 18.91%
# ============================================================
#
# MSE run saved: test_results/ccmm2d4/2026-07-28_13-08-27_mse4_shift_0.15

# %%
# 7) OT vs MSE 对比（收敛曲线 + 视电阻率四线合一 + 伪断面）
plot_ot_mse_convergence(history_ot, history_mse, target_misfit=1.05)

plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=[8,9],
    mode="xy",
)
plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=[8,9],
    mode="yx",
)

plot_ot_mse_pseudosection_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    mode="xy",
)
# Out:
# /home/liuxr/论文绘图/src/mt2d_inv/plotting/pseudosection.py:145: UserWarning: Glyph 8336 (\N{LATIN SUBSCRIPT SMALL LETTER A}) missing from font(s) STIXGeneral.
#   ax.figure.tight_layout()
# /home/liuxr/.conda/envs/torch/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8336 (\N{LATIN SUBSCRIPT SMALL LETTER A}) missing from font(s) STIXGeneral.
#   fig.canvas.print_figure(bytes_io, **kw)
# {'inversion_axes': array([<Axes: title={'center': 'True'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#         <Axes: title={'center': 'OT inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#         <Axes: title={'center': 'MSE inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>],
#        dtype=object),
#  'observed_axes': <Axes: xlabel='Distance (km)', ylabel='Period (s)'>}
