# %% [markdown]
# # COMMEMI 2D-1：随机静位移（TE/TM 相同模式） OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d1` 生成标准模型。
# **随机选取部分台站**，在 xy/yx（TE/TM）上施加**随机 log10 静位移**（`static_shift_std=0.15`）。
# 合成观测只生成一次，OT 与 MSE **共用同一套 `obs_data`**。
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演并对比。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d1",
    output_root=Path("test_results"),
)
ot_run_name = "ot1_shift_0.15"
mse_run_name = "mse1_shift_0.15"

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/论文绘图

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d1(
    zn=None,
    yn=None,
    nza=10,
    device=device,
    rho_host=100.0,
    rho_block=10.0,
    y_half_width_m=2000.0,
    z_top_m=10000.0,
    z_bottom_m=30000.0,
)

# 2) Survey setup
freqs = torch.logspace(0, -3.5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data（OT/MSE 共用，只生成一次）
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=10000,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(
    noise_level=0.01,
    noise_type="gaussian",
    static_shift_std=0.15,   # 对数域标准差 σ：每台站独立抽取 s~N(0,σ²)，乘子 10^s
    shift_modes=("xy", "yx"),
    shift_stations="random",
    shift_ratio=0.15,
)

# 保存 OT/MSE 共用观测快照
shared_obs_snapshot = {
    "obs_data": {k: v.clone() for k, v in inv.obs_data.items()},
    "data_std": {k: v.clone() if torch.is_tensor(v) else v for k, v in inv.data_std.items()},
}
shared_shift_meta = {
    "shift_mask": inv.shift_mask.clone(),
    "shift_station_ids": list(inv.shift_station_ids),
    "n_shift_stations": inv.n_shift_stations,
    "shift_fraction_actual": inv.shift_fraction_actual,
    "static_shift_std": inv.static_shift_std,
    "shift_ratio": inv.shift_ratio,
    "shift_modes": inv.shift_modes,
    "shift_stations": inv.shift_stations,
    "static_shift_log": {k: v.clone() for k, v in inv.static_shift_log.items()},
    "static_shift_factors": {k: v.clone() for k, v in inv.static_shift_factors.items()},
    "true_data_no_shift": {k: v.clone() for k, v in inv.true_data_no_shift.items()},
    "noise_level": inv.noise_level,
}
print(f"随机静位移受影响台站: {inv.shift_station_ids}")

inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0], synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.844943e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 1.0% (gaussian)
# 随机静位移受影响台站: [8, 15, 17]
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4a) OT 反演 (6dot)
inv.initialize_model(initial_sigma=0.01)
final_sigma_ot = inv.run_inversion(
    n_epochs=200,
    mode="6dot",
    progress_interval=20,
    current_lambda=1,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("OT inversion done")
print(final_sigma_ot.min().item(), final_sigma_ot.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/200 [   0.5%]
#   Elapsed: 0:00:02 | Remaining: ~0:04:51 | ETA: 04:01:26
#   Epoch time: 1.46s | Avg: 1.46s
#   Total: 1.5514e+01 | Data(6dot): 1.5514e+01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 10.983 | Rough: 0.00e+00 | Lam: 1.0000000
#   OT-distance(6D, view-only): 1.551431e+00
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e+00 -> 5.20e-01 (ratio=2.701e-01)
#  [Auto-Lambda] Epoch 20: Adjusted 5.20e-01 -> 2.82e-01 (ratio=2.937e-01)
# Epoch 21/200 [  10.5%]
#   Elapsed: 0:00:35 | Remaining: ~0:04:54 | ETA: 04:02:03
#   Epoch time: 2.05s | Avg: 1.65s
#   Total: 6.1858e+00 | Data(6dot): 5.9054e+00
#   Misfit(RMS χ²): 9.664 | Rough: 9.96e-01 | Lam: 0.2816966
#   OT-distance(6D, view-only): 5.905366e-01
#   GradNorms: |g_d|=1.886e-02 | |λ·g_m|=1.979e-02
#  [Auto-Lambda] Epoch 30: Adjusted 2.82e-01 -> 1.75e-01 (ratio=3.840e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 1.75e-01 -> 1.20e-01 (ratio=4.752e-01)
# Epoch 41/200 [  20.5%]
#   Elapsed: 0:01:08 | Remaining: ~0:04:22 | ETA: 04:02:03
#   Epoch time: 2.12s | Avg: 1.65s
#   Total: 5.6300e+00 | Data(6dot): 5.4348e+00
#   Misfit(RMS χ²): 9.451 | Rough: 1.62e+00 | Lam: 0.1203372
#   OT-distance(6D, view-only): 5.434760e-01
#   GradNorms: |g_d|=5.584e-03 | |λ·g_m|=4.722e-03
#  [Auto-Lambda] Epoch 50: Adjusted 1.20e-01 -> 9.38e-02 (ratio=6.077e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 9.38e-02 -> 7.02e-02 (ratio=5.601e-01)
# Epoch 61/200 [  30.5%]
#   Elapsed: 0:01:42 | Remaining: ~0:03:50 | ETA: 04:02:05
#   Epoch time: 2.05s | Avg: 1.66s
#   Total: 5.4686e+00 | Data(6dot): 5.3206e+00
#   Misfit(RMS χ²): 9.380 | Rough: 2.11e+00 | Lam: 0.0702094
#   OT-distance(6D, view-only): 5.320564e-01
#   GradNorms: |g_d|=3.239e-03 | |λ·g_m|=2.245e-03
#  [Auto-Lambda] Epoch 70: Adjusted 7.02e-02 -> 5.33e-02 (ratio=5.768e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 5.33e-02 -> 4.19e-02 (ratio=6.174e-01)
# Epoch 81/200 [  40.5%]
#   Elapsed: 0:02:14 | Remaining: ~0:03:16 | ETA: 04:02:04
#   Epoch time: 2.05s | Avg: 1.65s
#   Total: 5.3672e+00 | Data(6dot): 5.2486e+00
#   Misfit(RMS χ²): 9.342 | Rough: 2.83e+00 | Lam: 0.0419003
#   OT-distance(6D, view-only): 5.248586e-01
#   GradNorms: |g_d|=2.515e-03 | |λ·g_m|=1.534e-03
#  [Auto-Lambda] Epoch 90: Adjusted 4.19e-02 -> 3.26e-02 (ratio=6.054e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 3.26e-02 -> 2.57e-02 (ratio=6.230e-01)
# Epoch 101/200 [  50.5%]
#   Elapsed: 0:02:48 | Remaining: ~0:02:44 | ETA: 04:02:05
#   Epoch time: 2.09s | Avg: 1.66s
#   Total: 5.2863e+00 | Data(6dot): 5.1858e+00
#   Misfit(RMS χ²): 9.314 | Rough: 3.90e+00 | Lam: 0.0257335
#   OT-distance(6D, view-only): 5.185808e-01
#   GradNorms: |g_d|=1.744e-03 | |λ·g_m|=1.127e-03
#  [Auto-Lambda] Epoch 110: Adjusted 2.57e-02 -> 2.04e-02 (ratio=6.288e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 2.04e-02 -> 1.64e-02 (ratio=6.441e-01)
# Epoch 121/200 [  60.5%]
#   Elapsed: 0:03:21 | Remaining: ~0:02:11 | ETA: 04:02:06
#   Epoch time: 2.03s | Avg: 1.66s
#   Total: 5.2057e+00 | Data(6dot): 5.1135e+00
#   Misfit(RMS χ²): 9.298 | Rough: 5.63e+00 | Lam: 0.0163772
#   OT-distance(6D, view-only): 5.113515e-01
#   GradNorms: |g_d|=1.353e-03 | |λ·g_m|=8.654e-04
#  [Auto-Lambda] Epoch 130: Adjusted 1.64e-02 -> 1.33e-02 (ratio=6.592e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.33e-02 -> 1.08e-02 (ratio=6.571e-01)
# Epoch 141/200 [  70.5%]
#   Elapsed: 0:03:55 | Remaining: ~0:01:38 | ETA: 04:02:06
#   Epoch time: 2.05s | Avg: 1.67s
#   Total: 5.1245e+00 | Data(6dot): 5.0362e+00
#   Misfit(RMS χ²): 9.303 | Rough: 8.19e+00 | Lam: 0.0107791
#   OT-distance(6D, view-only): 5.036233e-01
#   GradNorms: |g_d|=1.094e-03 | |λ·g_m|=6.911e-04
#  [Auto-Lambda] Epoch 150: Adjusted 1.08e-02 -> 8.65e-03 (ratio=6.441e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 8.65e-03 -> 6.91e-03 (ratio=6.376e-01)
# Epoch 161/200 [  80.5%]
#   Elapsed: 0:04:28 | Remaining: ~0:01:04 | ETA: 04:02:05
#   Epoch time: 2.01s | Avg: 1.66s
#   Total: 5.0598e+00 | Data(6dot): 4.9857e+00
#   Misfit(RMS χ²): 9.314 | Rough: 1.07e+01 | Lam: 0.0069075
#   OT-distance(6D, view-only): 4.985683e-01
#   GradNorms: |g_d|=8.086e-04 | |λ·g_m|=5.194e-04
#  [Auto-Lambda] Epoch 170: Adjusted 6.91e-03 -> 6.51e-03 (ratio=8.871e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 6.51e-03 -> 6.03e-03 (ratio=8.587e-01)
# Epoch 181/200 [  90.5%]
#   Elapsed: 0:05:01 | Remaining: ~0:00:31 | ETA: 04:02:05
#   Epoch time: 2.05s | Avg: 1.66s
#   Total: 5.0376e+00 | Data(6dot): 4.9622e+00
#   Misfit(RMS χ²): 9.315 | Rough: 1.25e+01 | Lam: 0.0060289
#   OT-distance(6D, view-only): 4.962222e-01
#   GradNorms: |g_d|=8.893e-04 | |λ·g_m|=5.012e-04
#  [Auto-Lambda] Epoch 190: Adjusted 6.03e-03 -> 4.65e-03 (ratio=5.951e-01)
# Epoch 200/200 [ 100.0%]
#   Elapsed: 0:05:32 | Remaining: ~0:00:00 | ETA: 04:02:04
#   Epoch time: 2.10s | Avg: 1.66s
#   Total: 5.0141e+00 | Data(6dot): 4.9511e+00
#   Misfit(RMS χ²): 9.313 | Rough: 1.35e+01 | Lam: 0.0046507
#   OT-distance(6D, view-only): 4.951138e-01
#   GradNorms: |g_d|=5.708e-04 | |λ·g_m|=4.068e-04
# Inversion completed.
# OT inversion done
# 1e-10 0.08512145307728956

# %%
# 5a) OT 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.2110

# %%
# 6a) 保存 OT 结果
ot_run_dir = logger.save_from_inverter(inv, run_name=ot_run_name)
history_ot = list(inv.loss_history)
print(f"OT run saved: {ot_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d1/2026-07-25_04-02-18_ot1_shift_0.15
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.2110
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d1/2026-07-25_04-02-18_ot1_shift_0.15/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d1/2026-07-25_04-02-18_ot1_shift_0.15/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d1/2026-07-25_04-02-18_ot1_shift_0.15
#   Final RMS χ²: 9.3127
#   RMSE: 0.1642
#   MAPE: 6.35%
# ============================================================
#
# OT run saved: test_results/ccmm2d1/2026-07-25_04-02-18_ot1_shift_0.15

# %%
# 4b) MSE 反演（共用 OT 的 obs_data，仅重置初模与损失尺度）
inv_mse = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    data_loss_scale=30,
)
inv_mse.set_forward_operator()
inv_mse.sig_true = sig_true
inv_mse.load_obs_data(shared_obs_snapshot, noise_floor=shared_shift_meta["noise_level"])
for key, val in shared_shift_meta.items():
    if isinstance(val, dict):
        setattr(inv_mse, key, {k: (v.clone() if torch.is_tensor(v) else v) for k, v in val.items()})
    elif torch.is_tensor(val):
        setattr(inv_mse, key, val.clone())
    else:
        setattr(inv_mse, key, val)

inv_mse.initialize_model(initial_sigma=0.01)
inv_mse.plot_initial_model(clip_to_stations=True, ylim=[50, 0], synthetic_figwidth_scale=2.0)

final_sigma_mse = inv_mse.run_inversion(
    n_epochs=400,
    mode="mse",
    progress_interval=20,
    current_lambda=0.1,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
inv = inv_mse  # 供后续 MSE 绘图/导出使用
print("MSE inversion done")
print(final_sigma_mse.min().item(), final_sigma_mse.max().item())
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.844943e+01
# ✓ Observed data loaded from file
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/400 [   0.2%]
#   Elapsed: 0:00:01 | Remaining: ~0:09:06 | ETA: 04:11:53
#   Epoch time: 1.37s | Avg: 1.37s
#   Total: 1.0592e+00 | Data(mse): 1.0592e+00
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 10.983 | Rough: 0.00e+00 | Lam: 0.1000000
#   OT-distance(6D, view-only): 1.551431e+00
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e-01 -> 2.65e-02 (ratio=7.048e-02)
#  [Auto-Lambda] Epoch 20: Adjusted 2.65e-02 -> 1.38e-02 (ratio=2.690e-01)
# Epoch 21/400 [   5.2%]
#   Elapsed: 0:00:33 | Remaining: ~0:09:58 | ETA: 04:13:18
#   Epoch time: 1.94s | Avg: 1.58s
#   Total: 8.1890e-01 | Data(mse): 8.0620e-01
#   Misfit(RMS χ²): 9.582 | Rough: 9.22e-01 | Lam: 0.0137691
#   OT-distance(6D, view-only): 6.489431e-01
#   GradNorms: |g_d|=1.673e-03 | |λ·g_m|=1.649e-03
#  [Auto-Lambda] Epoch 30: Adjusted 1.38e-02 -> 1.15e-02 (ratio=7.029e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 1.15e-02 -> 8.29e-03 (ratio=5.155e-01)
# Epoch 41/400 [  10.2%]
#   Elapsed: 0:01:03 | Remaining: ~0:09:15 | ETA: 04:13:04
#   Epoch time: 1.90s | Avg: 1.55s
#   Total: 7.9333e-01 | Data(mse): 7.8452e-01
#   Misfit(RMS χ²): 9.452 | Rough: 1.06e+00 | Lam: 0.0082889
#   OT-distance(6D, view-only): 5.934632e-01
#   GradNorms: |g_d|=6.316e-04 | |λ·g_m|=4.182e-04
#  [Auto-Lambda] Epoch 50: Adjusted 8.29e-03 -> 6.10e-03 (ratio=5.410e-01)
# Epoch 61/400 [  15.2%]
#   Elapsed: 0:01:35 | Remaining: ~0:08:52 | ETA: 04:13:14
#   Epoch time: 2.66s | Avg: 1.57s
#   Total: 7.8078e-01 | Data(mse): 7.7222e-01
#   Misfit(RMS χ²): 9.378 | Rough: 1.40e+00 | Lam: 0.0060968
#   OT-distance(6D, view-only): 5.761580e-01
#   GradNorms: |g_d|=3.949e-04 | |λ·g_m|=2.502e-04
# Epoch 81/400 [  20.2%]
#   Elapsed: 0:02:08 | Remaining: ~0:08:24 | ETA: 04:13:18
#   Epoch time: 1.96s | Avg: 1.58s
#   Total: 7.7274e-01 | Data(mse): 7.6139e-01
#   Misfit(RMS χ²): 9.312 | Rough: 1.86e+00 | Lam: 0.0060968
#   OT-distance(6D, view-only): 5.713900e-01
#   GradNorms: |g_d|=4.011e-04 | |λ·g_m|=1.867e-04
#  [Auto-Lambda] Epoch 100: Adjusted 6.10e-03 -> 5.60e-03 (ratio=8.433e-01)
# Epoch 101/400 [  25.2%]
#   Elapsed: 0:02:40 | Remaining: ~0:07:54 | ETA: 04:13:20
#   Epoch time: 1.97s | Avg: 1.59s
#   Total: 7.6511e-01 | Data(mse): 7.5194e-01
#   Misfit(RMS χ²): 9.254 | Rough: 2.35e+00 | Lam: 0.0055989
#   OT-distance(6D, view-only): 5.774916e-01
#   GradNorms: |g_d|=3.283e-04 | |λ·g_m|=1.769e-04
#  [Auto-Lambda] Epoch 110: Adjusted 5.60e-03 -> 5.04e-03 (ratio=8.119e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 5.04e-03 -> 4.47e-03 (ratio=7.862e-01)
# Epoch 121/400 [  30.2%]
#   Elapsed: 0:03:12 | Remaining: ~0:07:24 | ETA: 04:13:22
#   Epoch time: 1.99s | Avg: 1.59s
#   Total: 7.5682e-01 | Data(mse): 7.4335e-01
#   Misfit(RMS χ²): 9.201 | Rough: 3.01e+00 | Lam: 0.0044732
#   OT-distance(6D, view-only): 5.914659e-01
#   GradNorms: |g_d|=2.770e-04 | |λ·g_m|=1.585e-04
#  [Auto-Lambda] Epoch 130: Adjusted 4.47e-03 -> 3.90e-03 (ratio=7.586e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 3.90e-03 -> 3.35e-03 (ratio=7.378e-01)
# Epoch 141/400 [  35.2%]
#   Elapsed: 0:03:45 | Remaining: ~0:06:53 | ETA: 04:13:24
#   Epoch time: 1.96s | Avg: 1.60s
#   Total: 7.4915e-01 | Data(mse): 7.3649e-01
#   Misfit(RMS χ²): 9.158 | Rough: 3.78e+00 | Lam: 0.0033466
#   OT-distance(6D, view-only): 6.114843e-01
#   GradNorms: |g_d|=2.276e-04 | |λ·g_m|=1.336e-04
#  [Auto-Lambda] Epoch 150: Adjusted 3.35e-03 -> 2.87e-03 (ratio=7.359e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 2.87e-03 -> 2.48e-03 (ratio=7.452e-01)
# Epoch 161/400 [  40.2%]
#   Elapsed: 0:04:16 | Remaining: ~0:06:21 | ETA: 04:13:23
#   Epoch time: 2.03s | Avg: 1.60s
#   Total: 7.4269e-01 | Data(mse): 7.3131e-01
#   Misfit(RMS χ²): 9.126 | Rough: 4.59e+00 | Lam: 0.0024782
#   OT-distance(6D, view-only): 6.272966e-01
#   GradNorms: |g_d|=1.900e-04 | |λ·g_m|=1.100e-04
#  [Auto-Lambda] Epoch 170: Adjusted 2.48e-03 -> 2.15e-03 (ratio=7.559e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 2.15e-03 -> 1.88e-03 (ratio=7.627e-01)
# Epoch 181/400 [  45.2%]
#   Elapsed: 0:04:48 | Remaining: ~0:05:49 | ETA: 04:13:24
#   Epoch time: 2.02s | Avg: 1.60s
#   Total: 7.3743e-01 | Data(mse): 7.2720e-01
#   Misfit(RMS χ²): 9.100 | Rough: 5.44e+00 | Lam: 0.0018817
#   OT-distance(6D, view-only): 6.421799e-01
#   GradNorms: |g_d|=1.594e-04 | |λ·g_m|=9.149e-05
#  [Auto-Lambda] Epoch 190: Adjusted 1.88e-03 -> 1.65e-03 (ratio=7.654e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 1.65e-03 -> 1.44e-03 (ratio=7.681e-01)
# Epoch 201/400 [  50.2%]
#   Elapsed: 0:05:21 | Remaining: ~0:05:18 | ETA: 04:13:25
#   Epoch time: 2.01s | Avg: 1.60s
#   Total: 7.3292e-01 | Data(mse): 7.2378e-01
#   Misfit(RMS χ²): 9.079 | Rough: 6.34e+00 | Lam: 0.0014428
#   OT-distance(6D, view-only): 6.579913e-01
#   GradNorms: |g_d|=1.325e-04 | |λ·g_m|=7.629e-05
#  [Auto-Lambda] Epoch 210: Adjusted 1.44e-03 -> 1.27e-03 (ratio=7.744e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 1.27e-03 -> 1.12e-03 (ratio=7.824e-01)
# Epoch 221/400 [  55.2%]
#   Elapsed: 0:05:53 | Remaining: ~0:04:46 | ETA: 04:13:25
#   Epoch time: 1.98s | Avg: 1.60s
#   Total: 7.2901e-01 | Data(mse): 7.2078e-01
#   Misfit(RMS χ²): 9.060 | Rough: 7.33e+00 | Lam: 0.0011230
#   OT-distance(6D, view-only): 6.755390e-01
#   GradNorms: |g_d|=1.131e-04 | |λ·g_m|=6.456e-05
#  [Auto-Lambda] Epoch 240: Adjusted 1.12e-03 -> 1.01e-03 (ratio=8.032e-01)
# Epoch 241/400 [  60.2%]
#   Elapsed: 0:06:26 | Remaining: ~0:04:14 | ETA: 04:13:26
#   Epoch time: 1.99s | Avg: 1.60s
#   Total: 7.2663e-01 | Data(mse): 7.1823e-01
#   Misfit(RMS χ²): 9.044 | Rough: 8.35e+00 | Lam: 0.0010065
#   OT-distance(6D, view-only): 6.950902e-01
#   GradNorms: |g_d|=1.222e-04 | |λ·g_m|=6.235e-05
#  [Auto-Lambda] Epoch 250: Adjusted 1.01e-03 -> 8.88e-04 (ratio=7.783e-01)
#  [Auto-Lambda] Epoch 260: Adjusted 8.88e-04 -> 7.82e-04 (ratio=7.757e-01)
# Epoch 261/400 [  65.2%]
#   Elapsed: 0:06:58 | Remaining: ~0:03:43 | ETA: 04:13:27
#   Epoch time: 2.07s | Avg: 1.60s
#   Total: 7.2347e-01 | Data(mse): 7.1618e-01
#   Misfit(RMS χ²): 9.031 | Rough: 9.32e+00 | Lam: 0.0007821
#   OT-distance(6D, view-only): 7.131220e-01
#   GradNorms: |g_d|=9.262e-05 | |λ·g_m|=5.180e-05
#  [Auto-Lambda] Epoch 270: Adjusted 7.82e-04 -> 7.04e-04 (ratio=8.099e-01)
#  [Auto-Lambda] Epoch 280: Adjusted 7.04e-04 -> 6.44e-04 (ratio=8.362e-01)
# Epoch 281/400 [  70.2%]
#   Elapsed: 0:07:31 | Remaining: ~0:03:11 | ETA: 04:13:28
#   Epoch time: 2.02s | Avg: 1.61s
#   Total: 7.2093e-01 | Data(mse): 7.1418e-01
#   Misfit(RMS χ²): 9.018 | Rough: 1.05e+01 | Lam: 0.0006436
#   OT-distance(6D, view-only): 7.264964e-01
#   GradNorms: |g_d|=8.346e-05 | |λ·g_m|=4.612e-05
#  [Auto-Lambda] Epoch 290: Adjusted 6.44e-04 -> 5.99e-04 (ratio=8.671e-01)
#  [Auto-Lambda] Epoch 300: Adjusted 5.99e-04 -> 5.67e-04 (ratio=8.951e-01)
# Epoch 301/400 [  75.2%]
#   Elapsed: 0:08:04 | Remaining: ~0:02:39 | ETA: 04:13:29
#   Epoch time: 2.02s | Avg: 1.61s
#   Total: 7.1869e-01 | Data(mse): 7.1191e-01
#   Misfit(RMS χ²): 9.004 | Rough: 1.20e+01 | Lam: 0.0005670
#   OT-distance(6D, view-only): 7.335423e-01
#   GradNorms: |g_d|=8.381e-05 | |λ·g_m|=4.452e-05
#  [Auto-Lambda] Epoch 320: Adjusted 5.67e-04 -> 5.30e-04 (ratio=8.742e-01)
# Epoch 321/400 [  80.2%]
#   Elapsed: 0:08:37 | Remaining: ~0:02:07 | ETA: 04:13:30
#   Epoch time: 1.93s | Avg: 1.61s
#   Total: 7.1667e-01 | Data(mse): 7.0932e-01
#   Misfit(RMS χ²): 8.988 | Rough: 1.39e+01 | Lam: 0.0005301
#   OT-distance(6D, view-only): 7.389050e-01
#   GradNorms: |g_d|=8.604e-05 | |λ·g_m|=4.616e-05
#  [Auto-Lambda] Epoch 340: Adjusted 5.30e-04 -> 4.93e-04 (ratio=8.663e-01)
# Epoch 341/400 [  85.2%]
#   Elapsed: 0:09:09 | Remaining: ~0:01:34 | ETA: 04:13:30
#   Epoch time: 2.00s | Avg: 1.61s
#   Total: 7.1464e-01 | Data(mse): 7.0678e-01
#   Misfit(RMS χ²): 8.971 | Rough: 1.59e+01 | Lam: 0.0004934
#   OT-distance(6D, view-only): 7.422362e-01
#   GradNorms: |g_d|=8.765e-05 | |λ·g_m|=4.723e-05
#  [Auto-Lambda] Epoch 350: Adjusted 4.93e-04 -> 4.66e-04 (ratio=8.932e-01)
# Epoch 361/400 [  90.2%]
#   Elapsed: 0:09:42 | Remaining: ~0:01:02 | ETA: 04:13:31
#   Epoch time: 2.12s | Avg: 1.61s
#   Total: 7.1256e-01 | Data(mse): 7.0402e-01
#   Misfit(RMS χ²): 8.954 | Rough: 1.83e+01 | Lam: 0.0004663
#   OT-distance(6D, view-only): 7.446928e-01
#   GradNorms: |g_d|=9.934e-05 | |λ·g_m|=4.921e-05
# Epoch 381/400 [  95.2%]
#   Elapsed: 0:10:14 | Remaining: ~0:00:30 | ETA: 04:13:31
#   Epoch time: 2.02s | Avg: 1.61s
#   Total: 7.1076e-01 | Data(mse): 7.0091e-01
#   Misfit(RMS χ²): 8.934 | Rough: 2.11e+01 | Lam: 0.0004663
#   OT-distance(6D, view-only): 7.468747e-01
#   GradNorms: |g_d|=1.298e-04 | |λ·g_m|=5.463e-05
# Epoch 400/400 [ 100.0%]
#   Elapsed: 0:10:45 | Remaining: ~0:00:00 | ETA: 04:13:31
#   Epoch time: 2.00s | Avg: 1.61s
#   Total: 7.0870e-01 | Data(mse): 6.9746e-01
#   Misfit(RMS χ²): 8.912 | Rough: 2.41e+01 | Lam: 0.0004663
#   OT-distance(6D, view-only): 7.498491e-01
#   GradNorms: |g_d|=1.057e-04 | |λ·g_m|=6.090e-05
# Inversion completed.
# MSE inversion done
# 1e-10 0.17086014127605714

# %%
# 5b) MSE 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.1224

# %%
# 6b) 保存 MSE 结果
mse_run_dir = logger.save_from_inverter(inv, run_name=mse_run_name)
history_mse = list(inv.loss_history)
print(f"MSE run saved: {mse_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d1/2026-07-25_04-13-45_mse1_shift_0.15
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.1224
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d1/2026-07-25_04-13-45_mse1_shift_0.15/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d1/2026-07-25_04-13-45_mse1_shift_0.15/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d1/2026-07-25_04-13-45_mse1_shift_0.15
#   Final RMS χ²: 8.9121
#   RMSE: 0.2687
#   MAPE: 10.73%
# ============================================================
#
# MSE run saved: test_results/ccmm2d1/2026-07-25_04-13-45_mse1_shift_0.15

# %%
# 7) OT vs MSE 对比（收敛曲线 + 视电阻率四线合一 + 伪断面）
plot_ot_mse_convergence(history_ot, history_mse, target_misfit=1.05)

plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=[8,9],
    mode="xy",
)
plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=[8,9],
    mode="yx",
)

plot_ot_mse_pseudosection_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    mode="xy",
)
# Out:
# /home/liuxr/论文绘图/src/mt2d_inv/plotting/pseudosection.py:176: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# {'inversion_axes': array([<Axes: title={'center': 'True'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#         <Axes: title={'center': 'OT inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#         <Axes: title={'center': 'MSE inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>],
#        dtype=object),
#  'observed_axes': <Axes: xlabel='Distance (km)', ylabel='Period (s)'>}
