# %% [markdown]
# # COMMEMI 2D-4：随机静位移（TE/TM 相同模式） OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d4` 生成标准模型。
# **随机选取部分台站**，在 xy/yx（TE/TM）上施加**随机 log10 静位移**（`static_shift_std=0.15`）。
# 合成观测只生成一次，OT 与 MSE **共用同一套 `obs_data`**。
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演并对比。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d4",
    output_root=Path("test_results"),
)
ot_run_name = "ot4_shift_0.1"
mse_run_name = "mse4_shift_0.1"

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/论文绘图

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d4(
    nza=10,
    device=device, 
)

# 2) Survey setup
freqs = torch.logspace(0, -3.5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data（OT/MSE 共用，只生成一次）
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=20000,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(
    noise_level=0.01,
    noise_type="gaussian",
    static_shift_std=0.15,   # 对数域标准差 σ：每台站独立抽取 s~N(0,σ²)，乘子 10^s
    shift_modes=("xy", "yx"),
    shift_stations="random",
    shift_ratio=0.1,
)

# 保存 OT/MSE 共用观测快照
shared_obs_snapshot = {
    "obs_data": {k: v.clone() for k, v in inv.obs_data.items()},
    "data_std": {k: v.clone() if torch.is_tensor(v) else v for k, v in inv.data_std.items()},
}
shared_shift_meta = {
    "shift_mask": inv.shift_mask.clone(),
    "shift_station_ids": list(inv.shift_station_ids),
    "n_shift_stations": inv.n_shift_stations,
    "shift_fraction_actual": inv.shift_fraction_actual,
    "static_shift_std": inv.static_shift_std,
    "shift_ratio": inv.shift_ratio,
    "shift_modes": inv.shift_modes,
    "shift_stations": inv.shift_stations,
    "static_shift_log": {k: v.clone() for k, v in inv.static_shift_log.items()},
    "static_shift_factors": {k: v.clone() for k, v in inv.static_shift_factors.items()},
    "true_data_no_shift": {k: v.clone() for k, v in inv.true_data_no_shift.items()},
    "noise_level": inv.noise_level,
}
print(f"随机静位移受影响台站: {inv.shift_station_ids}")

inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0], synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.844405e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 1.0% (gaussian)
# 随机静位移受影响台站: [8, 17]
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4a) OT 反演 (6dot)
inv.initialize_model(initial_sigma=0.01)
final_sigma_ot = inv.run_inversion(
    n_epochs=300,
    mode="6dot",
    progress_interval=20,
    current_lambda=3,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("OT inversion done")
print(final_sigma_ot.min().item(), final_sigma_ot.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:02 | Remaining: ~0:07:06 | ETA: 12:56:02
#   Epoch time: 1.43s | Avg: 1.43s
#   Total: 1.3634e+03 | Data(6dot): 1.3634e+03
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 60.620 | Rough: 0.00e+00 | Lam: 3.0000000
#   OT-distance(6D, view-only): 6.817044e+01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:34 | Remaining: ~0:07:29 | ETA: 12:56:57
#   Epoch time: 2.04s | Avg: 1.61s
#   Total: 5.4709e+02 | Data(6dot): 5.2842e+02
#   Misfit(RMS χ²): 44.734 | Rough: 6.22e+00 | Lam: 3.0000000
#   OT-distance(6D, view-only): 2.642094e+01
#   GradNorms: |g_d|=1.197e+00 | |λ·g_m|=3.014e-01
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:07 | Remaining: ~0:06:58 | ETA: 12:56:59
#   Epoch time: 2.07s | Avg: 1.62s
#   Total: 2.1498e+02 | Data(6dot): 1.7801e+02
#   Misfit(RMS χ²): 33.148 | Rough: 1.23e+01 | Lam: 3.0000000
#   OT-distance(6D, view-only): 8.900468e+00
#   GradNorms: |g_d|=4.827e-01 | |λ·g_m|=2.060e-01
#  [Auto-Lambda] Epoch 50: Adjusted 3.00e+00 -> 2.75e+00 (ratio=8.390e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 2.75e+00 -> 1.91e+00 (ratio=4.806e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:40 | Remaining: ~0:06:28 | ETA: 12:57:02
#   Epoch time: 2.05s | Avg: 1.63s
#   Total: 8.5456e+01 | Data(6dot): 6.0130e+01
#   Misfit(RMS χ²): 20.637 | Rough: 1.33e+01 | Lam: 1.9050161
#   OT-distance(6D, view-only): 3.006499e+00
#   GradNorms: |g_d|=1.869e-01 | |λ·g_m|=1.524e-01
#  [Auto-Lambda] Epoch 70: Adjusted 1.91e+00 -> 1.25e+00 (ratio=4.311e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 1.25e+00 -> 8.67e-01 (ratio=4.805e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:12 | Remaining: ~0:05:57 | ETA: 12:57:03
#   Epoch time: 2.12s | Avg: 1.63s
#   Total: 3.7671e+01 | Data(6dot): 2.5048e+01
#   Misfit(RMS χ²): 13.143 | Rough: 1.46e+01 | Lam: 0.8669997
#   OT-distance(6D, view-only): 1.252423e+00
#   GradNorms: |g_d|=6.227e-02 | |λ·g_m|=4.801e-02
#  [Auto-Lambda] Epoch 90: Adjusted 8.67e-01 -> 6.51e-01 (ratio=5.643e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 6.51e-01 -> 4.96e-01 (ratio=5.805e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:02:45 | Remaining: ~0:05:24 | ETA: 12:57:04
#   Epoch time: 2.05s | Avg: 1.63s
#   Total: 2.1532e+01 | Data(6dot): 1.3428e+01
#   Misfit(RMS χ²): 10.267 | Rough: 1.63e+01 | Lam: 0.4962098
#   OT-distance(6D, view-only): 6.713947e-01
#   GradNorms: |g_d|=4.179e-02 | |λ·g_m|=2.752e-02
#  [Auto-Lambda] Epoch 110: Adjusted 4.96e-01 -> 3.53e-01 (ratio=5.073e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 3.53e-01 -> 2.48e-01 (ratio=4.919e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:18 | Remaining: ~0:04:52 | ETA: 12:57:04
#   Epoch time: 2.04s | Avg: 1.63s
#   Total: 1.5030e+01 | Data(6dot): 1.0363e+01
#   Misfit(RMS χ²): 9.169 | Rough: 1.88e+01 | Lam: 0.2478771
#   OT-distance(6D, view-only): 5.181647e-01
#   GradNorms: |g_d|=1.844e-02 | |λ·g_m|=1.288e-02
#  [Auto-Lambda] Epoch 130: Adjusted 2.48e-01 -> 1.72e-01 (ratio=4.832e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:03:51 | Remaining: ~0:04:20 | ETA: 12:57:05
#   Epoch time: 2.05s | Avg: 1.64s
#   Total: 1.3325e+01 | Data(6dot): 9.8102e+00
#   Misfit(RMS χ²): 8.979 | Rough: 2.04e+01 | Lam: 0.1723115
#   OT-distance(6D, view-only): 4.905088e-01
#   GradNorms: |g_d|=2.067e-02 | |λ·g_m|=9.267e-03
#  [Auto-Lambda] Epoch 150: Adjusted 1.72e-01 -> 1.57e-01 (ratio=8.309e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 1.57e-01 -> 1.25e-01 (ratio=6.322e-01)
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:24 | Remaining: ~0:03:47 | ETA: 12:57:06
#   Epoch time: 2.06s | Avg: 1.64s
#   Total: 1.2229e+01 | Data(6dot): 9.6100e+00
#   Misfit(RMS χ²): 8.838 | Rough: 2.10e+01 | Lam: 0.1248823
#   OT-distance(6D, view-only): 4.804977e-01
#   GradNorms: |g_d|=1.196e-02 | |λ·g_m|=6.729e-03
#  [Auto-Lambda] Epoch 170: Adjusted 1.25e-01 -> 9.86e-02 (ratio=6.240e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 9.86e-02 -> 7.50e-02 (ratio=5.787e-01)
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:04:57 | Remaining: ~0:03:15 | ETA: 12:57:07
#   Epoch time: 2.04s | Avg: 1.64s
#   Total: 1.1073e+01 | Data(6dot): 9.4251e+00
#   Misfit(RMS χ²): 8.740 | Rough: 2.20e+01 | Lam: 0.0750477
#   OT-distance(6D, view-only): 4.712572e-01
#   GradNorms: |g_d|=6.714e-03 | |λ·g_m|=4.252e-03
#  [Auto-Lambda] Epoch 190: Adjusted 7.50e-02 -> 6.27e-02 (ratio=6.974e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 6.27e-02 -> 4.94e-02 (ratio=6.217e-01)
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:05:30 | Remaining: ~0:02:42 | ETA: 12:57:07
#   Epoch time: 2.04s | Avg: 1.64s
#   Total: 1.0413e+01 | Data(6dot): 9.2615e+00
#   Misfit(RMS χ²): 8.658 | Rough: 2.33e+01 | Lam: 0.0494138
#   OT-distance(6D, view-only): 4.630748e-01
#   GradNorms: |g_d|=4.685e-03 | |λ·g_m|=3.005e-03
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:06:03 | Remaining: ~0:02:09 | ETA: 12:57:07
#   Epoch time: 2.06s | Avg: 1.64s
#   Total: 1.0359e+01 | Data(6dot): 9.1457e+00
#   Misfit(RMS χ²): 8.606 | Rough: 2.46e+01 | Lam: 0.0494138
#   OT-distance(6D, view-only): 4.572831e-01
#   GradNorms: |g_d|=1.939e-02 | |λ·g_m|=3.179e-03
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:06:37 | Remaining: ~0:01:37 | ETA: 12:57:08
#   Epoch time: 2.09s | Avg: 1.64s
#   Total: 1.0326e+01 | Data(6dot): 9.0785e+00
#   Misfit(RMS χ²): 8.584 | Rough: 2.52e+01 | Lam: 0.0494138
#   OT-distance(6D, view-only): 4.539263e-01
#   GradNorms: |g_d|=8.355e-03 | |λ·g_m|=3.203e-03
#  [Auto-Lambda] Epoch 250: Adjusted 4.94e-02 -> 4.04e-02 (ratio=6.668e-01)
# Epoch 261/300 [  87.0%]
#   Elapsed: 0:07:10 | Remaining: ~0:01:04 | ETA: 12:57:08
#   Epoch time: 2.02s | Avg: 1.64s
#   Total: 1.0071e+01 | Data(6dot): 9.0224e+00
#   Misfit(RMS χ²): 8.559 | Rough: 2.60e+01 | Lam: 0.0403517
#   OT-distance(6D, view-only): 4.511194e-01
#   GradNorms: |g_d|=4.962e-03 | |λ·g_m|=2.690e-03
#  [Auto-Lambda] Epoch 270: Adjusted 4.04e-02 -> 3.40e-02 (ratio=7.119e-01)
#  [Auto-Lambda] Epoch 280: Adjusted 3.40e-02 -> 3.07e-02 (ratio=8.152e-01)
# Epoch 281/300 [  93.7%]
#   Elapsed: 0:07:43 | Remaining: ~0:00:31 | ETA: 12:57:08
#   Epoch time: 2.05s | Avg: 1.65s
#   Total: 9.7907e+00 | Data(6dot): 8.9601e+00
#   Misfit(RMS χ²): 8.533 | Rough: 2.70e+01 | Lam: 0.0307399
#   OT-distance(6D, view-only): 4.480061e-01
#   GradNorms: |g_d|=4.499e-03 | |λ·g_m|=2.139e-03
# Epoch 300/300 [ 100.0%]
#   Elapsed: 0:08:14 | Remaining: ~0:00:00 | ETA: 12:57:08
#   Epoch time: 2.05s | Avg: 1.65s
#   Total: 9.7703e+00 | Data(6dot): 8.9043e+00
#   Misfit(RMS χ²): 8.510 | Rough: 2.82e+01 | Lam: 0.0307399
#   OT-distance(6D, view-only): 4.452150e-01
#   GradNorms: |g_d|=2.158e-02 | |λ·g_m|=2.233e-03
# Inversion completed.
# OT inversion done
# 1e-10 0.13755888439139421

# %%
# 5a) OT 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.3571

# %%
# 6a) 保存 OT 结果
ot_run_dir = logger.save_from_inverter(inv, run_name=ot_run_name)
history_ot = list(inv.loss_history)
print(f"OT run saved: {ot_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d4/2026-07-28_12-57-22_ot4_shift_0.1
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.3571
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d4/2026-07-28_12-57-22_ot4_shift_0.1/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d4/2026-07-28_12-57-22_ot4_shift_0.1/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d4/2026-07-28_12-57-22_ot4_shift_0.1
#   Final RMS χ²: 8.5104
#   RMSE: 0.4341
#   MAPE: 12.30%
# ============================================================
#
# OT run saved: test_results/ccmm2d4/2026-07-28_12-57-22_ot4_shift_0.1

# %%
# 4b) MSE 反演（共用 OT 的 obs_data，仅重置初模与损失尺度）
inv_mse = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    data_loss_scale=500,
)
inv_mse.set_forward_operator()
inv_mse.sig_true = sig_true
inv_mse.load_obs_data(shared_obs_snapshot, noise_floor=shared_shift_meta["noise_level"])
for key, val in shared_shift_meta.items():
    if isinstance(val, dict):
        setattr(inv_mse, key, {k: (v.clone() if torch.is_tensor(v) else v) for k, v in val.items()})
    elif torch.is_tensor(val):
        setattr(inv_mse, key, val.clone())
    else:
        setattr(inv_mse, key, val)

inv_mse.initialize_model(initial_sigma=0.01)
inv_mse.plot_initial_model(clip_to_stations=True, ylim=[50, 0], synthetic_figwidth_scale=2.0)

final_sigma_mse = inv_mse.run_inversion(
    n_epochs=400,
    mode="mse",
    progress_interval=20,
    current_lambda=1,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
inv = inv_mse
print("MSE inversion done")
print(final_sigma_mse.min().item(), final_sigma_mse.max().item())
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.844405e+01
# ✓ Observed data loaded from file
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/400 [   0.2%]
#   Elapsed: 0:00:01 | Remaining: ~0:09:17 | ETA: 13:07:09
#   Epoch time: 1.40s | Avg: 1.40s
#   Total: 5.3793e+02 | Data(mse): 5.3793e+02
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 60.620 | Rough: 0.00e+00 | Lam: 1.0000000
#   OT-distance(6D, view-only): 6.817044e+01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
# Epoch 21/400 [   5.2%]
#   Elapsed: 0:00:32 | Remaining: ~0:09:53 | ETA: 13:08:17
#   Epoch time: 1.96s | Avg: 1.57s
#   Total: 2.2625e+02 | Data(mse): 2.2137e+02
#   Misfit(RMS χ²): 38.888 | Rough: 4.88e+00 | Lam: 1.0000000
#   OT-distance(6D, view-only): 3.871931e+01
#   GradNorms: |g_d|=7.126e-01 | |λ·g_m|=1.163e-01
# Epoch 41/400 [  10.2%]
#   Elapsed: 0:01:04 | Remaining: ~0:09:25 | ETA: 13:08:20
#   Epoch time: 1.97s | Avg: 1.57s
#   Total: 9.4191e+01 | Data(mse): 8.5492e+01
#   Misfit(RMS χ²): 24.167 | Rough: 8.70e+00 | Lam: 1.0000000
#   OT-distance(6D, view-only): 1.947478e+01
#   GradNorms: |g_d|=4.019e-01 | |λ·g_m|=6.766e-02
#  [Auto-Lambda] Epoch 60: Adjusted 1.00e+00 -> 8.10e-01 (ratio=6.562e-01)
# Epoch 61/400 [  15.2%]
#   Elapsed: 0:01:36 | Remaining: ~0:08:57 | ETA: 13:08:24
#   Epoch time: 1.98s | Avg: 1.58s
#   Total: 4.1112e+01 | Data(mse): 3.3455e+01
#   Misfit(RMS χ²): 15.118 | Rough: 9.45e+00 | Lam: 0.8100731
#   OT-distance(6D, view-only): 8.723200e+00
#   GradNorms: |g_d|=1.018e-01 | |λ·g_m|=7.168e-02
#  [Auto-Lambda] Epoch 70: Adjusted 8.10e-01 -> 6.54e-01 (ratio=6.521e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 6.54e-01 -> 5.28e-01 (ratio=6.505e-01)
# Epoch 81/400 [  20.2%]
#   Elapsed: 0:02:08 | Remaining: ~0:08:24 | ETA: 13:08:23
#   Epoch time: 2.04s | Avg: 1.58s
#   Total: 2.4157e+01 | Data(mse): 1.8466e+01
#   Misfit(RMS χ²): 11.232 | Rough: 1.08e+01 | Lam: 0.5276243
#   OT-distance(6D, view-only): 3.705987e+00
#   GradNorms: |g_d|=5.568e-02 | |λ·g_m|=3.398e-02
#  [Auto-Lambda] Epoch 90: Adjusted 5.28e-01 -> 4.80e-01 (ratio=8.273e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 4.80e-01 -> 3.49e-01 (ratio=5.303e-01)
# Epoch 101/400 [  25.2%]
#   Elapsed: 0:02:40 | Remaining: ~0:07:53 | ETA: 13:08:24
#   Epoch time: 1.95s | Avg: 1.58s
#   Total: 1.7194e+01 | Data(mse): 1.2734e+01
#   Misfit(RMS χ²): 9.327 | Rough: 1.28e+01 | Lam: 0.3494811
#   OT-distance(6D, view-only): 2.126725e+00
#   GradNorms: |g_d|=3.720e-02 | |λ·g_m|=2.566e-02
#  [Auto-Lambda] Epoch 110: Adjusted 3.49e-01 -> 2.58e-01 (ratio=5.454e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 2.58e-01 -> 1.74e-01 (ratio=4.560e-01)
# Epoch 121/400 [  30.2%]
#   Elapsed: 0:03:11 | Remaining: ~0:07:22 | ETA: 13:08:24
#   Epoch time: 1.97s | Avg: 1.59s
#   Total: 1.2884e+01 | Data(mse): 1.0205e+01
#   Misfit(RMS χ²): 8.350 | Rough: 1.54e+01 | Lam: 0.1742982
#   OT-distance(6D, view-only): 1.593133e+00
#   GradNorms: |g_d|=1.522e-02 | |λ·g_m|=1.074e-02
#  [Auto-Lambda] Epoch 130: Adjusted 1.74e-01 -> 1.36e-01 (ratio=6.108e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.36e-01 -> 1.06e-01 (ratio=6.089e-01)
# Epoch 141/400 [  35.2%]
#   Elapsed: 0:03:43 | Remaining: ~0:06:51 | ETA: 13:08:25
#   Epoch time: 1.89s | Avg: 1.59s
#   Total: 1.1269e+01 | Data(mse): 9.3015e+00
#   Misfit(RMS χ²): 7.971 | Rough: 1.85e+01 | Lam: 0.1062916
#   OT-distance(6D, view-only): 1.159245e+00
#   GradNorms: |g_d|=1.053e-02 | |λ·g_m|=6.656e-03
#  [Auto-Lambda] Epoch 150: Adjusted 1.06e-01 -> 8.26e-02 (ratio=6.038e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 8.26e-02 -> 6.66e-02 (ratio=6.496e-01)
# Epoch 161/400 [  40.2%]
#   Elapsed: 0:04:15 | Remaining: ~0:06:19 | ETA: 13:08:26
#   Epoch time: 1.98s | Avg: 1.59s
#   Total: 1.0258e+01 | Data(mse): 8.8100e+00
#   Misfit(RMS χ²): 7.758 | Rough: 2.18e+01 | Lam: 0.0665667
#   OT-distance(6D, view-only): 9.909969e-01
#   GradNorms: |g_d|=7.346e-03 | |λ·g_m|=4.635e-03
#  [Auto-Lambda] Epoch 170: Adjusted 6.66e-02 -> 5.63e-02 (ratio=7.160e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 5.63e-02 -> 5.11e-02 (ratio=8.234e-01)
# Epoch 181/400 [  45.2%]
#   Elapsed: 0:04:47 | Remaining: ~0:05:47 | ETA: 13:08:26
#   Epoch time: 1.97s | Avg: 1.59s
#   Total: 9.7620e+00 | Data(mse): 8.4869e+00
#   Misfit(RMS χ²): 7.614 | Rough: 2.49e+01 | Lam: 0.0511090
#   OT-distance(6D, view-only): 9.256782e-01
#   GradNorms: |g_d|=6.843e-03 | |λ·g_m|=3.967e-03
#  [Auto-Lambda] Epoch 190: Adjusted 5.11e-02 -> 4.20e-02 (ratio=6.765e-01)
# Epoch 201/400 [  50.2%]
#   Elapsed: 0:05:19 | Remaining: ~0:05:16 | ETA: 13:08:26
#   Epoch time: 1.99s | Avg: 1.59s
#   Total: 9.4378e+00 | Data(mse): 8.2750e+00
#   Misfit(RMS χ²): 7.519 | Rough: 2.77e+01 | Lam: 0.0420374
#   OT-distance(6D, view-only): 9.084948e-01
#   GradNorms: |g_d|=7.501e-03 | |λ·g_m|=3.572e-03
#  [Auto-Lambda] Epoch 210: Adjusted 4.20e-02 -> 3.61e-02 (ratio=7.376e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 3.61e-02 -> 3.12e-02 (ratio=7.468e-01)
# Epoch 221/400 [  55.2%]
#   Elapsed: 0:05:51 | Remaining: ~0:04:44 | ETA: 13:08:27
#   Epoch time: 1.94s | Avg: 1.59s
#   Total: 9.0575e+00 | Data(mse): 8.1222e+00
#   Misfit(RMS χ²): 7.449 | Rough: 3.00e+01 | Lam: 0.0311985
#   OT-distance(6D, view-only): 9.042758e-01
#   GradNorms: |g_d|=4.349e-03 | |λ·g_m|=2.851e-03
# Epoch 241/400 [  60.2%]
#   Elapsed: 0:06:23 | Remaining: ~0:04:12 | ETA: 13:08:26
#   Epoch time: 2.00s | Avg: 1.59s
#   Total: 8.9950e+00 | Data(mse): 7.9669e+00
#   Misfit(RMS χ²): 7.377 | Rough: 3.30e+01 | Lam: 0.0311985
#   OT-distance(6D, view-only): 9.049854e-01
#   GradNorms: |g_d|=5.696e-03 | |λ·g_m|=3.142e-03
#  [Auto-Lambda] Epoch 250: Adjusted 3.12e-02 -> 2.80e-02 (ratio=8.067e-01)
# Epoch 261/400 [  65.2%]
#   Elapsed: 0:06:55 | Remaining: ~0:03:40 | ETA: 13:08:26
#   Epoch time: 1.99s | Avg: 1.59s
#   Total: 8.8309e+00 | Data(mse): 7.8357e+00
#   Misfit(RMS χ²): 7.316 | Rough: 3.55e+01 | Lam: 0.0280218
#   OT-distance(6D, view-only): 9.091624e-01
#   GradNorms: |g_d|=4.734e-03 | |λ·g_m|=3.079e-03
#  [Auto-Lambda] Epoch 270: Adjusted 2.80e-02 -> 2.25e-02 (ratio=6.456e-01)
# Epoch 281/400 [  70.2%]
#   Elapsed: 0:07:26 | Remaining: ~0:03:09 | ETA: 13:08:26
#   Epoch time: 1.98s | Avg: 1.59s
#   Total: 8.5783e+00 | Data(mse): 7.7069e+00
#   Misfit(RMS χ²): 7.256 | Rough: 3.87e+01 | Lam: 0.0225150
#   OT-distance(6D, view-only): 9.158232e-01
#   GradNorms: |g_d|=1.478e-02 | |λ·g_m|=2.751e-03
# Epoch 301/400 [  75.2%]
#   Elapsed: 0:07:58 | Remaining: ~0:02:37 | ETA: 13:08:26
#   Epoch time: 1.97s | Avg: 1.59s
#   Total: 8.5390e+00 | Data(mse): 7.6087e+00
#   Misfit(RMS χ²): 7.210 | Rough: 4.13e+01 | Lam: 0.0225150
#   OT-distance(6D, view-only): 9.196523e-01
#   GradNorms: |g_d|=5.184e-03 | |λ·g_m|=2.910e-03
#  [Auto-Lambda] Epoch 310: Adjusted 2.25e-02 -> 1.81e-02 (ratio=6.448e-01)
# Epoch 321/400 [  80.2%]
#   Elapsed: 0:08:30 | Remaining: ~0:02:05 | ETA: 13:08:26
#   Epoch time: 1.96s | Avg: 1.59s
#   Total: 8.3268e+00 | Data(mse): 7.5459e+00
#   Misfit(RMS χ²): 7.180 | Rough: 4.32e+01 | Lam: 0.0180787
#   OT-distance(6D, view-only): 9.215329e-01
#   GradNorms: |g_d|=8.462e-03 | |λ·g_m|=2.421e-03
#  [Auto-Lambda] Epoch 340: Adjusted 1.81e-02 -> 1.61e-02 (ratio=7.896e-01)
# Epoch 341/400 [  85.2%]
#   Elapsed: 0:09:02 | Remaining: ~0:01:33 | ETA: 13:08:26
#   Epoch time: 2.04s | Avg: 1.59s
#   Total: 8.2117e+00 | Data(mse): 7.4829e+00
#   Misfit(RMS χ²): 7.150 | Rough: 4.54e+01 | Lam: 0.0160652
#   OT-distance(6D, view-only): 9.256283e-01
#   GradNorms: |g_d|=3.681e-03 | |λ·g_m|=2.247e-03
# Epoch 361/400 [  90.2%]
#   Elapsed: 0:09:34 | Remaining: ~0:01:01 | ETA: 13:08:26
#   Epoch time: 1.99s | Avg: 1.59s
#   Total: 8.1949e+00 | Data(mse): 7.4354e+00
#   Misfit(RMS χ²): 7.127 | Rough: 4.73e+01 | Lam: 0.0160652
#   OT-distance(6D, view-only): 9.285479e-01
#   GradNorms: |g_d|=1.072e-02 | |λ·g_m|=2.326e-03
# Epoch 381/400 [  95.2%]
#   Elapsed: 0:10:05 | Remaining: ~0:00:30 | ETA: 13:08:26
#   Epoch time: 1.99s | Avg: 1.59s
#   Total: 8.1799e+00 | Data(mse): 7.4016e+00
#   Misfit(RMS χ²): 7.111 | Rough: 4.84e+01 | Lam: 0.0160652
#   OT-distance(6D, view-only): 9.276763e-01
#   GradNorms: |g_d|=3.978e-03 | |λ·g_m|=2.357e-03
# Epoch 400/400 [ 100.0%]
#   Elapsed: 0:10:35 | Remaining: ~0:00:00 | ETA: 13:08:26
#   Epoch time: 1.85s | Avg: 1.59s
#   Total: 8.1705e+00 | Data(mse): 7.3815e+00
#   Misfit(RMS χ²): 7.101 | Rough: 4.91e+01 | Lam: 0.0160652
#   OT-distance(6D, view-only): 9.268630e-01
#   GradNorms: |g_d|=3.583e-03 | |λ·g_m|=2.365e-03
# Inversion completed.
# MSE inversion done
# 1e-10 1.202808135203497

# %%
# 5b) MSE 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.2732

# %%
# 6b) 保存 MSE 结果
mse_run_dir = logger.save_from_inverter(inv, run_name=mse_run_name)
history_mse = list(inv.loss_history)
print(f"MSE run saved: {mse_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d4/2026-07-28_13-08-40_mse4_shift_0.1
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.2732
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d4/2026-07-28_13-08-40_mse4_shift_0.1/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d4/2026-07-28_13-08-40_mse4_shift_0.1/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d4/2026-07-28_13-08-40_mse4_shift_0.1
#   Final RMS χ²: 7.1012
#   RMSE: 0.5312
#   MAPE: 17.44%
# ============================================================
#
# MSE run saved: test_results/ccmm2d4/2026-07-28_13-08-40_mse4_shift_0.1

# %%
# 7) OT vs MSE 对比（收敛曲线 + 视电阻率四线合一 + 伪断面）
plot_ot_mse_convergence(history_ot, history_mse, target_misfit=1.05)

plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=[8,9],
    mode="xy",
)
plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=[8,9],
    mode="yx",
)

plot_ot_mse_pseudosection_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    mode="xy",
)
# Out:
# /home/liuxr/论文绘图/src/mt2d_inv/plotting/pseudosection.py:145: UserWarning: Glyph 8336 (\N{LATIN SUBSCRIPT SMALL LETTER A}) missing from font(s) STIXGeneral.
#   ax.figure.tight_layout()
# /home/liuxr/.conda/envs/torch/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8336 (\N{LATIN SUBSCRIPT SMALL LETTER A}) missing from font(s) STIXGeneral.
#   fig.canvas.print_figure(bytes_io, **kw)
# {'inversion_axes': array([<Axes: title={'center': 'True'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#         <Axes: title={'center': 'OT inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#         <Axes: title={'center': 'MSE inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>],
#        dtype=object),
#  'observed_axes': <Axes: xlabel='Distance (km)', ylabel='Period (s)'>}
