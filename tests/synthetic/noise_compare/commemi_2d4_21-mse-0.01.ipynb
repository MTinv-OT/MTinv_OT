# %% [markdown]
# # COMMEMI 2D-4：固定静位移（TE 和 TM 有相同静位移） OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d4` 生成标准模型，
# **通过新接口固定静位移**（`static_shift_log` + `shift_station_indices`）施加静位移。
# xy 和 yx（TE/TM）在相同指定台站施加相同固定 log10 乘子 0.15。
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演，并对比。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d4",
    output_root=Path("test_results"),
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/论文绘图

# %%
import os
from pathlib import Path

print(f"当前目录: {Path.cwd()}")
print(f"目录内容: {list(Path.cwd().iterdir())}")

# 检查 src 在哪里
for p in [Path.cwd(), Path.cwd().parent, Path.cwd().parent.parent]:
    if (p / "src").exists():
        print(f"找到 src 在: {p}")
# Out:
# 当前目录: /home/liuxr/论文绘图/experiment/synthetic/noise_compare
# 目录内容: [PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/.ipynb_checkpoints'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-mse-0.01.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-mse-0.04.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-ot-0.02.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-mse-0.02.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-mse-0.02.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/test_results1'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-mse-scale=500-Copy1.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-mse-0.04.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-ot-0.04.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-ot-0.01.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-mse-0.01.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-ot-0.01.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/test_results'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-ot-0.04.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-ot-0.02.ipynb')]

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d4(
    nza=10,
    device=device, 
)

# 2) Survey setup
freqs = torch.logspace(0, -3.5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=300,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.01,
                        noise_type="gaussian",
)

inv.noise_floor = 0.026
inv._build_rms_chi2_cache()
inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0],synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.842733e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 1.0% (gaussian)
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4b) MSE 反演（同一静位移观测数据，重置初模）
inv.initialize_model(initial_sigma=0.01)
final_sigma_mse = inv.run_inversion(
    n_epochs=400,
    mode="mse",
    progress_interval=20,
    current_lambda=10,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("MSE inversion done")
print(final_sigma_mse.min().item(), final_sigma_mse.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/400 [   0.2%]
#   Elapsed: 0:00:02 | Remaining: ~0:09:59 | ETA: 21:36:14
#   Epoch time: 1.50s | Avg: 1.50s
#   Total: 3.1174e+02 | Data(mse): 3.1174e+02
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 45.814 | Rough: 0.00e+00 | Lam: 10.0000000
#   OT-distance(6D, view-only): 6.768785e+01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e+01 -> 4.49e+00 (ratio=2.020e-01)
#  [Auto-Lambda] Epoch 20: Adjusted 4.49e+00 -> 3.61e+00 (ratio=6.434e-01)
# Epoch 21/400 [   5.2%]
#   Elapsed: 0:00:32 | Remaining: ~0:09:26 | ETA: 21:36:12
#   Epoch time: 1.53s | Avg: 1.50s
#   Total: 1.4723e+02 | Data(mse): 1.3878e+02
#   Misfit(RMS χ²): 30.564 | Rough: 2.35e+00 | Lam: 3.6051884
#   OT-distance(6D, view-only): 4.221022e+01
#   GradNorms: |g_d|=4.802e-01 | |λ·g_m|=2.971e-01
#  [Auto-Lambda] Epoch 30: Adjusted 3.61e+00 -> 3.27e+00 (ratio=8.228e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 3.27e+00 -> 2.75e+00 (ratio=7.050e-01)
# Epoch 41/400 [  10.2%]
#   Elapsed: 0:01:02 | Remaining: ~0:09:02 | ETA: 21:36:17
#   Epoch time: 1.51s | Avg: 1.51s
#   Total: 6.7355e+01 | Data(mse): 5.0594e+01
#   Misfit(RMS χ²): 18.456 | Rough: 6.10e+00 | Lam: 2.7457975
#   OT-distance(6D, view-only): 2.415392e+01
#   GradNorms: |g_d|=2.842e-01 | |λ·g_m|=1.675e-01
#  [Auto-Lambda] Epoch 50: Adjusted 2.75e+00 -> 2.05e+00 (ratio=5.548e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 2.05e+00 -> 1.32e+00 (ratio=4.142e-01)
# Epoch 61/400 [  15.2%]
#   Elapsed: 0:01:33 | Remaining: ~0:08:32 | ETA: 21:36:18
#   Epoch time: 1.52s | Avg: 1.51s
#   Total: 2.6405e+01 | Data(mse): 1.4991e+01
#   Misfit(RMS χ²): 10.050 | Rough: 8.67e+00 | Lam: 1.3162764
#   OT-distance(6D, view-only): 1.086152e+01
#   GradNorms: |g_d|=1.130e-01 | |λ·g_m|=9.168e-02
#  [Auto-Lambda] Epoch 70: Adjusted 1.32e+00 -> 8.51e-01 (ratio=4.177e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 8.51e-01 -> 6.09e-01 (ratio=5.121e-01)
# Epoch 81/400 [  20.2%]
#   Elapsed: 0:02:03 | Remaining: ~0:08:02 | ETA: 21:36:19
#   Epoch time: 1.53s | Avg: 1.51s
#   Total: 1.0111e+01 | Data(mse): 4.5899e+00
#   Misfit(RMS χ²): 5.563 | Rough: 9.07e+00 | Lam: 0.6087382
#   OT-distance(6D, view-only): 4.170471e+00
#   GradNorms: |g_d|=4.420e-02 | |λ·g_m|=3.060e-02
#  [Auto-Lambda] Epoch 90: Adjusted 6.09e-01 -> 4.40e-01 (ratio=5.215e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 4.40e-01 -> 3.16e-01 (ratio=5.168e-01)
# Epoch 101/400 [  25.2%]
#   Elapsed: 0:02:34 | Remaining: ~0:07:33 | ETA: 21:36:20
#   Epoch time: 1.68s | Avg: 1.52s
#   Total: 5.1661e+00 | Data(mse): 2.1087e+00
#   Misfit(RMS χ²): 3.772 | Rough: 9.68e+00 | Lam: 0.3160022
#   OT-distance(6D, view-only): 2.239873e+00
#   GradNorms: |g_d|=2.036e-02 | |λ·g_m|=1.449e-02
#  [Auto-Lambda] Epoch 110: Adjusted 3.16e-01 -> 2.27e-01 (ratio=5.168e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 2.27e-01 -> 1.69e-01 (ratio=5.534e-01)
# Epoch 121/400 [  30.2%]
#   Elapsed: 0:03:03 | Remaining: ~0:07:01 | ETA: 21:36:18
#   Epoch time: 1.48s | Avg: 1.51s
#   Total: 3.1190e+00 | Data(mse): 1.2499e+00
#   Misfit(RMS χ²): 2.904 | Rough: 1.11e+01 | Lam: 0.1689927
#   OT-distance(6D, view-only): 1.399964e+00
#   GradNorms: |g_d|=1.182e-02 | |λ·g_m|=7.931e-03
#  [Auto-Lambda] Epoch 130: Adjusted 1.69e-01 -> 1.28e-01 (ratio=5.778e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.28e-01 -> 9.85e-02 (ratio=5.874e-01)
# Epoch 141/400 [  35.2%]
#   Elapsed: 0:03:33 | Remaining: ~0:06:31 | ETA: 21:36:18
#   Epoch time: 1.53s | Avg: 1.51s
#   Total: 2.0495e+00 | Data(mse): 7.9916e-01
#   Misfit(RMS χ²): 2.322 | Rough: 1.27e+01 | Lam: 0.0984526
#   OT-distance(6D, view-only): 9.014609e-01
#   GradNorms: |g_d|=7.290e-03 | |λ·g_m|=4.875e-03
#  [Auto-Lambda] Epoch 150: Adjusted 9.85e-02 -> 7.55e-02 (ratio=5.874e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 7.55e-02 -> 5.82e-02 (ratio=5.950e-01)
# Epoch 161/400 [  40.2%]
#   Elapsed: 0:04:04 | Remaining: ~0:06:01 | ETA: 21:36:18
#   Epoch time: 1.53s | Avg: 1.51s
#   Total: 1.3672e+00 | Data(mse): 5.3015e-01
#   Misfit(RMS χ²): 1.891 | Rough: 1.44e+01 | Lam: 0.0582040
#   OT-distance(6D, view-only): 5.930650e-01
#   GradNorms: |g_d|=4.596e-03 | |λ·g_m|=3.039e-03
#  [Auto-Lambda] Epoch 170: Adjusted 5.82e-02 -> 4.52e-02 (ratio=6.041e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 4.52e-02 -> 4.16e-02 (ratio=8.452e-01)
# Epoch 181/400 [  45.2%]
#   Elapsed: 0:04:34 | Remaining: ~0:05:31 | ETA: 21:36:19
#   Epoch time: 1.51s | Avg: 1.51s
#   Total: 1.0396e+00 | Data(mse): 3.7689e-01
#   Misfit(RMS χ²): 1.594 | Rough: 1.59e+01 | Lam: 0.0415905
#   OT-distance(6D, view-only): 4.262167e-01
#   GradNorms: |g_d|=4.452e-03 | |λ·g_m|=2.271e-03
#  [Auto-Lambda] Epoch 190: Adjusted 4.16e-02 -> 3.37e-02 (ratio=6.583e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 3.37e-02 -> 2.74e-02 (ratio=6.590e-01)
# Epoch 201/400 [  50.2%]
#   Elapsed: 0:05:04 | Remaining: ~0:05:01 | ETA: 21:36:18
#   Epoch time: 1.51s | Avg: 1.51s
#   Total: 7.6255e-01 | Data(mse): 2.9475e-01
#   Misfit(RMS χ²): 1.410 | Rough: 1.71e+01 | Lam: 0.0273942
#   OT-distance(6D, view-only): 3.295297e-01
#   GradNorms: |g_d|=2.360e-03 | |λ·g_m|=1.517e-03
#  [Auto-Lambda] Epoch 210: Adjusted 2.74e-02 -> 2.24e-02 (ratio=6.679e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 2.24e-02 -> 1.85e-02 (ratio=6.841e-01)
# Epoch 221/400 [  55.2%]
#   Elapsed: 0:05:35 | Remaining: ~0:04:30 | ETA: 21:36:19
#   Epoch time: 1.53s | Avg: 1.51s
#   Total: 5.7778e-01 | Data(mse): 2.4083e-01
#   Misfit(RMS χ²): 1.274 | Rough: 1.82e+01 | Lam: 0.0185167
#   OT-distance(6D, view-only): 2.654827e-01
#   GradNorms: |g_d|=1.722e-03 | |λ·g_m|=1.060e-03
#  [Auto-Lambda] Epoch 230: Adjusted 1.85e-02 -> 1.54e-02 (ratio=6.952e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 1.54e-02 -> 1.30e-02 (ratio=7.040e-01)
# Epoch 241/400 [  60.2%]
#   Elapsed: 0:06:05 | Remaining: ~0:04:00 | ETA: 21:36:18
#   Epoch time: 1.55s | Avg: 1.51s
#   Total: 4.5470e-01 | Data(mse): 2.0553e-01
#   Misfit(RMS χ²): 1.177 | Rough: 1.92e+01 | Lam: 0.0129540
#   OT-distance(6D, view-only): 2.212718e-01
#   GradNorms: |g_d|=1.282e-03 | |λ·g_m|=7.647e-04
#  [Auto-Lambda] Epoch 250: Adjusted 1.30e-02 -> 1.10e-02 (ratio=7.161e-01)
#  [Auto-Lambda] Epoch 260: Adjusted 1.10e-02 -> 9.33e-03 (ratio=7.248e-01)
# Epoch 261/400 [  65.2%]
#   Elapsed: 0:06:34 | Remaining: ~0:03:29 | ETA: 21:36:17
#   Epoch time: 1.44s | Avg: 1.51s
#   Total: 3.7081e-01 | Data(mse): 1.8284e-01
#   Misfit(RMS χ²): 1.111 | Rough: 2.01e+01 | Lam: 0.0093327
#   OT-distance(6D, view-only): 1.922918e-01
#   GradNorms: |g_d|=9.386e-04 | |λ·g_m|=5.656e-04
#  [Auto-Lambda] Epoch 270: Adjusted 9.33e-03 -> 8.25e-03 (ratio=7.805e-01)
# Epoch 281/400 [  70.2%]
#   Elapsed: 0:07:03 | Remaining: ~0:02:59 | ETA: 21:36:16
#   Epoch time: 1.45s | Avg: 1.51s
#   Total: 3.4053e-01 | Data(mse): 1.6806e-01
#   Misfit(RMS χ²): 1.065 | Rough: 2.09e+01 | Lam: 0.0082451
#   OT-distance(6D, view-only): 1.727061e-01
#   GradNorms: |g_d|=1.989e-03 | |λ·g_m|=5.114e-04
#   [Early stop] RMS χ² = 1.049 < 1.05, epoch = 290
# Inversion completed.
# MSE inversion done
# 1e-10 0.07254501486073857

# %%
# 5b) MSE 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.3188

# %%
mse_run_dir = logger.save_from_inverter(inv, run_name="mse_0.01")
history_mse = list(inv.loss_history)
print(f"MSE run saved: {mse_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d4/2026-08-18_21-33-46_mse_0.01
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.3188
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d4/2026-08-18_21-33-46_mse_0.01/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d4/2026-08-18_21-33-46_mse_0.01/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d4/2026-08-18_21-33-46_mse_0.01
#   Final RMS χ²: 1.0486
#   RMSE: 0.4853
#   MAPE: 14.89%
# ============================================================
#
# MSE run saved: test_results/ccmm2d4/2026-08-18_21-33-46_mse_0.01
