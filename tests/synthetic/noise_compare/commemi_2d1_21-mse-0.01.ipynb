# %% [markdown]
# # COMMEMI 2D-1：固定静位移（TE 和 TM 有相同静位移） OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d1` 生成标准模型，
# **通过新接口固定静位移**（`static_shift_log` + `shift_station_indices`）施加静位移。
# xy 和 yx（TE/TM）在相同指定台站施加相同固定 log10 乘子 0.15。
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演，并对比。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d1",
    output_root=Path("test_results"),
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/论文绘图

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d1(
    zn=None,
    yn=None,
    nza=10,
    device=device,
    rho_host=100.0,
    rho_block=10.0,
    y_half_width_m=2000.0,
    z_top_m=10000.0,
    z_bottom_m=30000.0,
)

# 2) Survey setup
freqs = torch.logspace(0, -3.5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=30,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.01,
                        noise_type="gaussian",
                        )
inv.update_ot_w_d_per_point_from_noise(
    w_d_scale=[2.0, 1.0, 1.0, 1.0],  # [rhoxy, phsxy, rhoyx, phsyx]
    normalize="mean",)
inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0],synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.843063e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 1.0% (gaussian)
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=tensor(630, 4)@cuda, blur=0.0100, scale=0.9, reach=None
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4b) MSE 反演（同一静位移观测数据，重置初模）
inv.initialize_model(initial_sigma=0.01)
final_sigma_mse = inv.run_inversion(
    n_epochs=500,
    mode="mse",
    progress_interval=20,
    current_lambda=0.1,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("MSE inversion done")
print(final_sigma_mse.min().item(), final_sigma_mse.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/500 [   0.2%]
#   Elapsed: 0:00:02 | Remaining: ~0:13:05 | ETA: 16:12:08
#   Epoch time: 1.57s | Avg: 1.57s
#   Total: 2.2922e-01 | Data(mse): 2.2922e-01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=tensor([[2., 1., 1., 1.],
#         [2., 1., 1., 1.],
#         [2., 1., 1., 1.],
#         ...,
#         [2., 1., 1., 1.],
#         [2., 1., 1., 1.],
#         [2., 1., 1., 1.]], device='cuda:0')
#   Misfit(RMS χ²): 5.107 | Rough: 0.00e+00 | Lam: 0.1000000
#   OT-distance(6D, view-only): 1.202506e+00
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e-01 -> 2.46e-02 (ratio=6.036e-02)
#  [Auto-Lambda] Epoch 20: Adjusted 2.46e-02 -> 9.98e-03 (ratio=1.649e-01)
# Epoch 21/500 [   4.2%]
#   Elapsed: 0:00:31 | Remaining: ~0:11:50 | ETA: 16:11:22
#   Epoch time: 1.59s | Avg: 1.48s
#   Total: 4.3799e-02 | Data(mse): 3.4805e-02
#   Misfit(RMS χ²): 1.990 | Rough: 9.01e-01 | Lam: 0.0099774
#   OT-distance(6D, view-only): 2.561047e-01
#   GradNorms: |g_d|=1.078e-03 | |λ·g_m|=1.216e-03
#  [Auto-Lambda] Epoch 30: Adjusted 9.98e-03 -> 5.35e-03 (ratio=2.878e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 5.35e-03 -> 2.97e-03 (ratio=3.084e-01)
# Epoch 41/500 [   8.2%]
#   Elapsed: 0:01:01 | Remaining: ~0:11:21 | ETA: 16:11:24
#   Epoch time: 1.46s | Avg: 1.49s
#   Total: 2.8457e-02 | Data(mse): 2.5154e-02
#   Misfit(RMS χ²): 1.692 | Rough: 1.11e+00 | Lam: 0.0029727
#   OT-distance(6D, view-only): 1.854796e-01
#   GradNorms: |g_d|=3.710e-04 | |λ·g_m|=3.572e-04
#  [Auto-Lambda] Epoch 50: Adjusted 2.97e-03 -> 2.63e-03 (ratio=7.812e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 2.63e-03 -> 1.99e-03 (ratio=5.739e-01)
# Epoch 61/500 [  12.2%]
#   Elapsed: 0:01:31 | Remaining: ~0:10:51 | ETA: 16:11:23
#   Epoch time: 1.52s | Avg: 1.48s
#   Total: 2.5287e-02 | Data(mse): 2.2878e-02
#   Misfit(RMS χ²): 1.614 | Rough: 1.21e+00 | Lam: 0.0019904
#   OT-distance(6D, view-only): 1.731610e-01
#   GradNorms: |g_d|=1.463e-04 | |λ·g_m|=1.057e-04
#  [Auto-Lambda] Epoch 70: Adjusted 1.99e-03 -> 1.78e-03 (ratio=8.039e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 1.78e-03 -> 1.55e-03 (ratio=7.560e-01)
# Epoch 81/500 [  16.2%]
#   Elapsed: 0:02:01 | Remaining: ~0:10:23 | ETA: 16:11:25
#   Epoch time: 1.46s | Avg: 1.49s
#   Total: 2.4057e-02 | Data(mse): 2.1960e-02
#   Misfit(RMS χ²): 1.581 | Rough: 1.35e+00 | Lam: 0.0015517
#   OT-distance(6D, view-only): 1.658180e-01
#   GradNorms: |g_d|=7.878e-05 | |λ·g_m|=4.781e-05
#  [Auto-Lambda] Epoch 90: Adjusted 1.55e-03 -> 1.26e-03 (ratio=6.590e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 1.26e-03 -> 1.07e-03 (ratio=7.243e-01)
# Epoch 101/500 [  20.2%]
#   Elapsed: 0:02:31 | Remaining: ~0:09:53 | ETA: 16:11:24
#   Epoch time: 1.49s | Avg: 1.49s
#   Total: 2.2959e-02 | Data(mse): 2.1340e-02
#   Misfit(RMS χ²): 1.558 | Rough: 1.51e+00 | Lam: 0.0010720
#   OT-distance(6D, view-only): 1.614331e-01
#   GradNorms: |g_d|=4.864e-05 | |λ·g_m|=2.940e-05
#  [Auto-Lambda] Epoch 110: Adjusted 1.07e-03 -> 9.14e-04 (ratio=7.262e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 9.14e-04 -> 7.82e-04 (ratio=7.330e-01)
# Epoch 121/500 [  24.2%]
#   Elapsed: 0:03:00 | Remaining: ~0:09:22 | ETA: 16:11:23
#   Epoch time: 1.46s | Avg: 1.48s
#   Total: 2.2085e-02 | Data(mse): 2.0714e-02
#   Misfit(RMS χ²): 1.535 | Rough: 1.75e+00 | Lam: 0.0007821
#   OT-distance(6D, view-only): 1.568941e-01
#   GradNorms: |g_d|=3.878e-05 | |λ·g_m|=2.273e-05
#  [Auto-Lambda] Epoch 130: Adjusted 7.82e-04 -> 6.93e-04 (ratio=7.858e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 6.93e-04 -> 6.29e-04 (ratio=8.243e-01)
# Epoch 141/500 [  28.2%]
#   Elapsed: 0:03:29 | Remaining: ~0:08:50 | ETA: 16:11:20
#   Epoch time: 1.50s | Avg: 1.48s
#   Total: 2.1320e-02 | Data(mse): 2.0002e-02
#   Misfit(RMS χ²): 1.509 | Rough: 2.09e+00 | Lam: 0.0006294
#   OT-distance(6D, view-only): 1.522552e-01
#   GradNorms: |g_d|=3.563e-05 | |λ·g_m|=1.976e-05
#  [Auto-Lambda] Epoch 150: Adjusted 6.29e-04 -> 5.86e-04 (ratio=8.667e-01)
# Epoch 161/500 [  32.2%]
#   Elapsed: 0:03:58 | Remaining: ~0:08:19 | ETA: 16:11:18
#   Epoch time: 1.43s | Avg: 1.47s
#   Total: 2.0604e-02 | Data(mse): 1.9091e-02
#   Misfit(RMS χ²): 1.474 | Rough: 2.58e+00 | Lam: 0.0005860
#   OT-distance(6D, view-only): 1.466900e-01
#   GradNorms: |g_d|=3.623e-05 | |λ·g_m|=1.999e-05
#  [Auto-Lambda] Epoch 170: Adjusted 5.86e-04 -> 5.55e-04 (ratio=8.954e-01)
# Epoch 181/500 [  36.2%]
#   Elapsed: 0:04:27 | Remaining: ~0:07:49 | ETA: 16:11:17
#   Epoch time: 1.41s | Avg: 1.47s
#   Total: 1.9706e-02 | Data(mse): 1.7891e-02
#   Misfit(RMS χ²): 1.427 | Rough: 3.27e+00 | Lam: 0.0005545
#   OT-distance(6D, view-only): 1.398208e-01
#   GradNorms: |g_d|=3.863e-05 | |λ·g_m|=2.069e-05
#  [Auto-Lambda] Epoch 200: Adjusted 5.55e-04 -> 5.22e-04 (ratio=8.873e-01)
# Epoch 201/500 [  40.2%]
#   Elapsed: 0:04:56 | Remaining: ~0:07:19 | ETA: 16:11:16
#   Epoch time: 1.45s | Avg: 1.47s
#   Total: 1.8611e-02 | Data(mse): 1.6411e-02
#   Misfit(RMS χ²): 1.367 | Rough: 4.21e+00 | Lam: 0.0005223
#   OT-distance(6D, view-only): 1.316381e-01
#   GradNorms: |g_d|=4.051e-05 | |λ·g_m|=2.159e-05
#  [Auto-Lambda] Epoch 210: Adjusted 5.22e-04 -> 4.93e-04 (ratio=8.925e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 4.93e-04 -> 4.62e-04 (ratio=8.753e-01)
# Epoch 221/500 [  44.2%]
#   Elapsed: 0:05:24 | Remaining: ~0:06:48 | ETA: 16:11:13
#   Epoch time: 1.37s | Avg: 1.46s
#   Total: 1.7323e-02 | Data(mse): 1.4845e-02
#   Misfit(RMS χ²): 1.300 | Rough: 5.37e+00 | Lam: 0.0004617
#   OT-distance(6D, view-only): 1.229758e-01
#   GradNorms: |g_d|=3.962e-05 | |λ·g_m|=2.136e-05
#  [Auto-Lambda] Epoch 230: Adjusted 4.62e-04 -> 4.26e-04 (ratio=8.520e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 4.26e-04 -> 3.88e-04 (ratio=8.301e-01)
# Epoch 241/500 [  48.2%]
#   Elapsed: 0:05:52 | Remaining: ~0:06:17 | ETA: 16:11:10
#   Epoch time: 1.37s | Avg: 1.46s
#   Total: 1.6033e-02 | Data(mse): 1.3470e-02
#   Misfit(RMS χ²): 1.238 | Rough: 6.60e+00 | Lam: 0.0003883
#   OT-distance(6D, view-only): 1.151671e-01
#   GradNorms: |g_d|=3.613e-05 | |λ·g_m|=2.005e-05
#  [Auto-Lambda] Epoch 250: Adjusted 3.88e-04 -> 3.50e-04 (ratio=8.132e-01)
#  [Auto-Lambda] Epoch 260: Adjusted 3.50e-04 -> 3.14e-04 (ratio=8.022e-01)
# Epoch 261/500 [  52.2%]
#   Elapsed: 0:06:19 | Remaining: ~0:05:46 | ETA: 16:11:06
#   Epoch time: 1.36s | Avg: 1.45s
#   Total: 1.4860e-02 | Data(mse): 1.2429e-02
#   Misfit(RMS χ²): 1.189 | Rough: 7.75e+00 | Lam: 0.0003136
#   OT-distance(6D, view-only): 1.089778e-01
#   GradNorms: |g_d|=3.155e-05 | |λ·g_m|=1.782e-05
#  [Auto-Lambda] Epoch 270: Adjusted 3.14e-04 -> 2.80e-04 (ratio=7.961e-01)
#  [Auto-Lambda] Epoch 280: Adjusted 2.80e-04 -> 2.49e-04 (ratio=7.942e-01)
# Epoch 281/500 [  56.2%]
#   Elapsed: 0:06:46 | Remaining: ~0:05:16 | ETA: 16:11:03
#   Epoch time: 1.37s | Avg: 1.44s
#   Total: 1.3865e-02 | Data(mse): 1.1677e-02
#   Misfit(RMS χ²): 1.153 | Rough: 8.77e+00 | Lam: 0.0002494
#   OT-distance(6D, view-only): 1.042832e-01
#   GradNorms: |g_d|=2.707e-05 | |λ·g_m|=1.536e-05
#  [Auto-Lambda] Epoch 290: Adjusted 2.49e-04 -> 2.23e-04 (ratio=7.970e-01)
# Epoch 301/500 [  60.2%]
#   Elapsed: 0:07:13 | Remaining: ~0:04:46 | ETA: 16:11:00
#   Epoch time: 1.37s | Avg: 1.44s
#   Total: 1.3283e-02 | Data(mse): 1.1132e-02
#   Misfit(RMS χ²): 1.126 | Rough: 9.67e+00 | Lam: 0.0002226
#   OT-distance(6D, view-only): 1.006769e-01
#   GradNorms: |g_d|=6.557e-05 | |λ·g_m|=1.467e-05
# Epoch 321/500 [  64.2%]
#   Elapsed: 0:07:40 | Remaining: ~0:04:16 | ETA: 16:10:58
#   Epoch time: 1.38s | Avg: 1.43s
#   Total: 1.3051e-02 | Data(mse): 1.0752e-02
#   Misfit(RMS χ²): 1.106 | Rough: 1.03e+01 | Lam: 0.0002226
#   OT-distance(6D, view-only): 9.797723e-02
#   GradNorms: |g_d|=4.031e-05 | |λ·g_m|=1.536e-05
#  [Auto-Lambda] Epoch 340: Adjusted 2.23e-04 -> 1.97e-04 (ratio=7.809e-01)
# Epoch 341/500 [  68.2%]
#   Elapsed: 0:08:08 | Remaining: ~0:03:47 | ETA: 16:10:55
#   Epoch time: 1.38s | Avg: 1.43s
#   Total: 1.2615e-02 | Data(mse): 1.0496e-02
#   Misfit(RMS χ²): 1.093 | Rough: 1.08e+01 | Lam: 0.0001967
#   OT-distance(6D, view-only): 9.602003e-02
#   GradNorms: |g_d|=1.966e-05 | |λ·g_m|=1.392e-05
#  [Auto-Lambda] Epoch 350: Adjusted 1.97e-04 -> 1.65e-04 (ratio=7.026e-01)
#  [Auto-Lambda] Epoch 360: Adjusted 1.65e-04 -> 1.42e-04 (ratio=7.382e-01)
# Epoch 361/500 [  72.2%]
#   Elapsed: 0:08:35 | Remaining: ~0:03:18 | ETA: 16:10:54
#   Epoch time: 1.37s | Avg: 1.43s
#   Total: 1.1869e-02 | Data(mse): 1.0274e-02
#   Misfit(RMS χ²): 1.081 | Rough: 1.13e+01 | Lam: 0.0001417
#   OT-distance(6D, view-only): 9.441509e-02
#   GradNorms: |g_d|=1.834e-05 | |λ·g_m|=1.032e-05
#  [Auto-Lambda] Epoch 370: Adjusted 1.42e-04 -> 1.24e-04 (ratio=7.669e-01)
#  [Auto-Lambda] Epoch 380: Adjusted 1.24e-04 -> 1.11e-04 (ratio=7.989e-01)
# Epoch 381/500 [  76.2%]
#   Elapsed: 0:09:02 | Remaining: ~0:02:49 | ETA: 16:10:52
#   Epoch time: 1.37s | Avg: 1.42s
#   Total: 1.1376e-02 | Data(mse): 1.0062e-02
#   Misfit(RMS χ²): 1.070 | Rough: 1.18e+01 | Lam: 0.0001109
#   OT-distance(6D, view-only): 9.295109e-02
#   GradNorms: |g_d|=1.475e-05 | |λ·g_m|=8.403e-06
#  [Auto-Lambda] Epoch 390: Adjusted 1.11e-04 -> 1.00e-04 (ratio=8.127e-01)
#  [Auto-Lambda] Epoch 400: Adjusted 1.00e-04 -> 9.07e-05 (ratio=8.241e-01)
# Epoch 401/500 [  80.2%]
#   Elapsed: 0:09:30 | Remaining: ~0:02:20 | ETA: 16:10:51
#   Epoch time: 1.37s | Avg: 1.42s
#   Total: 1.1012e-02 | Data(mse): 9.8837e-03
#   Misfit(RMS χ²): 1.061 | Rough: 1.24e+01 | Lam: 0.0000907
#   OT-distance(6D, view-only): 9.168679e-02
#   GradNorms: |g_d|=1.288e-05 | |λ·g_m|=7.151e-06
#  [Auto-Lambda] Epoch 410: Adjusted 9.07e-05 -> 8.28e-05 (ratio=8.323e-01)
#  [Auto-Lambda] Epoch 420: Adjusted 8.28e-05 -> 7.60e-05 (ratio=8.417e-01)
# Epoch 421/500 [  84.2%]
#   Elapsed: 0:09:57 | Remaining: ~0:01:51 | ETA: 16:10:49
#   Epoch time: 1.36s | Avg: 1.42s
#   Total: 1.0725e-02 | Data(mse): 9.7397e-03
#   Misfit(RMS χ²): 1.053 | Rough: 1.30e+01 | Lam: 0.0000760
#   OT-distance(6D, view-only): 9.064409e-02
#   GradNorms: |g_d|=1.131e-05 | |λ·g_m|=6.197e-06
#   [Early stop] RMS χ² = 1.050 < 1.05, epoch = 429
# Inversion completed.
# MSE inversion done
# 1e-10 0.10651072811042506

# %%
# 5b) MSE 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.3120

# %%
mse_run_dir = logger.save_from_inverter(inv, run_name="mse_0.01")
history_mse = list(inv.loss_history)
print(f"MSE run saved: {mse_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d1/2026-08-10_16-09-23_mse_21_2noise
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.3120
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d1/2026-08-10_16-09-23_mse_21_2noise/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d1/2026-08-10_16-09-23_mse_21_2noise/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d1/2026-08-10_16-09-23_mse_21_2noise
#   Final RMS χ²: 1.0498
#   RMSE: 0.1279
#   MAPE: 4.38%
# ============================================================
#
# MSE run saved: test_results/ccmm2d1/2026-08-10_16-09-23_mse_21_2noise
