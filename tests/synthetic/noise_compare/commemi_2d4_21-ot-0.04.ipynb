# %% [markdown]
# # COMMEMI 2D-4：固定静位移（TE 和 TM 有相同静位移） OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d4` 生成标准模型，
# **通过新接口固定静位移**（`static_shift_log` + `shift_station_indices`）施加静位移。
# xy 和 yx（TE/TM）在相同指定台站施加相同固定 log10 乘子 0.15。
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演，并对比。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "2"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d4",
    output_root=Path("test_results"),
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/论文绘图

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d4(
    nza=10,
    device=device, 
)

# 2) Survey setup
freqs = torch.logspace(0, -3.5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=10000,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.04,
                        noise_type="gaussian",
)

inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0],synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0348
#    phi(normalized) noise mean: 0.0255
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0349
#    phi(normalized) noise mean: 0.0255
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 4.0%)
#   - Resistivity Error Floor: 4.0%
#   - Phase Error Floor:       1.144 deg
# ✓ MSE data weights normalized (mean): scale=1.460815e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 4.0% (gaussian)
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4a) OT 反演 (6dot)
inv.initialize_model(initial_sigma=0.01)
final_sigma_ot = inv.run_inversion(
    n_epochs=300,
    mode="6dot",
    progress_interval=20,
    current_lambda=10,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("OT inversion done")
print(final_sigma_ot.min().item(), final_sigma_ot.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:02 | Remaining: ~0:07:32 | ETA: 21:33:29
#   Epoch time: 1.51s | Avg: 1.51s
#   Total: 6.8731e+02 | Data(6dot): 6.8731e+02
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 14.973 | Rough: 0.00e+00 | Lam: 10.0000000
#   OT-distance(6D, view-only): 6.873129e+01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e+01 -> 5.28e+00 (ratio=2.791e-01)
#  [Auto-Lambda] Epoch 20: Adjusted 5.28e+00 -> 4.50e+00 (ratio=7.246e-01)
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:32 | Remaining: ~0:06:58 | ETA: 21:33:25
#   Epoch time: 1.50s | Avg: 1.50s
#   Total: 3.0860e+02 | Data(6dot): 2.9024e+02
#   Misfit(RMS χ²): 11.114 | Rough: 4.08e+00 | Lam: 4.4975172
#   OT-distance(6D, view-only): 2.902370e+01
#   GradNorms: |g_d|=6.679e-01 | |λ·g_m|=4.030e-01
#  [Auto-Lambda] Epoch 30: Adjusted 4.50e+00 -> 4.04e+00 (ratio=8.052e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 4.04e+00 -> 3.19e+00 (ratio=6.247e-01)
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:03 | Remaining: ~0:06:37 | ETA: 21:33:36
#   Epoch time: 1.60s | Avg: 1.53s
#   Total: 1.3513e+02 | Data(6dot): 1.0088e+02
#   Misfit(RMS χ²): 8.098 | Rough: 1.07e+01 | Lam: 3.1897488
#   OT-distance(6D, view-only): 1.008819e+01
#   GradNorms: |g_d|=2.881e-01 | |λ·g_m|=1.870e-01
#  [Auto-Lambda] Epoch 50: Adjusted 3.19e+00 -> 2.36e+00 (ratio=5.476e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 2.36e+00 -> 1.72e+00 (ratio=5.289e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:34 | Remaining: ~0:06:08 | ETA: 21:33:39
#   Epoch time: 1.65s | Avg: 1.54s
#   Total: 6.2660e+01 | Data(6dot): 3.9821e+01
#   Misfit(RMS χ²): 4.830 | Rough: 1.33e+01 | Lam: 1.7165208
#   OT-distance(6D, view-only): 3.982145e+00
#   GradNorms: |g_d|=1.274e-01 | |λ·g_m|=9.460e-02
#  [Auto-Lambda] Epoch 70: Adjusted 1.72e+00 -> 1.13e+00 (ratio=4.354e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 1.13e+00 -> 7.43e-01 (ratio=4.298e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:06 | Remaining: ~0:05:41 | ETA: 21:33:43
#   Epoch time: 1.59s | Avg: 1.56s
#   Total: 3.1590e+01 | Data(6dot): 2.0871e+01
#   Misfit(RMS χ²): 2.378 | Rough: 1.44e+01 | Lam: 0.7425583
#   OT-distance(6D, view-only): 2.087107e+00
#   GradNorms: |g_d|=4.289e-02 | |λ·g_m|=3.688e-02
#  [Auto-Lambda] Epoch 90: Adjusted 7.43e-01 -> 5.22e-01 (ratio=4.940e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 5.22e-01 -> 3.75e-01 (ratio=5.168e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:02:39 | Remaining: ~0:05:12 | ETA: 21:33:46
#   Epoch time: 1.60s | Avg: 1.57s
#   Total: 2.1432e+01 | Data(6dot): 1.5602e+01
#   Misfit(RMS χ²): 1.547 | Rough: 1.55e+01 | Lam: 0.3751996
#   OT-distance(6D, view-only): 1.560197e+00
#   GradNorms: |g_d|=2.462e-02 | |λ·g_m|=1.842e-02
#  [Auto-Lambda] Epoch 110: Adjusted 3.75e-01 -> 2.65e-01 (ratio=4.983e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 2.65e-01 -> 1.87e-01 (ratio=4.967e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:11 | Remaining: ~0:04:42 | ETA: 21:33:49
#   Epoch time: 1.59s | Avg: 1.58s
#   Total: 1.7241e+01 | Data(6dot): 1.3958e+01
#   Misfit(RMS χ²): 1.193 | Rough: 1.76e+01 | Lam: 0.1866681
#   OT-distance(6D, view-only): 1.395823e+00
#   GradNorms: |g_d|=1.297e-02 | |λ·g_m|=9.635e-03
#  [Auto-Lambda] Epoch 130: Adjusted 1.87e-01 -> 1.33e-01 (ratio=5.050e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.33e-01 -> 9.64e-02 (ratio=5.276e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:03:43 | Remaining: ~0:04:11 | ETA: 21:33:49
#   Epoch time: 1.58s | Avg: 1.58s
#   Total: 1.5364e+01 | Data(6dot): 1.3514e+01
#   Misfit(RMS χ²): 1.121 | Rough: 1.92e+01 | Lam: 0.0963519
#   OT-distance(6D, view-only): 1.351417e+00
#   GradNorms: |g_d|=7.305e-03 | |λ·g_m|=5.093e-03
#  [Auto-Lambda] Epoch 150: Adjusted 9.64e-02 -> 7.07e-02 (ratio=5.382e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 7.07e-02 -> 5.26e-02 (ratio=5.535e-01)
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:15 | Remaining: ~0:03:39 | ETA: 21:33:50
#   Epoch time: 1.60s | Avg: 1.58s
#   Total: 1.4421e+01 | Data(6dot): 1.3348e+01
#   Misfit(RMS χ²): 1.092 | Rough: 2.04e+01 | Lam: 0.0525889
#   OT-distance(6D, view-only): 1.334782e+00
#   GradNorms: |g_d|=4.267e-03 | |λ·g_m|=2.919e-03
#  [Auto-Lambda] Epoch 170: Adjusted 5.26e-02 -> 3.97e-02 (ratio=5.713e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 3.97e-02 -> 3.07e-02 (ratio=5.973e-01)
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:04:47 | Remaining: ~0:03:08 | ETA: 21:33:50
#   Epoch time: 1.59s | Avg: 1.58s
#   Total: 1.3918e+01 | Data(6dot): 1.3257e+01
#   Misfit(RMS χ²): 1.076 | Rough: 2.15e+01 | Lam: 0.0307198
#   OT-distance(6D, view-only): 1.325689e+00
#   GradNorms: |g_d|=2.724e-03 | |λ·g_m|=1.803e-03
#  [Auto-Lambda] Epoch 190: Adjusted 3.07e-02 -> 2.43e-02 (ratio=6.245e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 2.43e-02 -> 1.95e-02 (ratio=6.475e-01)
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:05:19 | Remaining: ~0:02:36 | ETA: 21:33:51
#   Epoch time: 1.64s | Avg: 1.58s
#   Total: 1.3641e+01 | Data(6dot): 1.3199e+01
#   Misfit(RMS χ²): 1.066 | Rough: 2.26e+01 | Lam: 0.0195337
#   OT-distance(6D, view-only): 1.319919e+00
#   GradNorms: |g_d|=1.914e-03 | |λ·g_m|=1.227e-03
#  [Auto-Lambda] Epoch 210: Adjusted 1.95e-02 -> 1.60e-02 (ratio=6.697e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 1.60e-02 -> 1.34e-02 (ratio=6.981e-01)
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:05:51 | Remaining: ~0:02:05 | ETA: 21:33:52
#   Epoch time: 1.56s | Avg: 1.59s
#   Total: 1.3473e+01 | Data(6dot): 1.3156e+01
#   Misfit(RMS χ²): 1.060 | Rough: 2.37e+01 | Lam: 0.0133570
#   OT-distance(6D, view-only): 1.315574e+00
#   GradNorms: |g_d|=1.488e-03 | |λ·g_m|=9.139e-04
#  [Auto-Lambda] Epoch 230: Adjusted 1.34e-02 -> 1.14e-02 (ratio=7.292e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 1.14e-02 -> 9.96e-03 (ratio=7.622e-01)
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:06:23 | Remaining: ~0:01:33 | ETA: 21:33:51
#   Epoch time: 1.57s | Avg: 1.59s
#   Total: 1.3366e+01 | Data(6dot): 1.3115e+01
#   Misfit(RMS χ²): 1.055 | Rough: 2.52e+01 | Lam: 0.0099579
#   OT-distance(6D, view-only): 1.311483e+00
#   GradNorms: |g_d|=1.321e-03 | |λ·g_m|=7.661e-04
#  [Auto-Lambda] Epoch 250: Adjusted 9.96e-03 -> 8.85e-03 (ratio=7.897e-01)
#  [Auto-Lambda] Epoch 260: Adjusted 8.85e-03 -> 7.85e-03 (ratio=7.880e-01)
# Epoch 261/300 [  87.0%]
#   Elapsed: 0:06:54 | Remaining: ~0:01:01 | ETA: 21:33:51
#   Epoch time: 1.61s | Avg: 1.58s
#   Total: 1.3284e+01 | Data(6dot): 1.3068e+01
#   Misfit(RMS χ²): 1.050 | Rough: 2.75e+01 | Lam: 0.0078549
#   OT-distance(6D, view-only): 1.306798e+00
#   GradNorms: |g_d|=1.259e-03 | |λ·g_m|=7.204e-04
#   [Early stop] RMS χ² = 1.050 < 1.05, epoch = 263
# Inversion completed.
# OT inversion done
# 1e-10 0.10962373090038478

# %%
# 5a) OT 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.3314

# %%
# 6a) 保存 OT 结果
ot_run_dir = logger.save_from_inverter(inv, run_name="ot_0.04")
history_ot = list(inv.loss_history)
print(f"OT run saved: {ot_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d4/2026-08-18_21-33-09_ot_0.04
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.3314
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d4/2026-08-18_21-33-09_ot_0.04/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d4/2026-08-18_21-33-09_ot_0.04/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d4/2026-08-18_21-33-09_ot_0.04
#   Final RMS χ²: 1.0499
#   RMSE: 0.4683
#   MAPE: 14.36%
# ============================================================
#
# OT run saved: test_results/ccmm2d4/2026-08-18_21-33-09_ot_0.04
