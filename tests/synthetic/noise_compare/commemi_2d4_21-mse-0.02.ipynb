# %% [markdown]
# # COMMEMI 2D-4：固定静位移（TE 和 TM 有相同静位移） OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d4` 生成标准模型，
# **通过新接口固定静位移**（`static_shift_log` + `shift_station_indices`）施加静位移。
# xy 和 yx（TE/TM）在相同指定台站施加相同固定 log10 乘子 0.15。
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演，并对比。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d4",
    output_root=Path("test_results"),
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/论文绘图

# %%
import os
from pathlib import Path

print(f"当前目录: {Path.cwd()}")
print(f"目录内容: {list(Path.cwd().iterdir())}")

# 检查 src 在哪里
for p in [Path.cwd(), Path.cwd().parent, Path.cwd().parent.parent]:
    if (p / "src").exists():
        print(f"找到 src 在: {p}")
# Out:
# 当前目录: /home/liuxr/论文绘图/experiment/synthetic/noise_compare
# 目录内容: [PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/.ipynb_checkpoints'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-mse-0.01.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-mse-0.04.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-ot-0.02.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-mse-0.02.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-mse-0.02.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/test_results1'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-mse-scale=500-Copy1.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-mse-0.04.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-ot-0.04.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-ot-0.01.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-mse-0.01.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-ot-0.01.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/test_results'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-ot-0.04.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-ot-0.02.ipynb')]

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d4(
    nza=10,
    device=device, 
)

# 2) Survey setup
freqs = torch.logspace(0, -3.5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=300,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.02,
                        noise_type="gaussian",
)

inv.noise_floor = 0.043
inv._build_rms_chi2_cache()
inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0],synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0174
#    phi(normalized) noise mean: 0.0127
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0174
#    phi(normalized) noise mean: 0.0127
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 2.0%)
#   - Resistivity Error Floor: 2.0%
#   - Phase Error Floor:       0.572 deg
# ✓ MSE data weights normalized (mean): scale=2.921162e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 2.0% (gaussian)
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4b) MSE 反演（同一静位移观测数据，重置初模）
inv.initialize_model(initial_sigma=0.01)
final_sigma_mse = inv.run_inversion(
    n_epochs=300,
    mode="mse",
    progress_interval=20,
    current_lambda=10,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("MSE inversion done")
print(final_sigma_mse.min().item(), final_sigma_mse.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:02 | Remaining: ~0:07:36 | ETA: 21:34:03
#   Epoch time: 1.53s | Avg: 1.53s
#   Total: 3.1239e+02 | Data(mse): 3.1239e+02
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 27.707 | Rough: 0.00e+00 | Lam: 10.0000000
#   OT-distance(6D, view-only): 6.787059e+01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e+01 -> 4.49e+00 (ratio=2.012e-01)
#  [Auto-Lambda] Epoch 20: Adjusted 4.49e+00 -> 3.61e+00 (ratio=6.461e-01)
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:32 | Remaining: ~0:06:58 | ETA: 21:33:56
#   Epoch time: 1.54s | Avg: 1.50s
#   Total: 1.4778e+02 | Data(mse): 1.3930e+02
#   Misfit(RMS χ²): 18.494 | Rough: 2.35e+00 | Lam: 3.6055180
#   OT-distance(6D, view-only): 4.238621e+01
#   GradNorms: |g_d|=4.818e-01 | |λ·g_m|=3.025e-01
#  [Auto-Lambda] Epoch 30: Adjusted 3.61e+00 -> 3.27e+00 (ratio=8.209e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 3.27e+00 -> 2.75e+00 (ratio=7.086e-01)
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:02 | Remaining: ~0:06:29 | ETA: 21:33:57
#   Epoch time: 1.53s | Avg: 1.50s
#   Total: 6.7754e+01 | Data(mse): 5.0950e+01
#   Misfit(RMS χ²): 11.182 | Rough: 6.11e+00 | Lam: 2.7498249
#   OT-distance(6D, view-only): 2.433436e+01
#   GradNorms: |g_d|=2.859e-01 | |λ·g_m|=1.842e-01
#  [Auto-Lambda] Epoch 50: Adjusted 2.75e+00 -> 2.05e+00 (ratio=5.572e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 2.05e+00 -> 1.32e+00 (ratio=4.134e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:32 | Remaining: ~0:06:00 | ETA: 21:33:58
#   Epoch time: 1.50s | Avg: 1.51s
#   Total: 2.6857e+01 | Data(mse): 1.5367e+01
#   Misfit(RMS χ²): 6.144 | Rough: 8.71e+00 | Lam: 1.3198414
#   OT-distance(6D, view-only): 1.112666e+01
#   GradNorms: |g_d|=1.141e-01 | |λ·g_m|=9.317e-02
#  [Auto-Lambda] Epoch 70: Adjusted 1.32e+00 -> 8.45e-01 (ratio=4.097e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 8.45e-01 -> 5.98e-01 (ratio=5.015e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:02 | Remaining: ~0:05:29 | ETA: 21:33:57
#   Epoch time: 1.45s | Avg: 1.50s
#   Total: 1.0340e+01 | Data(mse): 4.8203e+00
#   Misfit(RMS χ²): 3.443 | Rough: 9.23e+00 | Lam: 0.5982897
#   OT-distance(6D, view-only): 4.359910e+00
#   GradNorms: |g_d|=4.496e-02 | |λ·g_m|=3.126e-02
#  [Auto-Lambda] Epoch 90: Adjusted 5.98e-01 -> 4.31e-01 (ratio=5.200e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 4.31e-01 -> 3.10e-01 (ratio=5.171e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:02:32 | Remaining: ~0:04:58 | ETA: 21:33:56
#   Epoch time: 1.44s | Avg: 1.50s
#   Total: 5.3958e+00 | Data(mse): 2.3391e+00
#   Misfit(RMS χ²): 2.399 | Rough: 9.85e+00 | Lam: 0.3102308
#   OT-distance(6D, view-only): 2.435918e+00
#   GradNorms: |g_d|=2.089e-02 | |λ·g_m|=1.467e-02
#  [Auto-Lambda] Epoch 110: Adjusted 3.10e-01 -> 2.23e-01 (ratio=5.176e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 2.23e-01 -> 1.66e-01 (ratio=5.509e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:02 | Remaining: ~0:04:28 | ETA: 21:33:56
#   Epoch time: 1.50s | Avg: 1.50s
#   Total: 3.3487e+00 | Data(mse): 1.4917e+00
#   Misfit(RMS χ²): 1.916 | Rough: 1.12e+01 | Lam: 0.1656608
#   OT-distance(6D, view-only): 1.616819e+00
#   GradNorms: |g_d|=1.196e-02 | |λ·g_m|=8.010e-03
#  [Auto-Lambda] Epoch 130: Adjusted 1.66e-01 -> 1.26e-01 (ratio=5.751e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.26e-01 -> 9.63e-02 (ratio=5.874e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:03:32 | Remaining: ~0:03:58 | ETA: 21:33:55
#   Epoch time: 1.53s | Avg: 1.50s
#   Total: 2.2897e+00 | Data(mse): 1.0552e+00
#   Misfit(RMS χ²): 1.612 | Rough: 1.28e+01 | Lam: 0.0962846
#   OT-distance(6D, view-only): 1.138349e+00
#   GradNorms: |g_d|=7.299e-03 | |λ·g_m|=4.877e-03
#  [Auto-Lambda] Epoch 150: Adjusted 9.63e-02 -> 7.39e-02 (ratio=5.894e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 7.39e-02 -> 5.77e-02 (ratio=6.091e-01)
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:02 | Remaining: ~0:03:28 | ETA: 21:33:56
#   Epoch time: 1.52s | Avg: 1.50s
#   Total: 1.6303e+00 | Data(mse): 7.9477e-01
#   Misfit(RMS χ²): 1.399 | Rough: 1.45e+01 | Lam: 0.0576916
#   OT-distance(6D, view-only): 8.428798e-01
#   GradNorms: |g_d|=4.649e-03 | |λ·g_m|=3.067e-03
#  [Auto-Lambda] Epoch 170: Adjusted 5.77e-02 -> 4.53e-02 (ratio=6.178e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 4.53e-02 -> 3.60e-02 (ratio=6.316e-01)
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:04:32 | Remaining: ~0:02:58 | ETA: 21:33:57
#   Epoch time: 1.53s | Avg: 1.50s
#   Total: 1.2188e+00 | Data(mse): 6.4006e-01
#   Misfit(RMS χ²): 1.255 | Rough: 1.61e+01 | Lam: 0.0360385
#   OT-distance(6D, view-only): 6.623851e-01
#   GradNorms: |g_d|=3.182e-03 | |λ·g_m|=2.004e-03
#  [Auto-Lambda] Epoch 190: Adjusted 3.60e-02 -> 2.89e-02 (ratio=6.434e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 2.89e-02 -> 2.46e-02 (ratio=7.217e-01)
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:05:03 | Remaining: ~0:02:29 | ETA: 21:33:57
#   Epoch time: 1.57s | Avg: 1.51s
#   Total: 9.7971e-01 | Data(mse): 5.5162e-01
#   Misfit(RMS χ²): 1.165 | Rough: 1.74e+01 | Lam: 0.0245578
#   OT-distance(6D, view-only): 5.633783e-01
#   GradNorms: |g_d|=2.412e-03 | |λ·g_m|=1.412e-03
#  [Auto-Lambda] Epoch 210: Adjusted 2.46e-02 -> 1.99e-02 (ratio=6.594e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 1.99e-02 -> 1.80e-02 (ratio=8.166e-01)
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:05:33 | Remaining: ~0:01:58 | ETA: 21:33:57
#   Epoch time: 1.48s | Avg: 1.51s
#   Total: 8.3505e-01 | Data(mse): 5.0059e-01
#   Misfit(RMS χ²): 1.110 | Rough: 1.86e+01 | Lam: 0.0180205
#   OT-distance(6D, view-only): 5.007753e-01
#   GradNorms: |g_d|=1.902e-03 | |λ·g_m|=1.066e-03
#  [Auto-Lambda] Epoch 230: Adjusted 1.80e-02 -> 1.53e-02 (ratio=7.174e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 1.53e-02 -> 1.26e-02 (ratio=6.807e-01)
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:06:03 | Remaining: ~0:01:28 | ETA: 21:33:57
#   Epoch time: 1.47s | Avg: 1.50s
#   Total: 7.1571e-01 | Data(mse): 4.7117e-01
#   Misfit(RMS χ²): 1.077 | Rough: 1.94e+01 | Lam: 0.0125934
#   OT-distance(6D, view-only): 4.641429e-01
#   GradNorms: |g_d|=1.240e-03 | |λ·g_m|=7.555e-04
#  [Auto-Lambda] Epoch 260: Adjusted 1.26e-02 -> 1.04e-02 (ratio=6.804e-01)
# Epoch 261/300 [  87.0%]
#   Elapsed: 0:06:32 | Remaining: ~0:00:58 | ETA: 21:33:56
#   Epoch time: 1.50s | Avg: 1.50s
#   Total: 6.6155e-01 | Data(mse): 4.5240e-01
#   Misfit(RMS χ²): 1.056 | Rough: 2.01e+01 | Lam: 0.0103880
#   OT-distance(6D, view-only): 4.396173e-01
#   GradNorms: |g_d|=1.050e-03 | |λ·g_m|=6.329e-04
#   [Early stop] RMS χ² = 1.050 < 1.05, epoch = 268
# Inversion completed.
# MSE inversion done
# 1e-10 0.07242880511001325

# %%
# 5b) MSE 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.3154

# %%
mse_run_dir = logger.save_from_inverter(inv, run_name="mse_0.02")
history_mse = list(inv.loss_history)
print(f"MSE run saved: {mse_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d4/2026-08-18_21-33-25_mse_0.02
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.3154
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d4/2026-08-18_21-33-25_mse_0.02/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d4/2026-08-18_21-33-25_mse_0.02/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d4/2026-08-18_21-33-25_mse_0.02
#   Final RMS χ²: 1.0495
#   RMSE: 0.4905
#   MAPE: 15.09%
# ============================================================
#
# MSE run saved: test_results/ccmm2d4/2026-08-18_21-33-25_mse_0.02
