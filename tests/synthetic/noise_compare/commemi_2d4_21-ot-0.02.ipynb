# %% [markdown]
# # COMMEMI 2D-4：固定静位移（TE 和 TM 有相同静位移） OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d4` 生成标准模型，
# **通过新接口固定静位移**（`static_shift_log` + `shift_station_indices`）施加静位移。
# xy 和 yx（TE/TM）在相同指定台站施加相同固定 log10 乘子 0.15。
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演，并对比。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "2"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d4",
    output_root=Path("test_results"),
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/论文绘图

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d4(
    nza=10,
    device=device, 
)

# 2) Survey setup
freqs = torch.logspace(0, -3.5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=20000,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.02,
                        noise_type="gaussian",
)

inv.noise_floor = 0.043
inv._build_rms_chi2_cache()
inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0],synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0174
#    phi(normalized) noise mean: 0.0127
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0174
#    phi(normalized) noise mean: 0.0127
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 2.0%)
#   - Resistivity Error Floor: 2.0%
#   - Phase Error Floor:       0.572 deg
# ✓ MSE data weights normalized (mean): scale=2.921162e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 2.0% (gaussian)
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4a) OT 反演 (6dot)
inv.initialize_model(initial_sigma=0.01)
final_sigma_ot = inv.run_inversion(
    n_epochs=300,
    mode="6dot",
    progress_interval=20,
    current_lambda=10,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("OT inversion done")
print(final_sigma_ot.min().item(), final_sigma_ot.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:02 | Remaining: ~0:07:30 | ETA: 21:33:03
#   Epoch time: 1.51s | Avg: 1.51s
#   Total: 1.3574e+03 | Data(6dot): 1.3574e+03
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 27.707 | Rough: 0.00e+00 | Lam: 10.0000000
#   OT-distance(6D, view-only): 6.787059e+01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e+01 -> 7.83e+00 (ratio=6.124e-01)
#  [Auto-Lambda] Epoch 20: Adjusted 7.83e+00 -> 7.33e+00 (ratio=8.780e-01)
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:31 | Remaining: ~0:06:52 | ETA: 21:32:55
#   Epoch time: 1.48s | Avg: 1.48s
#   Total: 5.7297e+02 | Data(6dot): 5.3756e+02
#   Misfit(RMS χ²): 20.246 | Rough: 4.83e+00 | Lam: 7.3327906
#   OT-distance(6D, view-only): 2.687811e+01
#   GradNorms: |g_d|=1.266e+00 | |λ·g_m|=5.900e-01
#  [Auto-Lambda] Epoch 40: Adjusted 7.33e+00 -> 5.92e+00 (ratio=6.523e-01)
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:02 | Remaining: ~0:06:31 | ETA: 21:33:05
#   Epoch time: 1.56s | Avg: 1.51s
#   Total: 2.4356e+02 | Data(6dot): 1.7913e+02
#   Misfit(RMS χ²): 14.770 | Rough: 1.09e+01 | Lam: 5.9222483
#   OT-distance(6D, view-only): 8.956346e+00
#   GradNorms: |g_d|=5.475e-01 | |λ·g_m|=3.489e-01
#  [Auto-Lambda] Epoch 50: Adjusted 5.92e+00 -> 4.44e+00 (ratio=5.611e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 4.44e+00 -> 3.19e+00 (ratio=5.172e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:34 | Remaining: ~0:06:06 | ETA: 21:33:12
#   Epoch time: 1.63s | Avg: 1.53s
#   Total: 1.0161e+02 | Data(6dot): 6.0033e+01
#   Misfit(RMS χ²): 8.751 | Rough: 1.30e+01 | Lam: 3.1902074
#   OT-distance(6D, view-only): 3.001672e+00
#   GradNorms: |g_d|=2.424e-01 | |λ·g_m|=1.779e-01
#  [Auto-Lambda] Epoch 70: Adjusted 3.19e+00 -> 2.04e+00 (ratio=4.082e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 2.04e+00 -> 1.31e+00 (ratio=4.111e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:06 | Remaining: ~0:05:40 | ETA: 21:33:18
#   Epoch time: 1.63s | Avg: 1.55s
#   Total: 4.1221e+01 | Data(6dot): 2.2109e+01
#   Misfit(RMS χ²): 4.109 | Rough: 1.46e+01 | Lam: 1.3067550
#   OT-distance(6D, view-only): 1.105473e+00
#   GradNorms: |g_d|=8.843e-02 | |λ·g_m|=7.406e-02
#  [Auto-Lambda] Epoch 90: Adjusted 1.31e+00 -> 8.83e-01 (ratio=4.565e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 8.83e-01 -> 6.05e-01 (ratio=4.696e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:02:39 | Remaining: ~0:05:11 | ETA: 21:33:22
#   Epoch time: 1.62s | Avg: 1.57s
#   Total: 2.0758e+01 | Data(6dot): 1.0946e+01
#   Misfit(RMS χ²): 2.219 | Rough: 1.62e+01 | Lam: 0.6050636
#   OT-distance(6D, view-only): 5.473154e-01
#   GradNorms: |g_d|=5.009e-02 | |λ·g_m|=3.564e-02
#  [Auto-Lambda] Epoch 110: Adjusted 6.05e-01 -> 4.06e-01 (ratio=4.496e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 4.06e-01 -> 2.62e-01 (ratio=4.179e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:11 | Remaining: ~0:04:41 | ETA: 21:33:24
#   Epoch time: 1.67s | Avg: 1.57s
#   Total: 1.2620e+01 | Data(6dot): 7.6951e+00
#   Misfit(RMS χ²): 1.281 | Rough: 1.88e+01 | Lam: 0.2622609
#   OT-distance(6D, view-only): 3.847559e-01
#   GradNorms: |g_d|=1.908e-02 | |λ·g_m|=1.377e-02
#  [Auto-Lambda] Epoch 130: Adjusted 2.62e-01 -> 1.83e-01 (ratio=4.876e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.83e-01 -> 1.38e-01 (ratio=5.698e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:03:43 | Remaining: ~0:04:11 | ETA: 21:33:26
#   Epoch time: 1.61s | Avg: 1.58s
#   Total: 1.0011e+01 | Data(6dot): 7.2525e+00
#   Misfit(RMS χ²): 1.191 | Rough: 2.00e+01 | Lam: 0.1382416
#   OT-distance(6D, view-only): 3.626238e-01
#   GradNorms: |g_d|=1.170e-02 | |λ·g_m|=7.124e-03
#  [Auto-Lambda] Epoch 150: Adjusted 1.38e-01 -> 1.08e-01 (ratio=6.073e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 1.08e-01 -> 8.10e-02 (ratio=5.649e-01)
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:15 | Remaining: ~0:03:40 | ETA: 21:33:27
#   Epoch time: 1.56s | Avg: 1.58s
#   Total: 8.7656e+00 | Data(6dot): 7.0711e+00
#   Misfit(RMS χ²): 1.137 | Rough: 2.09e+01 | Lam: 0.0809710
#   OT-distance(6D, view-only): 3.535556e-01
#   GradNorms: |g_d|=7.082e-03 | |λ·g_m|=4.315e-03
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:04:47 | Remaining: ~0:03:08 | ETA: 21:33:27
#   Epoch time: 1.62s | Avg: 1.58s
#   Total: 8.7267e+00 | Data(6dot): 6.9641e+00
#   Misfit(RMS χ²): 1.102 | Rough: 2.18e+01 | Lam: 0.0809710
#   OT-distance(6D, view-only): 3.482034e-01
#   GradNorms: |g_d|=6.281e-03 | |λ·g_m|=4.413e-03
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:05:19 | Remaining: ~0:02:36 | ETA: 21:33:27
#   Epoch time: 1.57s | Avg: 1.59s
#   Total: 8.7113e+00 | Data(6dot): 6.9259e+00
#   Misfit(RMS χ²): 1.094 | Rough: 2.20e+01 | Lam: 0.0809710
#   OT-distance(6D, view-only): 3.462966e-01
#   GradNorms: |g_d|=7.744e-03 | |λ·g_m|=4.410e-03
#  [Auto-Lambda] Epoch 210: Adjusted 8.10e-02 -> 5.97e-02 (ratio=5.429e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 5.97e-02 -> 4.59e-02 (ratio=5.915e-01)
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:05:51 | Remaining: ~0:02:05 | ETA: 21:33:28
#   Epoch time: 1.60s | Avg: 1.59s
#   Total: 7.9157e+00 | Data(6dot): 6.8829e+00
#   Misfit(RMS χ²): 1.082 | Rough: 2.25e+01 | Lam: 0.0458870
#   OT-distance(6D, view-only): 3.441474e-01
#   GradNorms: |g_d|=4.169e-03 | |λ·g_m|=2.575e-03
#  [Auto-Lambda] Epoch 230: Adjusted 4.59e-02 -> 4.09e-02 (ratio=7.939e-01)
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:06:23 | Remaining: ~0:01:33 | ETA: 21:33:28
#   Epoch time: 1.61s | Avg: 1.59s
#   Total: 7.7750e+00 | Data(6dot): 6.8100e+00
#   Misfit(RMS χ²): 1.056 | Rough: 2.36e+01 | Lam: 0.0408869
#   OT-distance(6D, view-only): 3.405020e-01
#   GradNorms: |g_d|=1.949e-02 | |λ·g_m|=2.428e-03
#   [Early stop] RMS χ² = 1.050 < 1.05, epoch = 247
# Inversion completed.
# OT inversion done
# 1e-10 0.10350590182916761

# %%
# 5a) OT 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.3585

# %%
# 6a) 保存 OT 结果
ot_run_dir = logger.save_from_inverter(inv, run_name="ot_0.02")
history_ot = list(inv.loss_history)
print(f"OT run saved: {ot_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d4/2026-08-18_21-32-21_ot_0.02
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.3585
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d4/2026-08-18_21-32-21_ot_0.02/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d4/2026-08-18_21-32-21_ot_0.02/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d4/2026-08-18_21-32-21_ot_0.02
#   Final RMS χ²: 1.0498
#   RMSE: 0.4539
#   MAPE: 13.60%
# ============================================================
#
# OT run saved: test_results/ccmm2d4/2026-08-18_21-32-21_ot_0.02
