# %% [markdown]
# # COMMEMI 2D-4：固定静位移（TE 和 TM 有相同静位移） OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d4` 生成标准模型，
# **通过新接口固定静位移**（`static_shift_log` + `shift_station_indices`）施加静位移。
# xy 和 yx（TE/TM）在相同指定台站施加相同固定 log10 乘子 0.15。
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演，并对比。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)
logger = ExperimentLogger(
    model_tag="ccmm2d4",
    output_root=Path("test_results"),
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/论文绘图

# %%
import os
from pathlib import Path

print(f"当前目录: {Path.cwd()}")
print(f"目录内容: {list(Path.cwd().iterdir())}")

# 检查 src 在哪里
for p in [Path.cwd(), Path.cwd().parent, Path.cwd().parent.parent]:
    if (p / "src").exists():
        print(f"找到 src 在: {p}")
# Out:
# 当前目录: /home/liuxr/论文绘图/experiment/synthetic/noise_compare
# 目录内容: [PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/.ipynb_checkpoints'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-mse-0.01.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-mse-0.04.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-ot-0.02.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-mse-0.02.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-mse-0.02.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/test_results1'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-mse-scale=500-Copy1.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-mse-0.04.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-ot-0.04.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-ot-0.01.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-mse-0.01.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-ot-0.01.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/test_results'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d1_21-ot-0.04.ipynb'), PosixPath('/home/liuxr/论文绘图/experiment/synthetic/noise_compare/commemi_2d4_21-ot-0.02.ipynb')]

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d4(
    nza=10,
    device=device, 
)

# 2) Survey setup
freqs = torch.logspace(0, -3.5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=300,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.04,
                        noise_type="gaussian",
)

inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0],synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0348
#    phi(normalized) noise mean: 0.0255
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0349
#    phi(normalized) noise mean: 0.0255
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 4.0%)
#   - Resistivity Error Floor: 4.0%
#   - Phase Error Floor:       1.144 deg
# ✓ MSE data weights normalized (mean): scale=1.460815e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 4.0% (gaussian)
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4b) MSE 反演（同一静位移观测数据，重置初模）
inv.initialize_model(initial_sigma=0.01)
final_sigma_mse = inv.run_inversion(
    n_epochs=500,
    mode="mse",
    progress_interval=20,
    current_lambda=10,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("MSE inversion done")
print(final_sigma_mse.min().item(), final_sigma_mse.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/500 [   0.2%]
#   Elapsed: 0:00:02 | Remaining: ~0:12:46 | ETA: 21:39:25
#   Epoch time: 1.54s | Avg: 1.54s
#   Total: 3.1516e+02 | Data(mse): 3.1516e+02
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 14.973 | Rough: 0.00e+00 | Lam: 10.0000000
#   OT-distance(6D, view-only): 6.873129e+01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e+01 -> 4.48e+00 (ratio=2.007e-01)
#  [Auto-Lambda] Epoch 20: Adjusted 4.48e+00 -> 3.60e+00 (ratio=6.443e-01)
# Epoch 21/500 [   4.2%]
#   Elapsed: 0:00:31 | Remaining: ~0:11:46 | ETA: 21:38:54
#   Epoch time: 1.45s | Avg: 1.47s
#   Total: 1.4988e+02 | Data(mse): 1.4141e+02
#   Misfit(RMS χ²): 10.030 | Rough: 2.35e+00 | Lam: 3.5955180
#   OT-distance(6D, view-only): 4.326179e+01
#   GradNorms: |g_d|=4.862e-01 | |λ·g_m|=3.040e-01
#  [Auto-Lambda] Epoch 30: Adjusted 3.60e+00 -> 3.25e+00 (ratio=8.194e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 3.25e+00 -> 2.83e+00 (ratio=7.565e-01)
# Epoch 41/500 [   8.2%]
#   Elapsed: 0:01:01 | Remaining: ~0:11:23 | ETA: 21:39:01
#   Epoch time: 1.53s | Avg: 1.49s
#   Total: 6.9794e+01 | Data(mse): 5.2469e+01
#   Misfit(RMS χ²): 6.109 | Rough: 6.12e+00 | Lam: 2.8307908
#   OT-distance(6D, view-only): 2.523688e+01
#   GradNorms: |g_d|=2.905e-01 | |λ·g_m|=1.718e-01
#  [Auto-Lambda] Epoch 50: Adjusted 2.83e+00 -> 2.11e+00 (ratio=5.538e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 2.11e+00 -> 1.36e+00 (ratio=4.160e-01)
# Epoch 61/500 [  12.2%]
#   Elapsed: 0:01:31 | Remaining: ~0:10:54 | ETA: 21:39:02
#   Epoch time: 1.49s | Avg: 1.49s
#   Total: 2.8269e+01 | Data(mse): 1.6597e+01
#   Misfit(RMS χ²): 3.436 | Rough: 8.59e+00 | Lam: 1.3586856
#   OT-distance(6D, view-only): 1.213047e+01
#   GradNorms: |g_d|=1.178e-01 | |λ·g_m|=9.531e-02
#  [Auto-Lambda] Epoch 70: Adjusted 1.36e+00 -> 8.74e-01 (ratio=4.134e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 8.74e-01 -> 6.21e-01 (ratio=5.047e-01)
# Epoch 81/500 [  16.2%]
#   Elapsed: 0:02:01 | Remaining: ~0:10:25 | ETA: 21:39:03
#   Epoch time: 1.50s | Avg: 1.49s
#   Total: 1.1545e+01 | Data(mse): 5.9506e+00
#   Misfit(RMS χ²): 2.057 | Rough: 9.02e+00 | Lam: 0.6205772
#   OT-distance(6D, view-only): 5.376193e+00
#   GradNorms: |g_d|=4.517e-02 | |λ·g_m|=3.195e-02
#  [Auto-Lambda] Epoch 90: Adjusted 6.21e-01 -> 4.46e-01 (ratio=5.158e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 4.46e-01 -> 3.19e-01 (ratio=5.124e-01)
# Epoch 101/500 [  20.2%]
#   Elapsed: 0:02:31 | Remaining: ~0:09:56 | ETA: 21:39:04
#   Epoch time: 1.58s | Avg: 1.49s
#   Total: 6.5147e+00 | Data(mse): 3.4443e+00
#   Misfit(RMS χ²): 1.565 | Rough: 9.62e+00 | Lam: 0.3190299
#   OT-distance(6D, view-only): 3.448307e+00
#   GradNorms: |g_d|=2.083e-02 | |λ·g_m|=1.476e-02
#  [Auto-Lambda] Epoch 110: Adjusted 3.19e-01 -> 2.29e-01 (ratio=5.161e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 2.29e-01 -> 1.70e-01 (ratio=5.513e-01)
# Epoch 121/500 [  24.2%]
#   Elapsed: 0:03:01 | Remaining: ~0:09:25 | ETA: 21:39:03
#   Epoch time: 1.51s | Avg: 1.49s
#   Total: 4.4558e+00 | Data(mse): 2.5856e+00
#   Misfit(RMS χ²): 1.356 | Rough: 1.10e+01 | Lam: 0.1701701
#   OT-distance(6D, view-only): 2.622181e+00
#   GradNorms: |g_d|=1.201e-02 | |λ·g_m|=8.063e-03
#  [Auto-Lambda] Epoch 130: Adjusted 1.70e-01 -> 1.29e-01 (ratio=5.752e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.29e-01 -> 9.88e-02 (ratio=5.865e-01)
# Epoch 141/500 [  28.2%]
#   Elapsed: 0:03:32 | Remaining: ~0:08:57 | ETA: 21:39:05
#   Epoch time: 1.48s | Avg: 1.50s
#   Total: 3.3861e+00 | Data(mse): 2.1396e+00
#   Misfit(RMS χ²): 1.234 | Rough: 1.26e+01 | Lam: 0.0988310
#   OT-distance(6D, view-only): 2.136200e+00
#   GradNorms: |g_d|=7.421e-03 | |λ·g_m|=4.942e-03
#  [Auto-Lambda] Epoch 150: Adjusted 9.88e-02 -> 7.59e-02 (ratio=5.897e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 7.59e-02 -> 5.85e-02 (ratio=5.943e-01)
# Epoch 161/500 [  32.2%]
#   Elapsed: 0:04:02 | Remaining: ~0:08:28 | ETA: 21:39:06
#   Epoch time: 1.45s | Avg: 1.50s
#   Total: 2.7190e+00 | Data(mse): 1.8882e+00
#   Misfit(RMS χ²): 1.159 | Rough: 1.42e+01 | Lam: 0.0585093
#   OT-distance(6D, view-only): 1.857451e+00
#   GradNorms: |g_d|=4.632e-03 | |λ·g_m|=3.072e-03
#  [Auto-Lambda] Epoch 170: Adjusted 5.85e-02 -> 4.59e-02 (ratio=6.145e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 4.59e-02 -> 3.66e-02 (ratio=6.378e-01)
# Epoch 181/500 [  36.2%]
#   Elapsed: 0:04:32 | Remaining: ~0:07:57 | ETA: 21:39:06
#   Epoch time: 1.45s | Avg: 1.50s
#   Total: 2.3113e+00 | Data(mse): 1.7331e+00
#   Misfit(RMS χ²): 1.110 | Rough: 1.58e+01 | Lam: 0.0366307
#   OT-distance(6D, view-only): 1.677168e+00
#   GradNorms: |g_d|=3.234e-03 | |λ·g_m|=2.020e-03
#  [Auto-Lambda] Epoch 190: Adjusted 3.66e-02 -> 3.35e-02 (ratio=8.372e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 3.35e-02 -> 2.70e-02 (ratio=6.488e-01)
# Epoch 201/500 [  40.2%]
#   Elapsed: 0:05:02 | Remaining: ~0:07:27 | ETA: 21:39:06
#   Epoch time: 1.49s | Avg: 1.50s
#   Total: 2.1055e+00 | Data(mse): 1.6442e+00
#   Misfit(RMS χ²): 1.081 | Rough: 1.71e+01 | Lam: 0.0269958
#   OT-distance(6D, view-only): 1.573846e+00
#   GradNorms: |g_d|=2.365e-03 | |λ·g_m|=1.529e-03
#  [Auto-Lambda] Epoch 210: Adjusted 2.70e-02 -> 2.23e-02 (ratio=6.851e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 2.23e-02 -> 1.86e-02 (ratio=6.897e-01)
# Epoch 221/500 [  44.2%]
#   Elapsed: 0:05:32 | Remaining: ~0:06:58 | ETA: 21:39:06
#   Epoch time: 1.54s | Avg: 1.50s
#   Total: 1.9289e+00 | Data(mse): 1.5929e+00
#   Misfit(RMS χ²): 1.064 | Rough: 1.81e+01 | Lam: 0.0185578
#   OT-distance(6D, view-only): 1.510502e+00
#   GradNorms: |g_d|=1.807e-03 | |λ·g_m|=1.077e-03
#  [Auto-Lambda] Epoch 230: Adjusted 1.86e-02 -> 1.56e-02 (ratio=7.046e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 1.56e-02 -> 1.32e-02 (ratio=7.181e-01)
# Epoch 241/500 [  48.2%]
#   Elapsed: 0:06:01 | Remaining: ~0:06:27 | ETA: 21:39:05
#   Epoch time: 1.47s | Avg: 1.50s
#   Total: 1.8105e+00 | Data(mse): 1.5587e+00
#   Misfit(RMS χ²): 1.053 | Rough: 1.91e+01 | Lam: 0.0132001
#   OT-distance(6D, view-only): 1.465587e+00
#   GradNorms: |g_d|=1.334e-03 | |λ·g_m|=7.908e-04
#   [Early stop] RMS χ² = 1.050 < 1.05, epoch = 247
# Inversion completed.
# MSE inversion done
# 1e-10 0.08306192514038387

# %%
# 5b) MSE 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.3133

# %%
mse_run_dir = logger.save_from_inverter(inv, run_name="mse_0.04")
history_mse = list(inv.loss_history)
print(f"MSE run saved: {mse_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d4/2026-08-18_21-33-03_mse_0.04
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.3133
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d4/2026-08-18_21-33-03_mse_0.04/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d4/2026-08-18_21-33-03_mse_0.04/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d4/2026-08-18_21-33-03_mse_0.04
#   Final RMS χ²: 1.0499
#   RMSE: 0.4980
#   MAPE: 15.52%
# ============================================================
#
# MSE run saved: test_results/ccmm2d4/2026-08-18_21-33-03_mse_0.04
