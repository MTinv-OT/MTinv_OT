# %% [markdown]
# # COMMEMI 2D-1：固定静位移（TE 和 TM 有相同静位移） OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d1` 生成标准模型，
# **通过新接口固定静位移**（`static_shift_log` + `shift_station_indices`）施加静位移。
# xy 和 yx（TE/TM）在相同指定台站施加相同固定 log10 乘子 0.15。
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演，并对比。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d1",
    output_root=Path("test_results"),
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/论文绘图

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d1(
    zn=None,
    yn=None,
    nza=10,
    device=device,
    rho_host=100.0,
    rho_block=10.0,
    y_half_width_m=2000.0,
    z_top_m=10000.0,
    z_bottom_m=30000.0,
)

# 2) Survey setup
freqs = torch.logspace(0, -3.5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=10000,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.02,
                        noise_type="gaussian",
                        )

inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0],synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0174
#    phi(normalized) noise mean: 0.0127
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0174
#    phi(normalized) noise mean: 0.0127
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 2.0%)
#   - Resistivity Error Floor: 2.0%
#   - Phase Error Floor:       0.572 deg
# ✓ MSE data weights normalized (mean): scale=2.921499e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 2.0% (gaussian)
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4a) OT 反演 (6dot)
inv.initialize_model(initial_sigma=0.01)
final_sigma_ot = inv.run_inversion(
    n_epochs=300,
    mode="6dot",
    progress_interval=20,
    current_lambda=0.3,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("OT inversion done")
print(final_sigma_ot.min().item(), final_sigma_ot.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:02 | Remaining: ~0:08:05 | ETA: 16:06:35
#   Epoch time: 1.62s | Avg: 1.62s
#   Total: 1.4108e+01 | Data(6dot): 1.4108e+01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 2.698 | Rough: 0.00e+00 | Lam: 0.3000000
#   OT-distance(6D, view-only): 1.410803e+00
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 3.00e-01 -> 2.61e-01 (ratio=7.594e-01)
#  [Auto-Lambda] Epoch 20: Adjusted 2.61e-01 -> 1.88e-01 (ratio=5.193e-01)
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:33 | Remaining: ~0:07:12 | ETA: 16:06:13
#   Epoch time: 1.80s | Avg: 1.55s
#   Total: 4.3895e+00 | Data(6dot): 4.1304e+00
#   Misfit(RMS χ²): 1.317 | Rough: 1.38e+00 | Lam: 0.1884057
#   OT-distance(6D, view-only): 4.130450e-01
#   GradNorms: |g_d|=1.338e-02 | |λ·g_m|=1.302e-02
#  [Auto-Lambda] Epoch 30: Adjusted 1.88e-01 -> 1.05e-01 (ratio=3.117e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 1.05e-01 -> 8.26e-02 (ratio=6.167e-01)
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:04 | Remaining: ~0:06:41 | ETA: 16:06:13
#   Epoch time: 1.60s | Avg: 1.55s
#   Total: 3.9781e+00 | Data(6dot): 3.8280e+00
#   Misfit(RMS χ²): 1.256 | Rough: 1.82e+00 | Lam: 0.0826006
#   OT-distance(6D, view-only): 3.828017e-01
#   GradNorms: |g_d|=6.099e-03 | |λ·g_m|=3.224e-03
#  [Auto-Lambda] Epoch 50: Adjusted 8.26e-02 -> 7.80e-02 (ratio=8.914e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 7.80e-02 -> 6.76e-02 (ratio=7.509e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:34 | Remaining: ~0:06:08 | ETA: 16:06:11
#   Epoch time: 1.50s | Avg: 1.54s
#   Total: 3.8956e+00 | Data(6dot): 3.7394e+00
#   Misfit(RMS χ²): 1.199 | Rough: 2.31e+00 | Lam: 0.0675775
#   OT-distance(6D, view-only): 3.739371e-01
#   GradNorms: |g_d|=3.665e-03 | |λ·g_m|=2.106e-03
#  [Auto-Lambda] Epoch 70: Adjusted 6.76e-02 -> 4.96e-02 (ratio=5.393e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 4.96e-02 -> 3.84e-02 (ratio=5.995e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:05 | Remaining: ~0:05:38 | ETA: 16:06:12
#   Epoch time: 1.49s | Avg: 1.54s
#   Total: 3.7949e+00 | Data(6dot): 3.6798e+00
#   Misfit(RMS χ²): 1.189 | Rough: 3.00e+00 | Lam: 0.0384267
#   OT-distance(6D, view-only): 3.679826e-01
#   GradNorms: |g_d|=1.969e-03 | |λ·g_m|=1.331e-03
#  [Auto-Lambda] Epoch 90: Adjusted 3.84e-02 -> 3.10e-02 (ratio=6.497e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 3.10e-02 -> 2.56e-02 (ratio=6.850e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:02:36 | Remaining: ~0:05:07 | ETA: 16:06:12
#   Epoch time: 1.47s | Avg: 1.55s
#   Total: 3.6929e+00 | Data(6dot): 3.5702e+00
#   Misfit(RMS χ²): 1.152 | Rough: 4.79e+00 | Lam: 0.0256353
#   OT-distance(6D, view-only): 3.570215e-01
#   GradNorms: |g_d|=1.902e-03 | |λ·g_m|=1.158e-03
#  [Auto-Lambda] Epoch 110: Adjusted 2.56e-02 -> 2.13e-02 (ratio=6.906e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 2.13e-02 -> 1.74e-02 (ratio=6.634e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:07 | Remaining: ~0:04:36 | ETA: 16:06:11
#   Epoch time: 1.52s | Avg: 1.54s
#   Total: 3.5624e+00 | Data(6dot): 3.4249e+00
#   Misfit(RMS χ²): 1.096 | Rough: 7.92e+00 | Lam: 0.0173514
#   OT-distance(6D, view-only): 3.424933e-01
#   GradNorms: |g_d|=1.647e-03 | |λ·g_m|=1.030e-03
#  [Auto-Lambda] Epoch 130: Adjusted 1.74e-02 -> 1.39e-02 (ratio=6.428e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.39e-02 -> 1.09e-02 (ratio=6.146e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:03:37 | Remaining: ~0:04:04 | ETA: 16:06:10
#   Epoch time: 1.49s | Avg: 1.54s
#   Total: 3.4483e+00 | Data(6dot): 3.3276e+00
#   Misfit(RMS χ²): 1.056 | Rough: 1.11e+01 | Lam: 0.0109056
#   OT-distance(6D, view-only): 3.327562e-01
#   GradNorms: |g_d|=1.226e-03 | |λ·g_m|=7.893e-04
#   [Early stop] RMS χ² = 1.050 < 1.05, epoch = 146
# Inversion completed.
# OT inversion done
# 1e-10 0.09583325076490176

# %%
# 5a) OT 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.2073

# %%
# 6a) 保存 OT 结果
ot_run_dir = logger.save_from_inverter(inv, run_name="ot_0.02")
history_ot = list(inv.loss_history)
print(f"OT run saved: {ot_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d1/2026-08-10_16-42-49_ot_0.02
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.2073
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d1/2026-08-10_16-42-49_ot_0.02/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d1/2026-08-10_16-42-49_ot_0.02/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d1/2026-08-10_16-42-49_ot_0.02
#   Final RMS χ²: 1.0499
#   RMSE: 0.1468
#   MAPE: 5.48%
# ============================================================
#
# OT run saved: test_results/ccmm2d1/2026-08-10_16-42-49_ot_0.02
