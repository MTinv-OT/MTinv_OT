# %% [markdown]
# # COMMEMI 2D-1：固定静位移（TE 和 TM 有相同静位移） OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d1` 生成标准模型，
# **通过新接口固定静位移**（`static_shift_log` + `shift_station_indices`）施加静位移。
# xy 和 yx（TE/TM）在相同指定台站施加相同固定 log10 乘子 0.15。
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演，并对比。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d1",
    output_root=Path("test_results"),
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/论文绘图

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d1(
    zn=None,
    yn=None,
    nza=10,
    device=device,
    rho_host=100.0,
    rho_block=10.0,
    y_half_width_m=2000.0,
    z_top_m=10000.0,
    z_bottom_m=30000.0,
)

# 2) Survey setup
freqs = torch.logspace(0, -3.5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=30,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.04,
                        noise_type="gaussian",
                        )
inv.update_ot_w_d_per_point_from_noise(
    w_d_scale=[2.0, 1.0, 1.0, 1.0],  # [rhoxy, phsxy, rhoyx, phsyx]
    normalize="mean",)
inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0],synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0348
#    phi(normalized) noise mean: 0.0255
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0348
#    phi(normalized) noise mean: 0.0255
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 4.0%)
#   - Resistivity Error Floor: 4.0%
#   - Phase Error Floor:       1.144 deg
# ✓ MSE data weights normalized (mean): scale=1.461167e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 4.0% (gaussian)
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=tensor(630, 4)@cuda, blur=0.0100, scale=0.9, reach=None
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4b) MSE 反演（同一静位移观测数据，重置初模）
inv.initialize_model(initial_sigma=0.01)
final_sigma_mse = inv.run_inversion(
    n_epochs=500,
    mode="mse",
    progress_interval=20,
    current_lambda=1,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("MSE inversion done")
print(final_sigma_mse.min().item(), final_sigma_mse.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/500 [   0.2%]
#   Elapsed: 0:00:02 | Remaining: ~0:12:52 | ETA: 16:07:39
#   Epoch time: 1.55s | Avg: 1.55s
#   Total: 3.6028e-01 | Data(mse): 3.6028e-01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=tensor([[2.0000, 1.0001, 1.0000, 1.0000],
#         [2.0000, 1.0001, 1.0000, 1.0000],
#         [2.0000, 1.0001, 1.0000, 1.0000],
#         ...,
#         [2.0000, 1.0001, 1.0000, 1.0000],
#         [2.0000, 1.0001, 1.0000, 1.0000],
#         [2.0000, 1.0001, 1.0000, 1.0000]], device='cuda:0')
#   Misfit(RMS χ²): 1.601 | Rough: 0.00e+00 | Lam: 1.0000000
#   OT-distance(6D, view-only): 2.573657e+00
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e+00 -> 1.42e-01 (ratio=2.010e-02)
#  [Auto-Lambda] Epoch 20: Adjusted 1.42e-01 -> 3.73e-02 (ratio=6.921e-02)
# Epoch 21/500 [   4.2%]
#   Elapsed: 0:00:31 | Remaining: ~0:11:37 | ETA: 16:06:52
#   Epoch time: 1.42s | Avg: 1.46s
#   Total: 2.2554e-01 | Data(mse): 2.1316e-01
#   Misfit(RMS χ²): 1.232 | Rough: 3.32e-01 | Lam: 0.0372952
#   OT-distance(6D, view-only): 1.866488e+00
#   GradNorms: |g_d|=2.344e-03 | |λ·g_m|=4.117e-03
#  [Auto-Lambda] Epoch 30: Adjusted 3.73e-02 -> 1.68e-02 (ratio=2.032e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 1.68e-02 -> 1.18e-02 (ratio=4.898e-01)
# Epoch 41/500 [   8.2%]
#   Elapsed: 0:01:00 | Remaining: ~0:11:05 | ETA: 16:06:49
#   Epoch time: 1.52s | Avg: 1.45s
#   Total: 1.8230e-01 | Data(mse): 1.7369e-01
#   Misfit(RMS χ²): 1.112 | Rough: 7.32e-01 | Lam: 0.0117659
#   OT-distance(6D, view-only): 1.588354e+00
#   GradNorms: |g_d|=1.001e-03 | |λ·g_m|=7.337e-04
#  [Auto-Lambda] Epoch 50: Adjusted 1.18e-02 -> 7.82e-03 (ratio=4.422e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 7.82e-03 -> 5.66e-03 (ratio=5.242e-01)
# Epoch 61/500 [  12.2%]
#   Elapsed: 0:01:28 | Remaining: ~0:10:34 | ETA: 16:06:47
#   Epoch time: 1.47s | Avg: 1.44s
#   Total: 1.7005e-01 | Data(mse): 1.6432e-01
#   Misfit(RMS χ²): 1.081 | Rough: 1.01e+00 | Lam: 0.0056646
#   OT-distance(6D, view-only): 1.513671e+00
#   GradNorms: |g_d|=3.298e-04 | |λ·g_m|=2.344e-04
#  [Auto-Lambda] Epoch 70: Adjusted 5.66e-03 -> 4.69e-03 (ratio=6.853e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 4.69e-03 -> 3.59e-03 (ratio=5.868e-01)
# Epoch 81/500 [  16.2%]
#   Elapsed: 0:01:58 | Remaining: ~0:10:06 | ETA: 16:06:49
#   Epoch time: 1.46s | Avg: 1.45s
#   Total: 1.6531e-01 | Data(mse): 1.6097e-01
#   Misfit(RMS χ²): 1.070 | Rough: 1.21e+00 | Lam: 0.0035922
#   OT-distance(6D, view-only): 1.488939e+00
#   GradNorms: |g_d|=1.637e-04 | |λ·g_m|=1.172e-04
#  [Auto-Lambda] Epoch 90: Adjusted 3.59e-03 -> 2.82e-03 (ratio=6.150e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 2.82e-03 -> 2.20e-03 (ratio=6.110e-01)
# Epoch 101/500 [  20.2%]
#   Elapsed: 0:02:27 | Remaining: ~0:09:38 | ETA: 16:06:49
#   Epoch time: 1.52s | Avg: 1.45s
#   Total: 1.6220e-01 | Data(mse): 1.5908e-01
#   Misfit(RMS χ²): 1.064 | Rough: 1.42e+00 | Lam: 0.0022020
#   OT-distance(6D, view-only): 1.474560e+00
#   GradNorms: |g_d|=1.092e-04 | |λ·g_m|=7.202e-05
#  [Auto-Lambda] Epoch 110: Adjusted 2.20e-03 -> 1.76e-03 (ratio=6.412e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 1.76e-03 -> 1.45e-03 (ratio=6.732e-01)
# Epoch 121/500 [  24.2%]
#   Elapsed: 0:02:57 | Remaining: ~0:09:13 | ETA: 16:06:54
#   Epoch time: 1.45s | Avg: 1.46s
#   Total: 1.6017e-01 | Data(mse): 1.5774e-01
#   Misfit(RMS χ²): 1.060 | Rough: 1.68e+00 | Lam: 0.0014466
#   OT-distance(6D, view-only): 1.464923e+00
#   GradNorms: |g_d|=8.341e-05 | |λ·g_m|=5.160e-05
#  [Auto-Lambda] Epoch 130: Adjusted 1.45e-03 -> 1.21e-03 (ratio=6.952e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.21e-03 -> 1.02e-03 (ratio=7.196e-01)
# Epoch 141/500 [  28.2%]
#   Elapsed: 0:03:27 | Remaining: ~0:08:46 | ETA: 16:06:58
#   Epoch time: 1.50s | Avg: 1.47s
#   Total: 1.5874e-01 | Data(mse): 1.5671e-01
#   Misfit(RMS χ²): 1.056 | Rough: 1.98e+00 | Lam: 0.0010232
#   OT-distance(6D, view-only): 1.457644e+00
#   GradNorms: |g_d|=6.721e-05 | |λ·g_m|=4.008e-05
#  [Auto-Lambda] Epoch 150: Adjusted 1.02e-03 -> 8.84e-04 (ratio=7.470e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 8.84e-04 -> 7.74e-04 (ratio=7.664e-01)
# Epoch 161/500 [  32.2%]
#   Elapsed: 0:03:58 | Remaining: ~0:08:21 | ETA: 16:07:04
#   Epoch time: 1.54s | Avg: 1.48s
#   Total: 1.5760e-01 | Data(mse): 1.5579e-01
#   Misfit(RMS χ²): 1.053 | Rough: 2.34e+00 | Lam: 0.0007742
#   OT-distance(6D, view-only): 1.451044e+00
#   GradNorms: |g_d|=5.734e-05 | |λ·g_m|=3.313e-05
#  [Auto-Lambda] Epoch 170: Adjusted 7.74e-04 -> 6.87e-04 (ratio=7.885e-01)
#   [Early stop] RMS χ² = 1.050 < 1.05, epoch = 178
# Inversion completed.
# MSE inversion done
# 1e-10 0.02304082157940005

# %%
# 5b) MSE 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.2982

# %%
mse_run_dir = logger.save_from_inverter(inv, run_name="mse_0.04")
history_mse = list(inv.loss_history)
print(f"MSE run saved: {mse_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d1/2026-08-10_16-39-56_mse_21_0.04
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.2982
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d1/2026-08-10_16-39-56_mse_21_0.04/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d1/2026-08-10_16-39-56_mse_21_0.04/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d1/2026-08-10_16-39-56_mse_21_0.04
#   Final RMS χ²: 1.0499
#   RMSE: 0.1539
#   MAPE: 5.51%
# ============================================================
#
# MSE run saved: test_results/ccmm2d1/2026-08-10_16-39-56_mse_21_0.04
