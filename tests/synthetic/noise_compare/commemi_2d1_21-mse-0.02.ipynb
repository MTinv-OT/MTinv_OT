# %% [markdown]
# # COMMEMI 2D-1：固定静位移（TE 和 TM 有相同静位移） OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d1` 生成标准模型，
# **通过新接口固定静位移**（`static_shift_log` + `shift_station_indices`）施加静位移。
# xy 和 yx（TE/TM）在相同指定台站施加相同固定 log10 乘子 0.15。
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演，并对比。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d1",
    output_root=Path("test_results"),
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/论文绘图

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d1(
    zn=None,
    yn=None,
    nza=10,
    device=device,
    rho_host=100.0,
    rho_block=10.0,
    y_half_width_m=2000.0,
    z_top_m=10000.0,
    z_bottom_m=30000.0,
)

# 2) Survey setup
freqs = torch.logspace(0, -3.5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=30,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.02,
                        noise_type="gaussian",
                        )
inv.update_ot_w_d_per_point_from_noise(
    w_d_scale=[2.0, 1.0, 1.0, 1.0],  # [rhoxy, phsxy, rhoyx, phsyx]
    normalize="mean",)
inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0],synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0174
#    phi(normalized) noise mean: 0.0127
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0174
#    phi(normalized) noise mean: 0.0127
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 2.0%)
#   - Resistivity Error Floor: 2.0%
#   - Phase Error Floor:       0.572 deg
# ✓ MSE data weights normalized (mean): scale=2.921499e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 2.0% (gaussian)
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=tensor(630, 4)@cuda, blur=0.0100, scale=0.9, reach=None
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4b) MSE 反演（同一静位移观测数据，重置初模）
inv.initialize_model(initial_sigma=0.01)
final_sigma_mse = inv.run_inversion(
    n_epochs=500,
    mode="mse",
    progress_interval=20,
    current_lambda=0.1,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("MSE inversion done")
print(final_sigma_mse.min().item(), final_sigma_mse.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/500 [   0.2%]
#   Elapsed: 0:00:02 | Remaining: ~0:12:04 | ETA: 16:09:18
#   Epoch time: 1.45s | Avg: 1.45s
#   Total: 2.5582e-01 | Data(mse): 2.5582e-01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=tensor([[2., 1., 1., 1.],
#         [2., 1., 1., 1.],
#         [2., 1., 1., 1.],
#         ...,
#         [2., 1., 1., 1.],
#         [2., 1., 1., 1.],
#         [2., 1., 1., 1.]], device='cuda:0')
#   Misfit(RMS χ²): 2.698 | Rough: 0.00e+00 | Lam: 0.1000000
#   OT-distance(6D, view-only): 1.485436e+00
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e-01 -> 2.52e-02 (ratio=6.338e-02)
#  [Auto-Lambda] Epoch 20: Adjusted 2.52e-02 -> 9.73e-03 (ratio=1.494e-01)
# Epoch 21/500 [   4.2%]
#   Elapsed: 0:00:31 | Remaining: ~0:11:28 | ETA: 16:09:11
#   Epoch time: 1.45s | Avg: 1.44s
#   Total: 7.0941e-02 | Data(mse): 6.1867e-02
#   Misfit(RMS χ²): 1.327 | Rough: 9.32e-01 | Lam: 0.0097323
#   OT-distance(6D, view-only): 5.157200e-01
#   GradNorms: |g_d|=1.110e-03 | |λ·g_m|=1.327e-03
#  [Auto-Lambda] Epoch 30: Adjusted 9.73e-03 -> 5.51e-03 (ratio=3.211e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 5.51e-03 -> 3.37e-03 (ratio=3.728e-01)
# Epoch 41/500 [   8.2%]
#   Elapsed: 0:01:00 | Remaining: ~0:11:13 | ETA: 16:09:25
#   Epoch time: 1.51s | Avg: 1.47s
#   Total: 5.5846e-02 | Data(mse): 5.2134e-02
#   Misfit(RMS χ²): 1.218 | Rough: 1.10e+00 | Lam: 0.0033673
#   OT-distance(6D, view-only): 4.451122e-01
#   GradNorms: |g_d|=4.438e-04 | |λ·g_m|=3.262e-04
#  [Auto-Lambda] Epoch 50: Adjusted 3.37e-03 -> 2.88e-03 (ratio=7.325e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 2.88e-03 -> 2.44e-03 (ratio=7.197e-01)
# Epoch 61/500 [  12.2%]
#   Elapsed: 0:01:31 | Remaining: ~0:10:52 | ETA: 16:09:35
#   Epoch time: 1.42s | Avg: 1.49s
#   Total: 5.2807e-02 | Data(mse): 4.9886e-02
#   Misfit(RMS χ²): 1.191 | Rough: 1.19e+00 | Lam: 0.0024448
#   OT-distance(6D, view-only): 4.320990e-01
#   GradNorms: |g_d|=1.507e-04 | |λ·g_m|=1.047e-04
#  [Auto-Lambda] Epoch 70: Adjusted 2.44e-03 -> 1.96e-03 (ratio=6.410e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 1.96e-03 -> 1.65e-03 (ratio=7.123e-01)
# Epoch 81/500 [  16.2%]
#   Elapsed: 0:02:01 | Remaining: ~0:10:24 | ETA: 16:09:37
#   Epoch time: 1.54s | Avg: 1.49s
#   Total: 5.1180e-02 | Data(mse): 4.9000e-02
#   Misfit(RMS χ²): 1.181 | Rough: 1.32e+00 | Lam: 0.0016519
#   OT-distance(6D, view-only): 4.251117e-01
#   GradNorms: |g_d|=9.388e-05 | |λ·g_m|=4.727e-05
#  [Auto-Lambda] Epoch 90: Adjusted 1.65e-03 -> 1.38e-03 (ratio=6.980e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 1.38e-03 -> 1.14e-03 (ratio=6.848e-01)
# Epoch 101/500 [  20.2%]
#   Elapsed: 0:02:31 | Remaining: ~0:09:54 | ETA: 16:09:37
#   Epoch time: 1.57s | Avg: 1.49s
#   Total: 5.0050e-02 | Data(mse): 4.8348e-02
#   Misfit(RMS χ²): 1.173 | Rough: 1.49e+00 | Lam: 0.0011421
#   OT-distance(6D, view-only): 4.204557e-01
#   GradNorms: |g_d|=5.261e-05 | |λ·g_m|=3.116e-05
#  [Auto-Lambda] Epoch 110: Adjusted 1.14e-03 -> 9.75e-04 (ratio=7.285e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 9.75e-04 -> 8.30e-04 (ratio=7.251e-01)
# Epoch 121/500 [  24.2%]
#   Elapsed: 0:03:00 | Remaining: ~0:09:23 | ETA: 16:09:35
#   Epoch time: 1.42s | Avg: 1.49s
#   Total: 4.9157e-02 | Data(mse): 4.7719e-02
#   Misfit(RMS χ²): 1.165 | Rough: 1.73e+00 | Lam: 0.0008301
#   OT-distance(6D, view-only): 4.158339e-01
#   GradNorms: |g_d|=4.068e-05 | |λ·g_m|=2.405e-05
#  [Auto-Lambda] Epoch 130: Adjusted 8.30e-04 -> 7.29e-04 (ratio=7.709e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 7.29e-04 -> 6.54e-04 (ratio=8.065e-01)
# Epoch 141/500 [  28.2%]
#   Elapsed: 0:03:30 | Remaining: ~0:08:53 | ETA: 16:09:35
#   Epoch time: 1.41s | Avg: 1.49s
#   Total: 4.8381e-02 | Data(mse): 4.7031e-02
#   Misfit(RMS χ²): 1.157 | Rough: 2.06e+00 | Lam: 0.0006545
#   OT-distance(6D, view-only): 4.111319e-01
#   GradNorms: |g_d|=3.683e-05 | |λ·g_m|=2.067e-05
#  [Auto-Lambda] Epoch 150: Adjusted 6.54e-04 -> 6.02e-04 (ratio=8.460e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 6.02e-04 -> 5.66e-04 (ratio=8.834e-01)
# Epoch 161/500 [  32.2%]
#   Elapsed: 0:04:00 | Remaining: ~0:08:24 | ETA: 16:09:36
#   Epoch time: 1.56s | Avg: 1.49s
#   Total: 4.7602e-02 | Data(mse): 4.6170e-02
#   Misfit(RMS χ²): 1.146 | Rough: 2.53e+00 | Lam: 0.0005658
#   OT-distance(6D, view-only): 4.056081e-01
#   GradNorms: |g_d|=3.666e-05 | |λ·g_m|=1.954e-05
# Epoch 181/500 [  36.2%]
#   Elapsed: 0:04:31 | Remaining: ~0:07:56 | ETA: 16:09:38
#   Epoch time: 1.43s | Avg: 1.49s
#   Total: 4.6835e-02 | Data(mse): 4.5023e-02
#   Misfit(RMS χ²): 1.132 | Rough: 3.20e+00 | Lam: 0.0005658
#   OT-distance(6D, view-only): 3.987239e-01
#   GradNorms: |g_d|=3.872e-05 | |λ·g_m|=2.147e-05
#  [Auto-Lambda] Epoch 190: Adjusted 5.66e-04 -> 5.34e-04 (ratio=8.907e-01)
# Epoch 201/500 [  40.2%]
#   Elapsed: 0:05:00 | Remaining: ~0:07:25 | ETA: 16:09:37
#   Epoch time: 1.44s | Avg: 1.49s
#   Total: 4.5774e-02 | Data(mse): 4.3576e-02
#   Misfit(RMS χ²): 1.113 | Rough: 4.12e+00 | Lam: 0.0005340
#   OT-distance(6D, view-only): 3.903401e-01
#   GradNorms: |g_d|=4.099e-05 | |λ·g_m|=2.239e-05
#  [Auto-Lambda] Epoch 210: Adjusted 5.34e-04 -> 5.01e-04 (ratio=8.791e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 5.01e-04 -> 4.69e-04 (ratio=8.793e-01)
# Epoch 221/500 [  44.2%]
#   Elapsed: 0:05:28 | Remaining: ~0:06:54 | ETA: 16:09:34
#   Epoch time: 1.60s | Avg: 1.48s
#   Total: 4.4453e-02 | Data(mse): 4.1976e-02
#   Misfit(RMS χ²): 1.093 | Rough: 5.28e+00 | Lam: 0.0004695
#   OT-distance(6D, view-only): 3.811188e-01
#   GradNorms: |g_d|=4.093e-05 | |λ·g_m|=2.199e-05
#  [Auto-Lambda] Epoch 230: Adjusted 4.69e-04 -> 4.36e-04 (ratio=8.612e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 4.36e-04 -> 3.99e-04 (ratio=8.406e-01)
# Epoch 241/500 [  48.2%]
#   Elapsed: 0:05:57 | Remaining: ~0:06:22 | ETA: 16:09:31
#   Epoch time: 1.36s | Avg: 1.48s
#   Total: 4.3136e-02 | Data(mse): 4.0519e-02
#   Misfit(RMS χ²): 1.074 | Rough: 6.55e+00 | Lam: 0.0003994
#   OT-distance(6D, view-only): 3.724642e-01
#   GradNorms: |g_d|=3.795e-05 | |λ·g_m|=2.091e-05
#  [Auto-Lambda] Epoch 250: Adjusted 3.99e-04 -> 3.62e-04 (ratio=8.234e-01)
#  [Auto-Lambda] Epoch 260: Adjusted 3.62e-04 -> 3.27e-04 (ratio=8.118e-01)
# Epoch 261/500 [  52.2%]
#   Elapsed: 0:06:25 | Remaining: ~0:05:51 | ETA: 16:09:28
#   Epoch time: 1.36s | Avg: 1.47s
#   Total: 4.1936e-02 | Data(mse): 3.9400e-02
#   Misfit(RMS χ²): 1.059 | Rough: 7.76e+00 | Lam: 0.0003266
#   OT-distance(6D, view-only): 3.654624e-01
#   GradNorms: |g_d|=3.361e-05 | |λ·g_m|=1.886e-05
#  [Auto-Lambda] Epoch 270: Adjusted 3.27e-04 -> 2.93e-04 (ratio=8.058e-01)
#   [Early stop] RMS χ² = 1.050 < 1.05, epoch = 276
# Inversion completed.
# MSE inversion done
# 1e-10 0.07011383520958799

# %%
# 5b) MSE 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.2830

# %%
mse_run_dir = logger.save_from_inverter(inv, run_name="mse_0.02")
history_mse = list(inv.loss_history)
print(f"MSE run saved: {mse_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d1/2026-08-10_16-04-13_mse_21_2noise
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.2830
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d1/2026-08-10_16-04-13_mse_21_2noise/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d1/2026-08-10_16-04-13_mse_21_2noise/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d1/2026-08-10_16-04-13_mse_21_2noise
#   Final RMS χ²: 1.0498
#   RMSE: 0.1381
#   MAPE: 5.08%
# ============================================================
#
# MSE run saved: test_results/ccmm2d1/2026-08-10_16-04-13_mse_21_2noise
