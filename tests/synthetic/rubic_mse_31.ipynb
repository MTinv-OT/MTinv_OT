# %% [markdown]
# # 棋盘格（Checkerboard）模型 MSE 反演
#
# 使用 `MT2DTrueModels.create_true_checkerboard` 生成高低阻交替棋盘格真实模型，并执行 2D MT 反演（MSE 损失）。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

current_path = os.path.abspath("")
root_path = os.path.abspath(os.path.join(current_path, "..", ".."))
if root_path not in sys.path:
    sys.path.insert(0, root_path)
os.environ["CUDA_VISIBLE_DEVICES"] = "0" 
from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger

logger = ExperimentLogger(
    model_tag="rubic",#need define
    output_root=Path("test_results") #去掉parent生成test_results套ccm2d1
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
# Out:
# Running on cuda

# %%
import os
from pathlib import Path

print(f"当前目录: {Path.cwd()}")
print(f"目录内容: {list(Path.cwd().iterdir())}")

# 检查 src 在哪里
for p in [Path.cwd(), Path.cwd().parent, Path.cwd().parent.parent]:
    if (p / "src").exists():
        print(f"找到 src 在: {p}")
# Out:
# 当前目录: /home/liuxr/MTinv_OT3/tests/synthetic
# 目录内容: [PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_ot_21.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/.ipynb_checkpoints'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.2.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.15.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.2.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_mse_31.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/test_results'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.1.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_mse_21.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.15.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.1.ipynb')]
# 找到 src 在: /home/liuxr/MTinv_OT3

# %%
yn_np, zn_np, nza = MT2DTrueModels._default_grid(nza=10)

# 2) 生成真实的交替棋盘格
sig_true = MT2DTrueModels.create_true_checkerboard(
    yn=yn_np,
    zn=zn_np,
    nza=nza,
    device=device,
    bg_rho=100.0,               # 背景电阻率
    rho_1=10.0,                 # 低阻块 (10 Ohm.m)
    rho_2=1000.0,               # 高阻块 (1000 Ohm.m)
    y_bounds=(-15000.0, 15000.0), # 横向范围匹配 stations
    dy_block=10000.0,           # 约 3×3 棋盘格：每块宽 10 km
    z_bounds=(2000.0, 22000.0),   # 深度 2 km 开始，向下延伸到 22 km
    dz_block=6667.0,            # 约 3×3 棋盘格：每块高约 6.7 km
)

# 转换为 tensor 以备正反演使用
yn = torch.tensor(yn_np, device=device)
zn = torch.tensor(zn_np, device=device)

# 3) Survey setup
freqs = torch.logspace(0, -5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 31, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")

PLOT_KWARGS = dict(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 31, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=20,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.01,
                        noise_type="gaussian",
                        static_shift_std=0.15,   # 0.15 会导致电阻率发生约半个量级的剧烈上下平移
                        shift_modes=("xy", "yx"),# 作用于双极化模式 (TM 模式通常对畸变最敏感)
                        shift_stations="middle",
                        shift_ratio = 0)
inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(**PLOT_KWARGS)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# /tmp/ipykernel_3861945/2159404610.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   yn=torch.tensor(yn, dtype=torch.float64, device=device),
# /tmp/ipykernel_3861945/2159404610.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   zn=torch.tensor(zn, dtype=torch.float64, device=device),
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.843704e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 1.0% (gaussian)
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4) Run inversion
final_sigma = inv.run_inversion(
    n_epochs=300,
    mode="mse",
    progress_interval=20,
    current_lambda=0.1,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing = False
)
print("Inversion done")
print(final_sigma.min().item(), final_sigma.max().item())
# Out:
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:02 | Remaining: ~0:08:29 | ETA: 13:11:06
#   Epoch time: 1.70s | Avg: 1.70s
#   Total: 1.1148e+01 | Data(mse): 1.1148e+01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 43.630 | Rough: 0.00e+00 | Lam: 0.1000000
#   OT-distance(6D, view-only): 5.109505e-01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 20: Adjusted 1.00e-01 -> 8.93e-02 (ratio=7.983e-01)
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:37 | Remaining: ~0:08:09 | ETA: 13:11:21
#   Epoch time: 2.12s | Avg: 1.75s
#   Total: 2.9327e+00 | Data(mse): 2.5111e+00
#   Misfit(RMS χ²): 20.706 | Rough: 4.72e+00 | Lam: 0.0893497
#   OT-distance(6D, view-only): 2.518919e-01
#   GradNorms: |g_d|=1.352e-02 | |λ·g_m|=8.232e-03
#  [Auto-Lambda] Epoch 30: Adjusted 8.93e-02 -> 7.12e-02 (ratio=6.349e-01)
#  [Auto-Lambda] Epoch 40: Adjusted 7.12e-02 -> 6.00e-02 (ratio=7.111e-01)
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:12 | Remaining: ~0:07:33 | ETA: 13:11:20
#   Epoch time: 2.43s | Avg: 1.75s
#   Total: 1.6545e+00 | Data(mse): 1.2648e+00
#   Misfit(RMS χ²): 14.696 | Rough: 6.49e+00 | Lam: 0.0600359
#   OT-distance(6D, view-only): 1.699977e-01
#   GradNorms: |g_d|=4.807e-03 | |λ·g_m|=2.777e-03
#  [Auto-Lambda] Epoch 50: Adjusted 6.00e-02 -> 5.41e-02 (ratio=8.114e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 5.41e-02 -> 5.01e-02 (ratio=8.591e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:46 | Remaining: ~0:06:53 | ETA: 13:11:14
#   Epoch time: 2.05s | Avg: 1.73s
#   Total: 1.2230e+00 | Data(mse): 9.0223e-01
#   Misfit(RMS χ²): 12.412 | Rough: 6.40e+00 | Lam: 0.0501259
#   OT-distance(6D, view-only): 1.252390e-01
#   GradNorms: |g_d|=3.376e-03 | |λ·g_m|=1.822e-03
#  [Auto-Lambda] Epoch 80: Adjusted 5.01e-02 -> 4.68e-02 (ratio=8.699e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:20 | Remaining: ~0:06:18 | ETA: 13:11:13
#   Epoch time: 2.00s | Avg: 1.73s
#   Total: 1.0008e+00 | Data(mse): 6.8705e-01
#   Misfit(RMS χ²): 10.831 | Rough: 6.71e+00 | Lam: 0.0467514
#   OT-distance(6D, view-only): 9.623130e-02
#   GradNorms: |g_d|=2.875e-03 | |λ·g_m|=1.550e-03
#  [Auto-Lambda] Epoch 90: Adjusted 4.68e-02 -> 4.32e-02 (ratio=8.555e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 4.32e-02 -> 3.98e-02 (ratio=8.479e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:02:55 | Remaining: ~0:05:43 | ETA: 13:11:13
#   Epoch time: 2.26s | Avg: 1.73s
#   Total: 8.3553e-01 | Data(mse): 5.4353e-01
#   Misfit(RMS χ²): 9.634 | Rough: 7.33e+00 | Lam: 0.0398195
#   OT-distance(6D, view-only): 7.625544e-02
#   GradNorms: |g_d|=2.453e-03 | |λ·g_m|=1.342e-03
#  [Auto-Lambda] Epoch 110: Adjusted 3.98e-02 -> 3.65e-02 (ratio=8.392e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 3.65e-02 -> 3.33e-02 (ratio=8.310e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:31 | Remaining: ~0:05:11 | ETA: 13:11:17
#   Epoch time: 2.20s | Avg: 1.74s
#   Total: 7.1249e-01 | Data(mse): 4.4150e-01
#   Misfit(RMS χ²): 8.682 | Rough: 8.15e+00 | Lam: 0.0332525
#   OT-distance(6D, view-only): 6.156585e-02
#   GradNorms: |g_d|=2.151e-03 | |λ·g_m|=1.190e-03
#  [Auto-Lambda] Epoch 130: Adjusted 3.33e-02 -> 3.01e-02 (ratio=8.214e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 3.01e-02 -> 2.72e-02 (ratio=8.132e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:04:07 | Remaining: ~0:04:37 | ETA: 13:11:19
#   Epoch time: 2.40s | Avg: 1.75s
#   Total: 6.1201e-01 | Data(mse): 3.6336e-01
#   Misfit(RMS χ²): 7.877 | Rough: 9.15e+00 | Lam: 0.0271768
#   OT-distance(6D, view-only): 5.025438e-02
#   GradNorms: |g_d|=1.885e-03 | |λ·g_m|=1.056e-03
#  [Auto-Lambda] Epoch 150: Adjusted 2.72e-02 -> 2.44e-02 (ratio=8.069e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 2.44e-02 -> 2.19e-02 (ratio=8.024e-01)
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:42 | Remaining: ~0:04:03 | ETA: 13:11:20
#   Epoch time: 2.38s | Avg: 1.75s
#   Total: 5.2610e-01 | Data(mse): 3.0103e-01
#   Misfit(RMS χ²): 7.169 | Rough: 1.03e+01 | Lam: 0.0218675
#   OT-distance(6D, view-only): 4.127517e-02
#   GradNorms: |g_d|=1.652e-03 | |λ·g_m|=9.318e-04
#  [Auto-Lambda] Epoch 170: Adjusted 2.19e-02 -> 1.95e-02 (ratio=7.985e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 1.95e-02 -> 1.74e-02 (ratio=7.952e-01)
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:05:18 | Remaining: ~0:03:28 | ETA: 13:11:21
#   Epoch time: 2.12s | Avg: 1.75s
#   Total: 4.5101e-01 | Data(mse): 2.4912e-01
#   Misfit(RMS χ²): 6.522 | Rough: 1.16e+01 | Lam: 0.0174246
#   OT-distance(6D, view-only): 3.391905e-02
#   GradNorms: |g_d|=1.446e-03 | |λ·g_m|=8.194e-04
#  [Auto-Lambda] Epoch 190: Adjusted 1.74e-02 -> 1.55e-02 (ratio=7.919e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 1.55e-02 -> 1.38e-02 (ratio=7.884e-01)
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:05:53 | Remaining: ~0:02:53 | ETA: 13:11:22
#   Epoch time: 2.22s | Avg: 1.76s
#   Total: 3.8426e-01 | Data(mse): 2.0460e-01
#   Misfit(RMS χ²): 5.910 | Rough: 1.30e+01 | Lam: 0.0137676
#   OT-distance(6D, view-only): 2.779509e-02
#   GradNorms: |g_d|=1.261e-03 | |λ·g_m|=7.183e-04
#  [Auto-Lambda] Epoch 210: Adjusted 1.38e-02 -> 1.22e-02 (ratio=7.841e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 1.22e-02 -> 1.08e-02 (ratio=7.786e-01)
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:06:29 | Remaining: ~0:02:19 | ETA: 13:11:23
#   Epoch time: 2.39s | Avg: 1.76s
#   Total: 3.2396e-01 | Data(mse): 1.6563e-01
#   Misfit(RMS χ²): 5.318 | Rough: 1.47e+01 | Lam: 0.0107570
#   OT-distance(6D, view-only): 2.258534e-02
#   GradNorms: |g_d|=1.093e-03 | |λ·g_m|=6.269e-04
#  [Auto-Lambda] Epoch 230: Adjusted 1.08e-02 -> 9.45e-03 (ratio=7.710e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 9.45e-03 -> 8.24e-03 (ratio=7.606e-01)
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:07:05 | Remaining: ~0:01:43 | ETA: 13:11:24
#   Epoch time: 2.20s | Avg: 1.76s
#   Total: 2.6845e-01 | Data(mse): 1.3137e-01
#   Misfit(RMS χ²): 4.736 | Rough: 1.66e+01 | Lam: 0.0082375
#   OT-distance(6D, view-only): 1.812902e-02
#   GradNorms: |g_d|=9.302e-04 | |λ·g_m|=5.411e-04
#  [Auto-Lambda] Epoch 250: Adjusted 8.24e-03 -> 7.12e-03 (ratio=7.468e-01)
#  [Auto-Lambda] Epoch 260: Adjusted 7.12e-03 -> 6.08e-03 (ratio=7.294e-01)
# Epoch 261/300 [  87.0%]
#   Elapsed: 0:07:42 | Remaining: ~0:01:08 | ETA: 13:11:26
#   Epoch time: 2.26s | Avg: 1.77s
#   Total: 2.1663e-01 | Data(mse): 1.0218e-01
#   Misfit(RMS χ²): 4.177 | Rough: 1.88e+01 | Lam: 0.0060794
#   OT-distance(6D, view-only): 1.453411e-02
#   GradNorms: |g_d|=7.602e-04 | |λ·g_m|=4.529e-04
#  [Auto-Lambda] Epoch 270: Adjusted 6.08e-03 -> 5.12e-03 (ratio=7.097e-01)
#  [Auto-Lambda] Epoch 280: Adjusted 5.12e-03 -> 4.26e-03 (ratio=6.912e-01)
# Epoch 281/300 [  93.7%]
#   Elapsed: 0:08:19 | Remaining: ~0:00:33 | ETA: 13:11:27
#   Epoch time: 2.25s | Avg: 1.77s
#   Total: 1.6948e-01 | Data(mse): 7.9373e-02
#   Misfit(RMS χ²): 3.681 | Rough: 2.12e+01 | Lam: 0.0042581
#   OT-distance(6D, view-only): 1.191110e-02
#   GradNorms: |g_d|=5.837e-04 | |λ·g_m|=3.582e-04
#  [Auto-Lambda] Epoch 290: Adjusted 4.26e-03 -> 3.51e-03 (ratio=6.788e-01)
# Epoch 300/300 [ 100.0%]
#   Elapsed: 0:08:54 | Remaining: ~0:00:00 | ETA: 13:11:29
#   Epoch time: 2.44s | Avg: 1.78s
#   Total: 1.4573e-01 | Data(mse): 6.3895e-02
#   Misfit(RMS χ²): 3.303 | Rough: 2.33e+01 | Lam: 0.0035082
#   OT-distance(6D, view-only): 1.021650e-02
#   GradNorms: |g_d|=4.404e-04 | |λ·g_m|=3.258e-04
# Inversion completed.
# Inversion done
# 1e-10 0.3365152497366182

# %%
# 5) Plot results
inv.plot_loss_history()
inv.plot_model_comparison(**PLOT_KWARGS)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.7809

# %%
logger.save_from_inverter(
    inv,
    run_name="rubic_mse",
    plot_kwargs=PLOT_KWARGS,
)
# Out:
# ============================================================
# Saving results to: test_results/rubic/2026-07-06_13-12-02_rubic_mse
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.7809
# /home/liuxr/MTinv_OT3/src/mt2d_inv/plotting/inversion.py:682: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   for batch_start in range(0, len(station_indices), stations_per_figure):
#   ✓ data_fitting: 31 plots saved to test_results/rubic/2026-07-06_13-12-02_rubic_mse/figures/data_fitting (31 stations)
#   ✓ Figures saved to test_results/rubic/2026-07-06_13-12-02_rubic_mse/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/rubic/2026-07-06_13-12-02_rubic_mse
#   Final RMS χ²: 3.3030
#   RMSE: 0.5607
#   MAPE: 23.44%
# ============================================================
# PosixPath('test_results/rubic/2026-07-06_13-12-02_rubic_mse')
