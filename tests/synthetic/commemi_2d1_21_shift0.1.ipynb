# %% [markdown]
# # COMMEMI 2D-1：静位移下 OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d1` 生成标准模型，在合成数据上施加静位移后，
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演，并对比收敛曲线与视电阻率拟合。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d1",
    output_root=Path("test_results"),
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/MTinv_OT3

# %%
import os
from pathlib import Path

print(f"当前目录: {Path.cwd()}")
print(f"目录内容: {list(Path.cwd().iterdir())}")

# 检查 src 在哪里
for p in [Path.cwd(), Path.cwd().parent, Path.cwd().parent.parent]:
    if (p / "src").exists():
        print(f"找到 src 在: {p}")
# Out:
# 当前目录: /home/liuxr/MTinv_OT3/tests/synthetic
# 目录内容: [PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_ot_21.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/.ipynb_checkpoints'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.15.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/test_results'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.1.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_mse_21.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.15.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.1.ipynb')]
# 找到 src 在: /home/liuxr/MTinv_OT3

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d1(
    zn=None,
    yn=None,
    nza=10,
    device=device,
    rho_host=100.0,
    rho_block=10.0,
    y_half_width_m=2000.0,
    z_top_m=10000.0,
    z_bottom_m=30000.0,
)

# 2) Survey setup
freqs = torch.logspace(0, -5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=10,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.01,
                        noise_type="gaussian",
                        static_shift_std=0.15,   # 0.15 会导致电阻率发生约半个量级的剧烈上下平移
                        shift_modes=("xy", "yx"),# 作用于双极化模式 (TM 模式通常对畸变最敏感)
                        shift_stations="random")
inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0],synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.846255e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 1.0% (gaussian)
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4a) OT 反演 (6dot)
inv.initialize_model(initial_sigma=0.01)
final_sigma_ot = inv.run_inversion(
    n_epochs=300,
    mode="6dot",
    progress_interval=20,
    current_lambda=0.01,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("OT inversion done")
print(final_sigma_ot.min().item(), final_sigma_ot.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:02 | Remaining: ~0:07:18 | ETA: 13:02:13
#   Epoch time: 1.47s | Avg: 1.47s
#   Total: 1.2014e-02 | Data(6dot): 1.2014e-02
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 10.124 | Rough: 0.00e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 1.201443e-02
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e-02 -> 1.37e-03 (ratio=1.874e-02)
#  [Auto-Lambda] Epoch 20: Adjusted 1.37e-03 -> 3.14e-04 (ratio=5.255e-02)
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:35 | Remaining: ~0:07:32 | ETA: 13:02:59
#   Epoch time: 1.93s | Avg: 1.62s
#   Total: 6.3382e-03 | Data(6dot): 6.0364e-03
#   Misfit(RMS χ²): 9.304 | Rough: 9.62e-01 | Lam: 0.0003138
#   OT-distance(6D, view-only): 6.036415e-03
#   GradNorms: |g_d|=2.432e-05 | |λ·g_m|=4.818e-05
#  [Auto-Lambda] Epoch 30: Adjusted 3.14e-04 -> 8.93e-05 (ratio=8.101e-02)
#  [Auto-Lambda] Epoch 40: Adjusted 8.93e-05 -> 5.35e-05 (ratio=3.588e-01)
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:08 | Remaining: ~0:07:05 | ETA: 13:03:06
#   Epoch time: 2.35s | Avg: 1.64s
#   Total: 5.5382e-03 | Data(6dot): 5.4592e-03
#   Misfit(RMS χ²): 9.151 | Rough: 1.48e+00 | Lam: 0.0000535
#   OT-distance(6D, view-only): 5.459199e-03
#   GradNorms: |g_d|=9.402e-06 | |λ·g_m|=9.083e-06
#  [Auto-Lambda] Epoch 50: Adjusted 5.35e-05 -> 3.79e-05 (ratio=5.028e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 3.79e-05 -> 3.25e-05 (ratio=7.321e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:41 | Remaining: ~0:06:35 | ETA: 13:03:09
#   Epoch time: 2.07s | Avg: 1.65s
#   Total: 5.2160e-03 | Data(6dot): 5.1455e-03
#   Misfit(RMS χ²): 9.008 | Rough: 2.17e+00 | Lam: 0.0000325
#   OT-distance(6D, view-only): 5.145517e-03
#   GradNorms: |g_d|=5.802e-06 | |λ·g_m|=3.570e-06
#  [Auto-Lambda] Epoch 70: Adjusted 3.25e-05 -> 2.97e-05 (ratio=8.387e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:16 | Remaining: ~0:06:05 | ETA: 13:03:14
#   Epoch time: 2.23s | Avg: 1.67s
#   Total: 5.0796e-03 | Data(6dot): 4.9930e-03
#   Misfit(RMS χ²): 8.945 | Rough: 2.91e+00 | Lam: 0.0000297
#   OT-distance(6D, view-only): 4.992985e-03
#   GradNorms: |g_d|=4.103e-06 | |λ·g_m|=2.229e-06
#  [Auto-Lambda] Epoch 90: Adjusted 2.97e-05 -> 2.82e-05 (ratio=9.010e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 2.82e-05 -> 2.68e-05 (ratio=9.006e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:02:50 | Remaining: ~0:05:34 | ETA: 13:03:16
#   Epoch time: 2.17s | Avg: 1.68s
#   Total: 4.9884e-03 | Data(6dot): 4.8965e-03
#   Misfit(RMS χ²): 8.910 | Rough: 3.43e+00 | Lam: 0.0000268
#   OT-distance(6D, view-only): 4.896512e-03
#   GradNorms: |g_d|=3.413e-06 | |λ·g_m|=1.805e-06
#  [Auto-Lambda] Epoch 110: Adjusted 2.68e-05 -> 2.54e-05 (ratio=8.965e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 2.54e-05 -> 2.38e-05 (ratio=8.791e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:25 | Remaining: ~0:05:02 | ETA: 13:03:19
#   Epoch time: 2.16s | Avg: 1.69s
#   Total: 4.9165e-03 | Data(6dot): 4.8225e-03
#   Misfit(RMS χ²): 8.885 | Rough: 3.96e+00 | Lam: 0.0000238
#   OT-distance(6D, view-only): 4.822466e-03
#   GradNorms: |g_d|=2.936e-06 | |λ·g_m|=1.578e-06
#  [Auto-Lambda] Epoch 130: Adjusted 2.38e-05 -> 2.22e-05 (ratio=8.686e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 2.22e-05 -> 2.05e-05 (ratio=8.582e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:04:00 | Remaining: ~0:04:30 | ETA: 13:03:23
#   Epoch time: 2.25s | Avg: 1.70s
#   Total: 4.8566e-03 | Data(6dot): 4.7623e-03
#   Misfit(RMS χ²): 8.865 | Rough: 4.59e+00 | Lam: 0.0000205
#   OT-distance(6D, view-only): 4.762301e-03
#   GradNorms: |g_d|=2.547e-06 | |λ·g_m|=1.386e-06
#  [Auto-Lambda] Epoch 150: Adjusted 2.05e-05 -> 1.89e-05 (ratio=8.451e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 1.89e-05 -> 1.73e-05 (ratio=8.379e-01)
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:36 | Remaining: ~0:03:57 | ETA: 13:03:25
#   Epoch time: 2.11s | Avg: 1.71s
#   Total: 4.8052e-03 | Data(6dot): 4.7137e-03
#   Misfit(RMS χ²): 8.850 | Rough: 5.30e+00 | Lam: 0.0000173
#   OT-distance(6D, view-only): 4.713658e-03
#   GradNorms: |g_d|=2.186e-06 | |λ·g_m|=1.205e-06
#  [Auto-Lambda] Epoch 170: Adjusted 1.73e-05 -> 1.58e-05 (ratio=8.322e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 1.58e-05 -> 1.44e-05 (ratio=8.296e-01)
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:05:12 | Remaining: ~0:03:24 | ETA: 13:03:29
#   Epoch time: 2.18s | Avg: 1.72s
#   Total: 4.7611e-03 | Data(6dot): 4.6746e-03
#   Misfit(RMS χ²): 8.837 | Rough: 6.03e+00 | Lam: 0.0000144
#   OT-distance(6D, view-only): 4.674581e-03
#   GradNorms: |g_d|=1.878e-06 | |λ·g_m|=1.041e-06
#  [Auto-Lambda] Epoch 190: Adjusted 1.44e-05 -> 1.31e-05 (ratio=8.279e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 1.31e-05 -> 1.19e-05 (ratio=8.274e-01)
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:05:47 | Remaining: ~0:02:50 | ETA: 13:03:29
#   Epoch time: 2.21s | Avg: 1.72s
#   Total: 4.7235e-03 | Data(6dot): 4.6431e-03
#   Misfit(RMS χ²): 8.828 | Rough: 6.77e+00 | Lam: 0.0000119
#   OT-distance(6D, view-only): 4.643142e-03
#   GradNorms: |g_d|=1.616e-06 | |λ·g_m|=8.968e-07
#  [Auto-Lambda] Epoch 210: Adjusted 1.19e-05 -> 1.08e-05 (ratio=8.279e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 1.08e-05 -> 9.84e-06 (ratio=8.292e-01)
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:06:21 | Remaining: ~0:02:16 | ETA: 13:03:29
#   Epoch time: 2.24s | Avg: 1.72s
#   Total: 4.6915e-03 | Data(6dot): 4.6178e-03
#   Misfit(RMS χ²): 8.821 | Rough: 7.49e+00 | Lam: 0.0000098
#   OT-distance(6D, view-only): 4.617794e-03
#   GradNorms: |g_d|=1.395e-06 | |λ·g_m|=7.729e-07
#  [Auto-Lambda] Epoch 230: Adjusted 9.84e-06 -> 8.97e-06 (ratio=8.314e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 8.97e-06 -> 8.20e-06 (ratio=8.341e-01)
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:06:57 | Remaining: ~0:01:41 | ETA: 13:03:31
#   Epoch time: 2.44s | Avg: 1.73s
#   Total: 4.6643e-03 | Data(6dot): 4.5973e-03
#   Misfit(RMS χ²): 8.816 | Rough: 8.18e+00 | Lam: 0.0000082
#   OT-distance(6D, view-only): 4.597260e-03
#   GradNorms: |g_d|=1.209e-06 | |λ·g_m|=6.678e-07
#  [Auto-Lambda] Epoch 250: Adjusted 8.20e-06 -> 7.50e-06 (ratio=8.374e-01)
#  [Auto-Lambda] Epoch 260: Adjusted 7.50e-06 -> 6.88e-06 (ratio=8.409e-01)
# Epoch 261/300 [  87.0%]
#   Elapsed: 0:07:32 | Remaining: ~0:01:07 | ETA: 13:03:32
#   Epoch time: 2.09s | Avg: 1.73s
#   Total: 4.6413e-03 | Data(6dot): 4.5805e-03
#   Misfit(RMS χ²): 8.812 | Rough: 8.84e+00 | Lam: 0.0000069
#   OT-distance(6D, view-only): 4.580508e-03
#   GradNorms: |g_d|=1.054e-06 | |λ·g_m|=5.796e-07
#  [Auto-Lambda] Epoch 270: Adjusted 6.88e-06 -> 6.32e-06 (ratio=8.447e-01)
#  [Auto-Lambda] Epoch 280: Adjusted 6.32e-06 -> 5.82e-06 (ratio=8.487e-01)
# Epoch 281/300 [  93.7%]
#   Elapsed: 0:08:09 | Remaining: ~0:00:33 | ETA: 13:03:34
#   Epoch time: 2.20s | Avg: 1.74s
#   Total: 4.6219e-03 | Data(6dot): 4.5668e-03
#   Misfit(RMS χ²): 8.809 | Rough: 9.47e+00 | Lam: 0.0000058
#   OT-distance(6D, view-only): 4.566756e-03
#   GradNorms: |g_d|=9.252e-07 | |λ·g_m|=5.060e-07
#  [Auto-Lambda] Epoch 290: Adjusted 5.82e-06 -> 5.38e-06 (ratio=8.529e-01)
# Epoch 300/300 [ 100.0%]
#   Elapsed: 0:08:44 | Remaining: ~0:00:00 | ETA: 13:03:37
#   Epoch time: 2.39s | Avg: 1.75s
#   Total: 4.6099e-03 | Data(6dot): 4.5559e-03
#   Misfit(RMS χ²): 8.807 | Rough: 1.00e+01 | Lam: 0.0000054
#   OT-distance(6D, view-only): 4.555941e-03
#   GradNorms: |g_d|=8.224e-07 | |λ·g_m|=4.798e-07
# Inversion completed.
# OT inversion done
# 1e-10 0.07993592335166237

# %%
# 5a) OT 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.9433

# %%
# 6a) 保存 OT 结果
ot_run_dir = logger.save_from_inverter(inv, run_name="ot_21_1shift0.1")
history_ot = list(inv.loss_history)
print(f"OT run saved: {ot_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d1/2026-07-06_13-04-00_ot_21_1shift0.1
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.9433
# /home/liuxr/MTinv_OT3/src/mt2d_inv/plotting/inversion.py:682: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axes = plt.subplots(
#   ✓ data_fitting: 21 plots saved to test_results/ccmm2d1/2026-07-06_13-04-00_ot_21_1shift0.1/figures/data_fitting (21 stations)
#   ✓ Figures saved to test_results/ccmm2d1/2026-07-06_13-04-00_ot_21_1shift0.1/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d1/2026-07-06_13-04-00_ot_21_1shift0.1
#   Final RMS χ²: 8.8067
#   RMSE: 0.1488
#   MAPE: 5.44%
# ============================================================
#
# OT run saved: test_results/ccmm2d1/2026-07-06_13-04-00_ot_21_1shift0.1

# %%
# 4b) MSE 反演（同一静位移观测数据，重置初模）
inv.initialize_model(initial_sigma=0.01)
final_sigma_mse = inv.run_inversion(
    n_epochs=300,
    mode="mse",
    progress_interval=20,
    current_lambda=0.01,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("MSE inversion done")
print(final_sigma_mse.min().item(), final_sigma_mse.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:01 | Remaining: ~0:07:49 | ETA: 13:12:18
#   Epoch time: 1.57s | Avg: 1.57s
#   Total: 2.9987e-01 | Data(mse): 2.9987e-01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 10.124 | Rough: 0.00e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 1.201443e-02
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e-02 -> 6.69e-03 (ratio=4.478e-01)
#  [Auto-Lambda] Epoch 20: Adjusted 6.69e-03 -> 5.87e-03 (ratio=7.687e-01)
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:36 | Remaining: ~0:08:06 | ETA: 13:13:11
#   Epoch time: 2.25s | Avg: 1.74s
#   Total: 2.4147e-01 | Data(mse): 2.3715e-01
#   Misfit(RMS χ²): 9.003 | Rough: 7.36e-01 | Lam: 0.0058671
#   OT-distance(6D, view-only): 5.620350e-03
#   GradNorms: |g_d|=7.756e-04 | |λ·g_m|=4.291e-04
#  [Auto-Lambda] Epoch 30: Adjusted 5.87e-03 -> 4.98e-03 (ratio=7.198e-01)
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:12 | Remaining: ~0:07:39 | ETA: 13:13:20
#   Epoch time: 2.72s | Avg: 1.78s
#   Total: 2.3514e-01 | Data(mse): 2.3088e-01
#   Misfit(RMS χ²): 8.883 | Rough: 8.56e-01 | Lam: 0.0049776
#   OT-distance(6D, view-only): 5.187289e-03
#   GradNorms: |g_d|=2.863e-04 | |λ·g_m|=1.593e-04
#  [Auto-Lambda] Epoch 50: Adjusted 4.98e-03 -> 4.18e-03 (ratio=7.050e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 4.18e-03 -> 3.54e-03 (ratio=7.175e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:48 | Remaining: ~0:07:05 | ETA: 13:13:22
#   Epoch time: 2.18s | Avg: 1.78s
#   Total: 2.3180e-01 | Data(mse): 2.2845e-01
#   Misfit(RMS χ²): 8.836 | Rough: 9.47e-01 | Lam: 0.0035402
#   OT-distance(6D, view-only): 5.182763e-03
#   GradNorms: |g_d|=1.289e-04 | |λ·g_m|=7.932e-05
#  [Auto-Lambda] Epoch 70: Adjusted 3.54e-03 -> 3.10e-03 (ratio=7.676e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 3.10e-03 -> 2.79e-03 (ratio=8.064e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:23 | Remaining: ~0:06:28 | ETA: 13:13:19
#   Epoch time: 2.07s | Avg: 1.77s
#   Total: 2.2915e-01 | Data(mse): 2.2540e-01
#   Misfit(RMS χ²): 8.777 | Rough: 1.35e+00 | Lam: 0.0027853
#   OT-distance(6D, view-only): 5.106205e-03
#   GradNorms: |g_d|=1.157e-04 | |λ·g_m|=6.577e-05
#  [Auto-Lambda] Epoch 90: Adjusted 2.79e-03 -> 2.48e-03 (ratio=7.936e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 2.48e-03 -> 2.19e-03 (ratio=7.784e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:03:00 | Remaining: ~0:05:56 | ETA: 13:13:25
#   Epoch time: 2.37s | Avg: 1.79s
#   Total: 2.2521e-01 | Data(mse): 2.2061e-01
#   Misfit(RMS χ²): 8.683 | Rough: 2.10e+00 | Lam: 0.0021891
#   OT-distance(6D, view-only): 5.445006e-03
#   GradNorms: |g_d|=1.071e-04 | |λ·g_m|=6.140e-05
#  [Auto-Lambda] Epoch 110: Adjusted 2.19e-03 -> 1.81e-03 (ratio=6.821e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 1.81e-03 -> 1.44e-03 (ratio=6.362e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:36 | Remaining: ~0:05:19 | ETA: 13:13:23
#   Epoch time: 2.09s | Avg: 1.79s
#   Total: 2.2122e-01 | Data(mse): 2.1684e-01
#   Misfit(RMS χ²): 8.609 | Rough: 3.03e+00 | Lam: 0.0014421
#   OT-distance(6D, view-only): 6.562965e-03
#   GradNorms: |g_d|=7.436e-05 | |λ·g_m|=4.782e-05
#  [Auto-Lambda] Epoch 130: Adjusted 1.44e-03 -> 1.20e-03 (ratio=6.972e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.20e-03 -> 1.03e-03 (ratio=7.346e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:04:11 | Remaining: ~0:04:43 | ETA: 13:13:24
#   Epoch time: 2.26s | Avg: 1.79s
#   Total: 2.1904e-01 | Data(mse): 2.1537e-01
#   Misfit(RMS χ²): 8.580 | Rough: 3.56e+00 | Lam: 0.0010321
#   OT-distance(6D, view-only): 6.787653e-03
#   GradNorms: |g_d|=6.282e-05 | |λ·g_m|=3.781e-05
#  [Auto-Lambda] Epoch 150: Adjusted 1.03e-03 -> 8.90e-04 (ratio=7.434e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 8.90e-04 -> 7.80e-04 (ratio=7.677e-01)
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:47 | Remaining: ~0:04:07 | ETA: 13:13:23
#   Epoch time: 2.19s | Avg: 1.78s
#   Total: 2.1746e-01 | Data(mse): 2.1428e-01
#   Misfit(RMS χ²): 8.558 | Rough: 4.08e+00 | Lam: 0.0007797
#   OT-distance(6D, view-only): 6.946171e-03
#   GradNorms: |g_d|=5.340e-05 | |λ·g_m|=3.102e-05
#  [Auto-Lambda] Epoch 170: Adjusted 7.80e-04 -> 6.90e-04 (ratio=7.824e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 6.90e-04 -> 6.13e-04 (ratio=7.908e-01)
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:05:22 | Remaining: ~0:03:31 | ETA: 13:13:22
#   Epoch time: 2.28s | Avg: 1.78s
#   Total: 2.1615e-01 | Data(mse): 2.1329e-01
#   Misfit(RMS χ²): 8.538 | Rough: 4.66e+00 | Lam: 0.0006133
#   OT-distance(6D, view-only): 7.093869e-03
#   GradNorms: |g_d|=4.697e-05 | |λ·g_m|=2.634e-05
#  [Auto-Lambda] Epoch 190: Adjusted 6.13e-04 -> 5.49e-04 (ratio=8.007e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 5.49e-04 -> 4.89e-04 (ratio=7.926e-01)
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:05:58 | Remaining: ~0:02:56 | ETA: 13:13:23
#   Epoch time: 2.32s | Avg: 1.78s
#   Total: 2.1501e-01 | Data(mse): 2.1244e-01
#   Misfit(RMS χ²): 8.521 | Rough: 5.28e+00 | Lam: 0.0004886
#   OT-distance(6D, view-only): 7.213863e-03
#   GradNorms: |g_d|=3.987e-05 | |λ·g_m|=2.246e-05
#  [Auto-Lambda] Epoch 210: Adjusted 4.89e-04 -> 4.31e-04 (ratio=7.776e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 4.31e-04 -> 3.77e-04 (ratio=7.661e-01)
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:06:35 | Remaining: ~0:02:21 | ETA: 13:13:25
#   Epoch time: 2.57s | Avg: 1.79s
#   Total: 2.1399e-01 | Data(mse): 2.1176e-01
#   Misfit(RMS χ²): 8.507 | Rough: 5.90e+00 | Lam: 0.0003771
#   OT-distance(6D, view-only): 7.328929e-03
#   GradNorms: |g_d|=3.184e-05 | |λ·g_m|=1.838e-05
#  [Auto-Lambda] Epoch 230: Adjusted 3.77e-04 -> 3.31e-04 (ratio=7.687e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 3.31e-04 -> 2.92e-04 (ratio=7.795e-01)
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:07:11 | Remaining: ~0:01:45 | ETA: 13:13:25
#   Epoch time: 2.28s | Avg: 1.79s
#   Total: 2.1315e-01 | Data(mse): 2.1123e-01
#   Misfit(RMS χ²): 8.497 | Rough: 6.55e+00 | Lam: 0.0002919
#   OT-distance(6D, view-only): 7.433331e-03
#   GradNorms: |g_d|=2.636e-05 | |λ·g_m|=1.504e-05
#  [Auto-Lambda] Epoch 250: Adjusted 2.92e-04 -> 2.60e-04 (ratio=7.922e-01)
#  [Auto-Lambda] Epoch 260: Adjusted 2.60e-04 -> 2.34e-04 (ratio=8.106e-01)
# Epoch 261/300 [  87.0%]
#   Elapsed: 0:07:47 | Remaining: ~0:01:09 | ETA: 13:13:26
#   Epoch time: 2.19s | Avg: 1.79s
#   Total: 2.1248e-01 | Data(mse): 2.1078e-01
#   Misfit(RMS χ²): 8.488 | Rough: 7.28e+00 | Lam: 0.0002339
#   OT-distance(6D, view-only): 7.519258e-03
#   GradNorms: |g_d|=2.289e-05 | |λ·g_m|=1.279e-05
#  [Auto-Lambda] Epoch 270: Adjusted 2.34e-04 -> 2.14e-04 (ratio=8.339e-01)
#  [Auto-Lambda] Epoch 280: Adjusted 2.14e-04 -> 1.98e-04 (ratio=8.569e-01)
# Epoch 281/300 [  93.7%]
#   Elapsed: 0:08:23 | Remaining: ~0:00:34 | ETA: 13:13:25
#   Epoch time: 2.19s | Avg: 1.79s
#   Total: 2.1194e-01 | Data(mse): 2.1033e-01
#   Misfit(RMS χ²): 8.479 | Rough: 8.16e+00 | Lam: 0.0001977
#   OT-distance(6D, view-only): 7.577249e-03
#   GradNorms: |g_d|=2.138e-05 | |λ·g_m|=1.160e-05
#  [Auto-Lambda] Epoch 290: Adjusted 1.98e-04 -> 1.86e-04 (ratio=8.800e-01)
# Epoch 300/300 [ 100.0%]
#   Elapsed: 0:08:55 | Remaining: ~0:00:00 | ETA: 13:13:23
#   Epoch time: 2.16s | Avg: 1.78s
#   Total: 2.1154e-01 | Data(mse): 2.0982e-01
#   Misfit(RMS χ²): 8.468 | Rough: 9.30e+00 | Lam: 0.0001855
#   OT-distance(6D, view-only): 7.593252e-03
#   GradNorms: |g_d|=2.153e-05 | |λ·g_m|=1.193e-05
# Inversion completed.
# MSE inversion done
# 1e-10 0.2609154067282792

# %%
# 5b) MSE 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.9002

# %%
# 6b) 保存 MSE 结果
mse_run_dir = logger.save_from_inverter(inv, run_name="mse_21_1shift0.1")
history_mse = list(inv.loss_history)
print(f"MSE run saved: {mse_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d1/2026-07-06_13-13-47_mse_21_1shift0.1
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.9002
# /home/liuxr/MTinv_OT3/src/mt2d_inv/plotting/inversion.py:682: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axes = plt.subplots(
#   ✓ data_fitting: 21 plots saved to test_results/ccmm2d1/2026-07-06_13-13-47_mse_21_1shift0.1/figures/data_fitting (21 stations)
#   ✓ Figures saved to test_results/ccmm2d1/2026-07-06_13-13-47_mse_21_1shift0.1/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d1/2026-07-06_13-13-47_mse_21_1shift0.1
#   Final RMS χ²: 8.4684
#   RMSE: 0.2414
#   MAPE: 9.47%
# ============================================================
#
# MSE run saved: test_results/ccmm2d1/2026-07-06_13-13-47_mse_21_1shift0.1

# %%
# 7) OT vs MSE 对比（收敛曲线 + 视电阻率四线合一 + 伪断面）
plot_ot_mse_convergence(history_ot, history_mse, target_misfit=1.05)

plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=0,
    mode="xy",
)
plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=0,
    mode="yx",
)

plot_ot_mse_pseudosection_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    mode="xy",
)
# Out:
# /home/liuxr/MTinv_OT3/src/mt2d_inv/plotting/pseudosection.py:171: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# {'inversion_axes': array([[<Axes: title={'center': 'True'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#          <Axes: title={'center': 'OT inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#          <Axes: title={'center': 'MSE inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>]],
#        dtype=object),
#  'observed_axes': <Axes: title={'center': 'Observed (rhoxy)'}, xlabel='Distance (km)', ylabel='Period (s)'>}
