# %% [markdown]
# # COMMEMI 2D-4：静位移下 OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d4` 生成标准模型，在合成数据上施加静位移后，
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演，并对比收敛曲线与视电阻率拟合。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d4",
    output_root=Path("test_results"),
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/MTinv_OT3

# %%
import os
from pathlib import Path

print(f"当前目录: {Path.cwd()}")
print(f"目录内容: {list(Path.cwd().iterdir())}")

# 检查 src 在哪里
for p in [Path.cwd(), Path.cwd().parent, Path.cwd().parent.parent]:
    if (p / "src").exists():
        print(f"找到 src 在: {p}")
# Out:
# 当前目录: /home/liuxr/MTinv_OT3/tests/synthetic
# 目录内容: [PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_ot_21.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/.ipynb_checkpoints'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.2.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.15.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.2.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_mse_31.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/test_results'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.1.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_mse_21.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.15.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.1.ipynb')]
# 找到 src 在: /home/liuxr/MTinv_OT3

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d4(
    nza=10,
    device=device, 
)

# 2) Survey setup
freqs = torch.logspace(0, -5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=10,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.01,
                        noise_type="gaussian",
                        static_shift_std=0.15,   # 0.15 会导致电阻率发生约半个量级的剧烈上下平移
                        shift_modes=("xy", "yx"),# 作用于双极化模式 (TM 模式通常对畸变最敏感)
                        shift_stations="random")
inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0],synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.846331e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 1.0% (gaussian)
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4a) OT 反演 (6dot)
inv.initialize_model(initial_sigma=0.01)
final_sigma_ot = inv.run_inversion(
    n_epochs=300,
    mode="6dot",
    progress_interval=20,
    current_lambda=0.01,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("OT inversion done")
print(final_sigma_ot.min().item(), final_sigma_ot.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:02 | Remaining: ~0:07:37 | ETA: 13:12:39
#   Epoch time: 1.53s | Avg: 1.53s
#   Total: 5.6323e-01 | Data(6dot): 5.6323e-01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 64.613 | Rough: 0.00e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 5.632340e-01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e-02 -> 5.70e-03 (ratio=3.245e-01)
#  [Auto-Lambda] Epoch 20: Adjusted 5.70e-03 -> 4.65e-03 (ratio=6.668e-01)
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:38 | Remaining: ~0:08:23 | ETA: 13:14:02
#   Epoch time: 2.30s | Avg: 1.80s
#   Total: 2.6504e-01 | Data(6dot): 2.4815e-01
#   Misfit(RMS χ²): 46.044 | Rough: 3.63e+00 | Lam: 0.0046514
#   OT-distance(6D, view-only): 2.481522e-01
#   GradNorms: |g_d|=6.547e-04 | |λ·g_m|=3.932e-04
#  [Auto-Lambda] Epoch 40: Adjusted 4.65e-03 -> 4.40e-03 (ratio=8.965e-01)
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:15 | Remaining: ~0:07:50 | ETA: 13:14:06
#   Epoch time: 2.11s | Avg: 1.82s
#   Total: 1.5460e-01 | Data(6dot): 1.2023e-01
#   Misfit(RMS χ²): 36.997 | Rough: 7.80e+00 | Lam: 0.0044041
#   OT-distance(6D, view-only): 1.202310e-01
#   GradNorms: |g_d|=4.718e-04 | |λ·g_m|=2.482e-04
#  [Auto-Lambda] Epoch 50: Adjusted 4.40e-03 -> 3.84e-03 (ratio=7.601e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 3.84e-03 -> 3.31e-03 (ratio=7.416e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:50 | Remaining: ~0:07:09 | ETA: 13:14:00
#   Epoch time: 2.20s | Avg: 1.80s
#   Total: 1.0470e-01 | Data(6dot): 7.2399e-02
#   Misfit(RMS χ²): 30.630 | Rough: 9.77e+00 | Lam: 0.0033066
#   OT-distance(6D, view-only): 7.239895e-02
#   GradNorms: |g_d|=2.888e-04 | |λ·g_m|=1.699e-04
#  [Auto-Lambda] Epoch 70: Adjusted 3.31e-03 -> 2.82e-03 (ratio=7.284e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 2.82e-03 -> 2.46e-03 (ratio=7.603e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:29 | Remaining: ~0:06:42 | ETA: 13:14:12
#   Epoch time: 2.58s | Avg: 1.84s
#   Total: 7.6899e-02 | Data(6dot): 4.9853e-02
#   Misfit(RMS χ²): 26.004 | Rough: 1.10e+01 | Lam: 0.0024607
#   OT-distance(6D, view-only): 4.985346e-02
#   GradNorms: |g_d|=2.222e-04 | |λ·g_m|=1.283e-04
#  [Auto-Lambda] Epoch 90: Adjusted 2.46e-03 -> 2.18e-03 (ratio=7.829e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 2.18e-03 -> 1.91e-03 (ratio=7.671e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:03:06 | Remaining: ~0:06:04 | ETA: 13:14:11
#   Epoch time: 2.18s | Avg: 1.83s
#   Total: 5.9658e-02 | Data(6dot): 3.6652e-02
#   Misfit(RMS χ²): 22.432 | Rough: 1.21e+01 | Lam: 0.0019070
#   OT-distance(6D, view-only): 3.665158e-02
#   GradNorms: |g_d|=1.760e-04 | |λ·g_m|=1.018e-04
#  [Auto-Lambda] Epoch 110: Adjusted 1.91e-03 -> 1.66e-03 (ratio=7.558e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 1.66e-03 -> 1.44e-03 (ratio=7.524e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:42 | Remaining: ~0:05:27 | ETA: 13:14:09
#   Epoch time: 2.39s | Avg: 1.83s
#   Total: 4.6923e-02 | Data(6dot): 2.8194e-02
#   Misfit(RMS χ²): 19.608 | Rough: 1.30e+01 | Lam: 0.0014381
#   OT-distance(6D, view-only): 2.819368e-02
#   GradNorms: |g_d|=1.353e-04 | |λ·g_m|=7.896e-05
#  [Auto-Lambda] Epoch 130: Adjusted 1.44e-03 -> 1.25e-03 (ratio=7.574e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.25e-03 -> 1.09e-03 (ratio=7.630e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:04:18 | Remaining: ~0:04:50 | ETA: 13:14:09
#   Epoch time: 2.29s | Avg: 1.83s
#   Total: 3.7719e-02 | Data(6dot): 2.2519e-02
#   Misfit(RMS χ²): 17.457 | Rough: 1.39e+01 | Lam: 0.0010933
#   OT-distance(6D, view-only): 2.251915e-02
#   GradNorms: |g_d|=1.059e-04 | |λ·g_m|=6.126e-05
#  [Auto-Lambda] Epoch 150: Adjusted 1.09e-03 -> 9.60e-04 (ratio=7.705e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 9.60e-04 -> 8.48e-04 (ratio=7.806e-01)
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:55 | Remaining: ~0:04:14 | ETA: 13:14:10
#   Epoch time: 2.60s | Avg: 1.83s
#   Total: 3.1086e-02 | Data(6dot): 1.8652e-02
#   Misfit(RMS χ²): 15.870 | Rough: 1.47e+01 | Lam: 0.0008479
#   OT-distance(6D, view-only): 1.865163e-02
#   GradNorms: |g_d|=8.455e-05 | |λ·g_m|=4.829e-05
#  [Auto-Lambda] Epoch 170: Adjusted 8.48e-04 -> 7.55e-04 (ratio=7.935e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 7.55e-04 -> 6.79e-04 (ratio=8.070e-01)
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:05:32 | Remaining: ~0:03:37 | ETA: 13:14:10
#   Epoch time: 2.29s | Avg: 1.83s
#   Total: 2.6346e-02 | Data(6dot): 1.5965e-02
#   Misfit(RMS χ²): 14.704 | Rough: 1.53e+01 | Lam: 0.0006785
#   OT-distance(6D, view-only): 1.596475e-02
#   GradNorms: |g_d|=6.984e-05 | |λ·g_m|=3.917e-05
#  [Auto-Lambda] Epoch 190: Adjusted 6.79e-04 -> 6.14e-04 (ratio=8.202e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 6.14e-04 -> 5.61e-04 (ratio=8.325e-01)
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:06:09 | Remaining: ~0:03:01 | ETA: 13:14:11
#   Epoch time: 2.30s | Avg: 1.83s
#   Total: 2.2918e-02 | Data(6dot): 1.4052e-02
#   Misfit(RMS χ²): 13.838 | Rough: 1.58e+01 | Lam: 0.0005607
#   OT-distance(6D, view-only): 1.405174e-02
#   GradNorms: |g_d|=5.939e-05 | |λ·g_m|=3.275e-05
#  [Auto-Lambda] Epoch 210: Adjusted 5.61e-04 -> 5.15e-04 (ratio=8.438e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 5.15e-04 -> 4.76e-04 (ratio=8.539e-01)
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:06:47 | Remaining: ~0:02:25 | ETA: 13:14:12
#   Epoch time: 2.50s | Avg: 1.84s
#   Total: 2.0366e-02 | Data(6dot): 1.2642e-02
#   Misfit(RMS χ²): 13.179 | Rough: 1.62e+01 | Lam: 0.0004759
#   OT-distance(6D, view-only): 1.264166e-02
#   GradNorms: |g_d|=5.168e-05 | |λ·g_m|=2.811e-05
#  [Auto-Lambda] Epoch 230: Adjusted 4.76e-04 -> 4.42e-04 (ratio=8.630e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 4.42e-04 -> 4.13e-04 (ratio=8.715e-01)
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:07:24 | Remaining: ~0:01:48 | ETA: 13:14:13
#   Epoch time: 2.29s | Avg: 1.84s
#   Total: 1.8400e-02 | Data(6dot): 1.1557e-02
#   Misfit(RMS χ²): 12.658 | Rough: 1.66e+01 | Lam: 0.0004127
#   OT-distance(6D, view-only): 1.155662e-02
#   GradNorms: |g_d|=4.584e-05 | |λ·g_m|=2.466e-05
#  [Auto-Lambda] Epoch 250: Adjusted 4.13e-04 -> 3.87e-04 (ratio=8.797e-01)
#  [Auto-Lambda] Epoch 260: Adjusted 3.87e-04 -> 3.65e-04 (ratio=8.877e-01)
# Epoch 261/300 [  87.0%]
#   Elapsed: 0:08:00 | Remaining: ~0:01:11 | ETA: 13:14:12
#   Epoch time: 2.24s | Avg: 1.84s
#   Total: 1.6844e-02 | Data(6dot): 1.0683e-02
#   Misfit(RMS χ²): 12.228 | Rough: 1.69e+01 | Lam: 0.0003647
#   OT-distance(6D, view-only): 1.068269e-02
#   GradNorms: |g_d|=4.147e-05 | |λ·g_m|=2.209e-05
#  [Auto-Lambda] Epoch 270: Adjusted 3.65e-04 -> 3.45e-04 (ratio=8.956e-01)
# Epoch 281/300 [  93.7%]
#   Elapsed: 0:08:36 | Remaining: ~0:00:34 | ETA: 13:14:11
#   Epoch time: 2.20s | Avg: 1.83s
#   Total: 1.5881e-02 | Data(6dot): 9.9487e-03
#   Misfit(RMS χ²): 11.858 | Rough: 1.72e+01 | Lam: 0.0003451
#   OT-distance(6D, view-only): 9.948731e-03
#   GradNorms: |g_d|=3.826e-05 | |λ·g_m|=2.125e-05
#  [Auto-Lambda] Epoch 290: Adjusted 3.45e-04 -> 3.23e-04 (ratio=8.779e-01)
# Epoch 300/300 [ 100.0%]
#   Elapsed: 0:09:10 | Remaining: ~0:00:00 | ETA: 13:14:10
#   Epoch time: 2.28s | Avg: 1.83s
#   Total: 1.4989e-02 | Data(6dot): 9.3591e-03
#   Misfit(RMS χ²): 11.547 | Rough: 1.74e+01 | Lam: 0.0003234
#   OT-distance(6D, view-only): 9.359120e-03
#   GradNorms: |g_d|=3.617e-05 | |λ·g_m|=2.023e-05
# Inversion completed.
# OT inversion done
# 1e-10 0.11170568411199834

# %%
# 5a) OT 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.8398

# %%
# 6a) 保存 OT 结果
ot_run_dir = logger.save_from_inverter(inv, run_name="ot_21_4shift0.1")
history_ot = list(inv.loss_history)
print(f"OT run saved: {ot_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d4/2026-07-06_13-14-35_ot_21_4shift0.1
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.8398
# /home/liuxr/MTinv_OT3/src/mt2d_inv/plotting/inversion.py:682: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   for batch_start in range(0, len(station_indices), stations_per_figure):
#   ✓ data_fitting: 21 plots saved to test_results/ccmm2d4/2026-07-06_13-14-35_ot_21_4shift0.1/figures/data_fitting (21 stations)
#   ✓ Figures saved to test_results/ccmm2d4/2026-07-06_13-14-35_ot_21_4shift0.1/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d4/2026-07-06_13-14-35_ot_21_4shift0.1
#   Final RMS χ²: 11.5474
#   RMSE: 0.5771
#   MAPE: 17.57%
# ============================================================
#
# OT run saved: test_results/ccmm2d4/2026-07-06_13-14-35_ot_21_4shift0.1

# %%
# 4b) MSE 反演（同一静位移观测数据，重置初模）
inv.initialize_model(initial_sigma=0.01)
final_sigma_mse = inv.run_inversion(
    n_epochs=300,
    mode="mse",
    progress_interval=20,
    current_lambda=0.01,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("MSE inversion done")
print(final_sigma_mse.min().item(), final_sigma_mse.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:01 | Remaining: ~0:07:24 | ETA: 13:22:29
#   Epoch time: 1.49s | Avg: 1.49s
#   Total: 1.2215e+01 | Data(mse): 1.2215e+01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 64.613 | Rough: 0.00e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 5.632340e-01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:36 | Remaining: ~0:08:03 | ETA: 13:23:44
#   Epoch time: 2.05s | Avg: 1.73s
#   Total: 5.0078e+00 | Data(mse): 4.9414e+00
#   Misfit(RMS χ²): 41.097 | Rough: 6.65e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 3.488087e-01
#   GradNorms: |g_d|=2.778e-02 | |λ·g_m|=8.684e-04
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:10 | Remaining: ~0:07:24 | ETA: 13:23:38
#   Epoch time: 2.12s | Avg: 1.71s
#   Total: 2.3846e+00 | Data(mse): 2.2933e+00
#   Misfit(RMS χ²): 27.997 | Rough: 9.13e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 2.002709e-01
#   GradNorms: |g_d|=1.746e-02 | |λ·g_m|=9.355e-04
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:43 | Remaining: ~0:06:43 | ETA: 13:23:30
#   Epoch time: 1.98s | Avg: 1.69s
#   Total: 1.2367e+00 | Data(mse): 1.1354e+00
#   Misfit(RMS χ²): 19.699 | Rough: 1.01e+01 | Lam: 0.0100000
#   OT-distance(6D, view-only): 1.198500e-01
#   GradNorms: |g_d|=1.066e-02 | |λ·g_m|=8.068e-04
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:15 | Remaining: ~0:06:07 | ETA: 13:23:26
#   Epoch time: 2.04s | Avg: 1.68s
#   Total: 7.9955e-01 | Data(mse): 6.9946e-01
#   Misfit(RMS χ²): 15.462 | Rough: 1.00e+01 | Lam: 0.0100000
#   OT-distance(6D, view-only): 7.939809e-02
#   GradNorms: |g_d|=3.912e-03 | |λ·g_m|=6.614e-04
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:02:49 | Remaining: ~0:05:33 | ETA: 13:23:27
#   Epoch time: 2.09s | Avg: 1.68s
#   Total: 6.2416e-01 | Data(mse): 5.3093e-01
#   Misfit(RMS χ²): 13.471 | Rough: 9.32e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 5.974707e-02
#   GradNorms: |g_d|=1.934e-03 | |λ·g_m|=5.313e-04
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:22 | Remaining: ~0:04:59 | ETA: 13:23:25
#   Epoch time: 2.10s | Avg: 1.67s
#   Total: 5.3332e-01 | Data(mse): 4.4526e-01
#   Misfit(RMS χ²): 12.337 | Rough: 8.81e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 4.988084e-02
#   GradNorms: |g_d|=1.721e-03 | |λ·g_m|=4.711e-04
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:03:55 | Remaining: ~0:04:25 | ETA: 13:23:24
#   Epoch time: 1.97s | Avg: 1.67s
#   Total: 4.8148e-01 | Data(mse): 3.9890e-01
#   Misfit(RMS χ²): 11.677 | Rough: 8.26e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 4.183168e-02
#   GradNorms: |g_d|=1.615e-03 | |λ·g_m|=3.858e-04
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:28 | Remaining: ~0:03:52 | ETA: 13:23:24
#   Epoch time: 2.09s | Avg: 1.67s
#   Total: 4.4892e-01 | Data(mse): 3.6690e-01
#   Misfit(RMS χ²): 11.198 | Rough: 8.20e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 3.655176e-02
#   GradNorms: |g_d|=1.535e-03 | |λ·g_m|=3.508e-04
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:05:02 | Remaining: ~0:03:18 | ETA: 13:23:25
#   Epoch time: 2.26s | Avg: 1.67s
#   Total: 4.2689e-01 | Data(mse): 3.4407e-01
#   Misfit(RMS χ²): 10.844 | Rough: 8.28e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 3.302224e-02
#   GradNorms: |g_d|=1.453e-03 | |λ·g_m|=3.532e-04
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:05:35 | Remaining: ~0:02:45 | ETA: 13:23:24
#   Epoch time: 2.00s | Avg: 1.67s
#   Total: 4.1109e-01 | Data(mse): 3.2679e-01
#   Misfit(RMS χ²): 10.569 | Rough: 8.43e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 3.044226e-02
#   GradNorms: |g_d|=1.373e-03 | |λ·g_m|=3.852e-04
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:06:09 | Remaining: ~0:02:12 | ETA: 13:23:25
#   Epoch time: 2.05s | Avg: 1.67s
#   Total: 3.9917e-01 | Data(mse): 3.1309e-01
#   Misfit(RMS χ²): 10.345 | Rough: 8.61e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 2.848119e-02
#   GradNorms: |g_d|=1.287e-03 | |λ·g_m|=3.780e-04
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:06:42 | Remaining: ~0:01:38 | ETA: 13:23:24
#   Epoch time: 2.25s | Avg: 1.67s
#   Total: 3.8995e-01 | Data(mse): 3.0200e-01
#   Misfit(RMS χ²): 10.160 | Rough: 8.79e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 2.694041e-02
#   GradNorms: |g_d|=1.201e-03 | |λ·g_m|=4.418e-04
# Epoch 261/300 [  87.0%]
#   Elapsed: 0:07:15 | Remaining: ~0:01:04 | ETA: 13:23:23
#   Epoch time: 2.01s | Avg: 1.67s
#   Total: 3.8255e-01 | Data(mse): 2.9286e-01
#   Misfit(RMS χ²): 10.005 | Rough: 8.97e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 2.569869e-02
#   GradNorms: |g_d|=1.115e-03 | |λ·g_m|=4.353e-04
# Epoch 281/300 [  93.7%]
#   Elapsed: 0:07:48 | Remaining: ~0:00:31 | ETA: 13:23:23
#   Epoch time: 1.97s | Avg: 1.67s
#   Total: 3.7657e-01 | Data(mse): 2.8522e-01
#   Misfit(RMS χ²): 9.873 | Rough: 9.14e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 2.467601e-02
#   GradNorms: |g_d|=1.033e-03 | |λ·g_m|=4.195e-04
# Epoch 300/300 [ 100.0%]
#   Elapsed: 0:08:19 | Remaining: ~0:00:00 | ETA: 13:23:23
#   Epoch time: 2.09s | Avg: 1.67s
#   Total: 3.7195e-01 | Data(mse): 2.7906e-01
#   Misfit(RMS χ²): 9.766 | Rough: 9.29e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 2.385680e-02
#   GradNorms: |g_d|=9.600e-04 | |λ·g_m|=4.602e-04
# Inversion completed.
# MSE inversion done
# 1e-10 0.4657351190487202

# %%
# 5b) MSE 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.8531

# %%
# 6b) 保存 MSE 结果
mse_run_dir = logger.save_from_inverter(inv, run_name="mse21_4shift0.1")
history_mse = list(inv.loss_history)
print(f"MSE run saved: {mse_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d4/2026-07-06_13-23-45_mse21_4shift0.1
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.8531
# /home/liuxr/MTinv_OT3/src/mt2d_inv/plotting/inversion.py:682: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   for batch_start in range(0, len(station_indices), stations_per_figure):
#   ✓ data_fitting: 21 plots saved to test_results/ccmm2d4/2026-07-06_13-23-45_mse21_4shift0.1/figures/data_fitting (21 stations)
#   ✓ Figures saved to test_results/ccmm2d4/2026-07-06_13-23-45_mse21_4shift0.1/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d4/2026-07-06_13-23-45_mse21_4shift0.1
#   Final RMS χ²: 9.7664
#   RMSE: 0.5772
#   MAPE: 20.59%
# ============================================================
#
# MSE run saved: test_results/ccmm2d4/2026-07-06_13-23-45_mse21_4shift0.1

# %%
# 7) OT vs MSE 对比（收敛曲线 + 视电阻率四线合一 + 伪断面）
_shift_ids = getattr(inv, "shift_station_ids", []) or []
_st_km = inv.stations.detach().cpu().numpy() / 1000.0
print(f"静位移影响台站 ({len(_shift_ids)}/{len(_st_km)}): " + ", ".join(
    f"idx={i} ({_st_km[i]:.1f} km)" for i in _shift_ids
) if _shift_ids else "无")

plot_ot_mse_convergence(history_ot, history_mse, target_misfit=1.05)

plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=8,
    mode="xy",
)
plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=8,
    mode="yx",
)

plot_ot_mse_pseudosection_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    mode="xy",
)
# Out:
# 静位移影响台站 (2/21): idx=8 (-3.0 km), idx=17 (10.5 km)
# /home/liuxr/MTinv_OT3/src/mt2d_inv/plotting/pseudosection.py:171: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# {'inversion_axes': array([[<Axes: title={'center': 'True'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#          <Axes: title={'center': 'OT inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#          <Axes: title={'center': 'MSE inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>]],
#        dtype=object),
#  'observed_axes': <Axes: title={'center': 'Observed (rhoxy)'}, xlabel='Distance (km)', ylabel='Period (s)'>}
