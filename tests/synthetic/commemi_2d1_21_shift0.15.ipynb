# %% [markdown]
# # COMMEMI 2D-1：静位移下 OT vs MSE 反演对比
#
# 使用 `MT2DTrueModels.create_commemi_2d1` 生成标准模型，在合成数据上施加静位移后，
# 分别用 **6D OT**（`mode="6dot"`）与 **MSE**（`mode="mse"`）反演，并对比收敛曲线与视电阻率拟合。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d1",
    output_root=Path("test_results"),
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/MTinv_OT3

# %%
import os
from pathlib import Path

print(f"当前目录: {Path.cwd()}")
print(f"目录内容: {list(Path.cwd().iterdir())}")

# 检查 src 在哪里
for p in [Path.cwd(), Path.cwd().parent, Path.cwd().parent.parent]:
    if (p / "src").exists():
        print(f"找到 src 在: {p}")
# Out:
# 当前目录: /home/liuxr/MTinv_OT3/tests/synthetic
# 目录内容: [PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_ot_21.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/.ipynb_checkpoints'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.15.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/test_results'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d1_21_shift0.1.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/rubic_mse_21.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.15.ipynb'), PosixPath('/home/liuxr/MTinv_OT3/tests/synthetic/commemi_2d4_21_shift0.1.ipynb')]
# 找到 src 在: /home/liuxr/MTinv_OT3

# %%
# 1) Build COMMEMI 2D-i true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d1(
    zn=None,
    yn=None,
    nza=10,
    device=device,
    rho_host=100.0,
    rho_block=10.0,
    y_half_width_m=2000.0,
    z_top_m=10000.0,
    z_bottom_m=30000.0,
)

# 2) Survey setup
freqs = torch.logspace(0, -5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=10,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(noise_level=0.01,
                        noise_type="gaussian",
                        static_shift_std=0.15,   # 0.15 会导致电阻率发生约半个量级的剧烈上下平移
                        shift_modes=("xy", "yx"),# 作用于双极化模式 (TM 模式通常对畸变最敏感)
                        shift_stations="random",
                        shift_ratio =0.15)
inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(clip_to_stations=True, ylim=[50, 0],synthetic_figwidth_scale=2.0)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.846255e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 1.0% (gaussian)
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %%
# 4a) OT 反演 (6dot)
inv.initialize_model(initial_sigma=0.01)
final_sigma_ot = inv.run_inversion(
    n_epochs=300,
    mode="6dot",
    progress_interval=20,
    current_lambda=0.01,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("OT inversion done")
print(final_sigma_ot.min().item(), final_sigma_ot.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:02 | Remaining: ~0:08:05 | ETA: 13:04:12
#   Epoch time: 1.62s | Avg: 1.62s
#   Total: 1.2354e-02 | Data(6dot): 1.2354e-02
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 10.475 | Rough: 0.00e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 1.235371e-02
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e-02 -> 1.41e-03 (ratio=2.002e-02)
#  [Auto-Lambda] Epoch 20: Adjusted 1.41e-03 -> 3.38e-04 (ratio=5.722e-02)
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:36 | Remaining: ~0:07:58 | ETA: 13:04:39
#   Epoch time: 2.13s | Avg: 1.71s
#   Total: 6.6962e-03 | Data(6dot): 6.3815e-03
#   Misfit(RMS χ²): 9.690 | Rough: 9.30e-01 | Lam: 0.0003385
#   OT-distance(6D, view-only): 6.381470e-03
#   GradNorms: |g_d|=2.220e-05 | |λ·g_m|=4.966e-05
#  [Auto-Lambda] Epoch 30: Adjusted 3.38e-04 -> 9.03e-05 (ratio=7.113e-02)
#  [Auto-Lambda] Epoch 40: Adjusted 9.03e-05 -> 5.93e-05 (ratio=4.321e-01)
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:09 | Remaining: ~0:07:15 | ETA: 13:04:29
#   Epoch time: 2.02s | Avg: 1.68s
#   Total: 5.9260e-03 | Data(6dot): 5.8473e-03
#   Misfit(RMS χ²): 9.590 | Rough: 1.33e+00 | Lam: 0.0000593
#   OT-distance(6D, view-only): 5.847273e-03
#   GradNorms: |g_d|=9.227e-06 | |λ·g_m|=7.962e-06
#  [Auto-Lambda] Epoch 50: Adjusted 5.93e-05 -> 4.10e-05 (ratio=4.769e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 4.10e-05 -> 3.37e-05 (ratio=6.775e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:43 | Remaining: ~0:06:44 | ETA: 13:04:32
#   Epoch time: 1.98s | Avg: 1.69s
#   Total: 5.6297e-03 | Data(6dot): 5.5629e-03
#   Misfit(RMS χ²): 9.489 | Rough: 1.98e+00 | Lam: 0.0000337
#   OT-distance(6D, view-only): 5.562884e-03
#   GradNorms: |g_d|=5.611e-06 | |λ·g_m|=3.486e-06
#  [Auto-Lambda] Epoch 70: Adjusted 3.37e-05 -> 3.00e-05 (ratio=7.937e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:17 | Remaining: ~0:06:08 | ETA: 13:04:30
#   Epoch time: 2.13s | Avg: 1.68s
#   Total: 5.5049e-03 | Data(6dot): 5.4246e-03
#   Misfit(RMS χ²): 9.445 | Rough: 2.67e+00 | Lam: 0.0000300
#   OT-distance(6D, view-only): 5.424586e-03
#   GradNorms: |g_d|=3.734e-06 | |λ·g_m|=2.044e-06
#  [Auto-Lambda] Epoch 90: Adjusted 3.00e-05 -> 2.82e-05 (ratio=8.827e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 2.82e-05 -> 2.67e-05 (ratio=8.964e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:02:51 | Remaining: ~0:05:36 | ETA: 13:04:32
#   Epoch time: 2.10s | Avg: 1.69s
#   Total: 5.4249e-03 | Data(6dot): 5.3398e-03
#   Misfit(RMS χ²): 9.422 | Rough: 3.18e+00 | Lam: 0.0000267
#   OT-distance(6D, view-only): 5.339773e-03
#   GradNorms: |g_d|=3.055e-06 | |λ·g_m|=1.621e-06
#  [Auto-Lambda] Epoch 110: Adjusted 2.67e-05 -> 2.52e-05 (ratio=8.899e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 2.52e-05 -> 2.36e-05 (ratio=8.771e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:26 | Remaining: ~0:05:03 | ETA: 13:04:34
#   Epoch time: 2.30s | Avg: 1.70s
#   Total: 5.3632e-03 | Data(6dot): 5.2763e-03
#   Misfit(RMS χ²): 9.405 | Rough: 3.68e+00 | Lam: 0.0000236
#   OT-distance(6D, view-only): 5.276304e-03
#   GradNorms: |g_d|=2.643e-06 | |λ·g_m|=1.423e-06
#  [Auto-Lambda] Epoch 130: Adjusted 2.36e-05 -> 2.20e-05 (ratio=8.661e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 2.20e-05 -> 2.04e-05 (ratio=8.583e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:04:01 | Remaining: ~0:04:30 | ETA: 13:04:36
#   Epoch time: 2.07s | Avg: 1.70s
#   Total: 5.3118e-03 | Data(6dot): 5.2251e-03
#   Misfit(RMS χ²): 9.392 | Rough: 4.26e+00 | Lam: 0.0000204
#   OT-distance(6D, view-only): 5.225122e-03
#   GradNorms: |g_d|=2.310e-06 | |λ·g_m|=1.257e-06
#  [Auto-Lambda] Epoch 150: Adjusted 2.04e-05 -> 1.87e-05 (ratio=8.480e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 1.87e-05 -> 1.72e-05 (ratio=8.425e-01)
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:35 | Remaining: ~0:03:56 | ETA: 13:04:36
#   Epoch time: 2.18s | Avg: 1.70s
#   Total: 5.2676e-03 | Data(6dot): 5.1832e-03
#   Misfit(RMS χ²): 9.382 | Rough: 4.90e+00 | Lam: 0.0000172
#   OT-distance(6D, view-only): 5.183223e-03
#   GradNorms: |g_d|=2.011e-06 | |λ·g_m|=1.105e-06
#  [Auto-Lambda] Epoch 170: Adjusted 1.72e-05 -> 1.58e-05 (ratio=8.382e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 1.58e-05 -> 1.44e-05 (ratio=8.361e-01)
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:05:09 | Remaining: ~0:03:23 | ETA: 13:04:37
#   Epoch time: 2.05s | Avg: 1.71s
#   Total: 5.2292e-03 | Data(6dot): 5.1487e-03
#   Misfit(RMS χ²): 9.375 | Rough: 5.58e+00 | Lam: 0.0000144
#   OT-distance(6D, view-only): 5.148748e-03
#   GradNorms: |g_d|=1.753e-06 | |λ·g_m|=9.672e-07
#  [Auto-Lambda] Epoch 190: Adjusted 1.44e-05 -> 1.32e-05 (ratio=8.351e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 1.32e-05 -> 1.20e-05 (ratio=8.343e-01)
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:05:44 | Remaining: ~0:02:49 | ETA: 13:04:37
#   Epoch time: 2.19s | Avg: 1.71s
#   Total: 5.1959e-03 | Data(6dot): 5.1202e-03
#   Misfit(RMS χ²): 9.369 | Rough: 6.29e+00 | Lam: 0.0000120
#   OT-distance(6D, view-only): 5.120247e-03
#   GradNorms: |g_d|=1.531e-06 | |λ·g_m|=8.457e-07
#  [Auto-Lambda] Epoch 210: Adjusted 1.20e-05 -> 1.10e-05 (ratio=8.347e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 1.10e-05 -> 1.00e-05 (ratio=8.355e-01)
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:06:20 | Remaining: ~0:02:15 | ETA: 13:04:39
#   Epoch time: 2.16s | Avg: 1.72s
#   Total: 5.1669e-03 | Data(6dot): 5.0967e-03
#   Misfit(RMS χ²): 9.365 | Rough: 6.99e+00 | Lam: 0.0000100
#   OT-distance(6D, view-only): 5.096731e-03
#   GradNorms: |g_d|=1.339e-06 | |λ·g_m|=7.391e-07
#  [Auto-Lambda] Epoch 230: Adjusted 1.00e-05 -> 9.19e-06 (ratio=8.370e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 9.19e-06 -> 8.42e-06 (ratio=8.389e-01)
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:06:55 | Remaining: ~0:01:41 | ETA: 13:04:41
#   Epoch time: 2.15s | Avg: 1.72s
#   Total: 5.1420e-03 | Data(6dot): 5.0774e-03
#   Misfit(RMS χ²): 9.362 | Rough: 7.68e+00 | Lam: 0.0000084
#   OT-distance(6D, view-only): 5.077414e-03
#   GradNorms: |g_d|=1.174e-06 | |λ·g_m|=6.464e-07
#  [Auto-Lambda] Epoch 250: Adjusted 8.42e-06 -> 7.72e-06 (ratio=8.412e-01)
#  [Auto-Lambda] Epoch 260: Adjusted 7.72e-06 -> 7.09e-06 (ratio=8.438e-01)
# Epoch 261/300 [  87.0%]
#   Elapsed: 0:07:31 | Remaining: ~0:01:07 | ETA: 13:04:43
#   Epoch time: 2.39s | Avg: 1.73s
#   Total: 5.1206e-03 | Data(6dot): 5.0616e-03
#   Misfit(RMS χ²): 9.361 | Rough: 8.33e+00 | Lam: 0.0000071
#   OT-distance(6D, view-only): 5.061578e-03
#   GradNorms: |g_d|=1.032e-06 | |λ·g_m|=5.665e-07
#  [Auto-Lambda] Epoch 270: Adjusted 7.09e-06 -> 6.52e-06 (ratio=8.467e-01)
#  [Auto-Lambda] Epoch 280: Adjusted 6.52e-06 -> 6.01e-06 (ratio=8.498e-01)
# Epoch 281/300 [  93.7%]
#   Elapsed: 0:08:06 | Remaining: ~0:00:32 | ETA: 13:04:43
#   Epoch time: 2.12s | Avg: 1.73s
#   Total: 5.1024e-03 | Data(6dot): 5.0486e-03
#   Misfit(RMS χ²): 9.360 | Rough: 8.95e+00 | Lam: 0.0000060
#   OT-distance(6D, view-only): 5.048579e-03
#   GradNorms: |g_d|=9.112e-07 | |λ·g_m|=4.980e-07
#  [Auto-Lambda] Epoch 290: Adjusted 6.01e-06 -> 5.55e-06 (ratio=8.530e-01)
# Epoch 300/300 [ 100.0%]
#   Elapsed: 0:08:40 | Remaining: ~0:00:00 | ETA: 13:04:45
#   Epoch time: 2.16s | Avg: 1.73s
#   Total: 5.0911e-03 | Data(6dot): 5.0383e-03
#   Misfit(RMS χ²): 9.359 | Rough: 9.50e+00 | Lam: 0.0000056
#   OT-distance(6D, view-only): 5.038344e-03
#   GradNorms: |g_d|=8.126e-07 | |λ·g_m|=4.744e-07
# Inversion completed.
# OT inversion done
# 1e-10 0.07509700603148206

# %%
# 5a) OT 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.9434

# %%
# 6a) 保存 OT 结果
ot_run_dir = logger.save_from_inverter(inv, run_name="ot_21_1shift0.15")
history_ot = list(inv.loss_history)
print(f"OT run saved: {ot_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d1/2026-07-06_13-05-08_ot_21_1shift0.15
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.9434
# /home/liuxr/MTinv_OT3/src/mt2d_inv/plotting/inversion.py:682: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axes = plt.subplots(
#   ✓ data_fitting: 21 plots saved to test_results/ccmm2d1/2026-07-06_13-05-08_ot_21_1shift0.15/figures/data_fitting (21 stations)
#   ✓ Figures saved to test_results/ccmm2d1/2026-07-06_13-05-08_ot_21_1shift0.15/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d1/2026-07-06_13-05-08_ot_21_1shift0.15
#   Final RMS χ²: 9.3594
#   RMSE: 0.1458
#   MAPE: 5.33%
# ============================================================
#
# OT run saved: test_results/ccmm2d1/2026-07-06_13-05-08_ot_21_1shift0.15

# %%
# 4b) MSE 反演（同一静位移观测数据，重置初模）
inv.initialize_model(initial_sigma=0.01)
final_sigma_mse = inv.run_inversion(
    n_epochs=300,
    mode="mse",
    progress_interval=20,
    current_lambda=0.01,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
print("MSE inversion done")
print(final_sigma_mse.min().item(), final_sigma_mse.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/300 [   0.3%]
#   Elapsed: 0:00:01 | Remaining: ~0:08:07 | ETA: 13:13:47
#   Epoch time: 1.63s | Avg: 1.63s
#   Total: 3.2104e-01 | Data(mse): 3.2104e-01
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 10.475 | Rough: 0.00e+00 | Lam: 0.0100000
#   OT-distance(6D, view-only): 1.235371e-02
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
#  [Auto-Lambda] Epoch 10: Adjusted 1.00e-02 -> 6.95e-03 (ratio=4.823e-01)
#  [Auto-Lambda] Epoch 20: Adjusted 6.95e-03 -> 6.01e-03 (ratio=7.491e-01)
# Epoch 21/300 [   7.0%]
#   Elapsed: 0:00:38 | Remaining: ~0:08:28 | ETA: 13:14:44
#   Epoch time: 2.06s | Avg: 1.82s
#   Total: 2.6827e-01 | Data(mse): 2.6414e-01
#   Misfit(RMS χ²): 9.502 | Rough: 6.86e-01 | Lam: 0.0060108
#   OT-distance(6D, view-only): 5.994772e-03
#   GradNorms: |g_d|=7.820e-04 | |λ·g_m|=4.176e-04
#  [Auto-Lambda] Epoch 30: Adjusted 6.01e-03 -> 4.86e-03 (ratio=6.542e-01)
# Epoch 41/300 [  13.7%]
#   Elapsed: 0:01:12 | Remaining: ~0:07:40 | ETA: 13:14:31
#   Epoch time: 2.14s | Avg: 1.78s
#   Total: 2.6298e-01 | Data(mse): 2.5920e-01
#   Misfit(RMS χ²): 9.412 | Rough: 7.77e-01 | Lam: 0.0048618
#   OT-distance(6D, view-only): 5.671299e-03
#   GradNorms: |g_d|=2.565e-04 | |λ·g_m|=1.551e-04
#  [Auto-Lambda] Epoch 50: Adjusted 4.86e-03 -> 4.30e-03 (ratio=7.828e-01)
#  [Auto-Lambda] Epoch 60: Adjusted 4.30e-03 -> 3.72e-03 (ratio=7.474e-01)
# Epoch 61/300 [  20.3%]
#   Elapsed: 0:01:50 | Remaining: ~0:07:13 | ETA: 13:14:42
#   Epoch time: 2.37s | Avg: 1.81s
#   Total: 2.6011e-01 | Data(mse): 2.5667e-01
#   Misfit(RMS χ²): 9.366 | Rough: 9.25e-01 | Lam: 0.0037187
#   OT-distance(6D, view-only): 5.685443e-03
#   GradNorms: |g_d|=1.319e-04 | |λ·g_m|=7.621e-05
#  [Auto-Lambda] Epoch 70: Adjusted 3.72e-03 -> 3.31e-03 (ratio=7.902e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 3.31e-03 -> 2.93e-03 (ratio=7.858e-01)
# Epoch 81/300 [  27.0%]
#   Elapsed: 0:02:26 | Remaining: ~0:06:35 | ETA: 13:14:39
#   Epoch time: 2.24s | Avg: 1.81s
#   Total: 2.5678e-01 | Data(mse): 2.5232e-01
#   Misfit(RMS χ²): 9.286 | Rough: 1.52e+00 | Lam: 0.0029304
#   OT-distance(6D, view-only): 5.823422e-03
#   GradNorms: |g_d|=1.210e-04 | |λ·g_m|=6.870e-05
#  [Auto-Lambda] Epoch 90: Adjusted 2.93e-03 -> 2.49e-03 (ratio=7.204e-01)
#  [Auto-Lambda] Epoch 100: Adjusted 2.49e-03 -> 2.01e-03 (ratio=6.507e-01)
# Epoch 101/300 [  33.7%]
#   Elapsed: 0:03:02 | Remaining: ~0:05:59 | ETA: 13:14:39
#   Epoch time: 2.29s | Avg: 1.81s
#   Total: 2.5237e-01 | Data(mse): 2.4740e-01
#   Misfit(RMS χ²): 9.195 | Rough: 2.48e+00 | Lam: 0.0020063
#   OT-distance(6D, view-only): 6.977766e-03
#   GradNorms: |g_d|=9.191e-05 | |λ·g_m|=5.880e-05
#  [Auto-Lambda] Epoch 110: Adjusted 2.01e-03 -> 1.63e-03 (ratio=6.618e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 1.63e-03 -> 1.37e-03 (ratio=7.045e-01)
# Epoch 121/300 [  40.3%]
#   Elapsed: 0:03:37 | Remaining: ~0:05:21 | ETA: 13:14:37
#   Epoch time: 2.21s | Avg: 1.80s
#   Total: 2.4946e-01 | Data(mse): 2.4521e-01
#   Misfit(RMS χ²): 9.155 | Rough: 3.10e+00 | Lam: 0.0013699
#   OT-distance(6D, view-only): 7.446369e-03
#   GradNorms: |g_d|=7.534e-05 | |λ·g_m|=4.639e-05
#  [Auto-Lambda] Epoch 130: Adjusted 1.37e-03 -> 1.17e-03 (ratio=7.310e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 1.17e-03 -> 1.02e-03 (ratio=7.584e-01)
# Epoch 141/300 [  47.0%]
#   Elapsed: 0:04:12 | Remaining: ~0:04:45 | ETA: 13:14:35
#   Epoch time: 2.21s | Avg: 1.79s
#   Total: 2.4743e-01 | Data(mse): 2.4363e-01
#   Misfit(RMS χ²): 9.125 | Rough: 3.72e+00 | Lam: 0.0010200
#   OT-distance(6D, view-only): 7.737639e-03
#   GradNorms: |g_d|=6.573e-05 | |λ·g_m|=3.876e-05
#  [Auto-Lambda] Epoch 150: Adjusted 1.02e-03 -> 8.98e-04 (ratio=7.743e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 8.98e-04 -> 7.97e-04 (ratio=7.883e-01)
# Epoch 161/300 [  53.7%]
#   Elapsed: 0:04:48 | Remaining: ~0:04:09 | ETA: 13:14:36
#   Epoch time: 2.27s | Avg: 1.79s
#   Total: 2.4575e-01 | Data(mse): 2.4224e-01
#   Misfit(RMS χ²): 9.099 | Rough: 4.39e+00 | Lam: 0.0007969
#   OT-distance(6D, view-only): 7.975807e-03
#   GradNorms: |g_d|=5.890e-05 | |λ·g_m|=3.352e-05
#  [Auto-Lambda] Epoch 170: Adjusted 7.97e-04 -> 7.10e-04 (ratio=7.935e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 7.10e-04 -> 6.33e-04 (ratio=7.958e-01)
# Epoch 181/300 [  60.3%]
#   Elapsed: 0:05:24 | Remaining: ~0:03:33 | ETA: 13:14:35
#   Epoch time: 2.62s | Avg: 1.79s
#   Total: 2.4424e-01 | Data(mse): 2.4100e-01
#   Misfit(RMS χ²): 9.076 | Rough: 5.12e+00 | Lam: 0.0006333
#   OT-distance(6D, view-only): 8.166854e-03
#   GradNorms: |g_d|=5.196e-05 | |λ·g_m|=2.913e-05
#  [Auto-Lambda] Epoch 190: Adjusted 6.33e-04 -> 5.64e-04 (ratio=7.932e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 5.64e-04 -> 5.00e-04 (ratio=7.864e-01)
# Epoch 201/300 [  67.0%]
#   Elapsed: 0:06:01 | Remaining: ~0:02:58 | ETA: 13:14:37
#   Epoch time: 2.23s | Avg: 1.80s
#   Total: 2.4290e-01 | Data(mse): 2.3997e-01
#   Misfit(RMS χ²): 9.056 | Rough: 5.87e+00 | Lam: 0.0005001
#   OT-distance(6D, view-only): 8.344591e-03
#   GradNorms: |g_d|=4.371e-05 | |λ·g_m|=2.480e-05
#  [Auto-Lambda] Epoch 210: Adjusted 5.00e-04 -> 4.41e-04 (ratio=7.766e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 4.41e-04 -> 3.87e-04 (ratio=7.716e-01)
# Epoch 221/300 [  73.7%]
#   Elapsed: 0:06:38 | Remaining: ~0:02:22 | ETA: 13:14:38
#   Epoch time: 2.20s | Avg: 1.80s
#   Total: 2.4175e-01 | Data(mse): 2.3919e-01
#   Misfit(RMS χ²): 9.042 | Rough: 6.60e+00 | Lam: 0.0003871
#   OT-distance(6D, view-only): 8.504535e-03
#   GradNorms: |g_d|=3.556e-05 | |λ·g_m|=2.043e-05
#  [Auto-Lambda] Epoch 230: Adjusted 3.87e-04 -> 3.41e-04 (ratio=7.777e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 3.41e-04 -> 3.04e-04 (ratio=7.908e-01)
# Epoch 241/300 [  80.3%]
#   Elapsed: 0:07:13 | Remaining: ~0:01:46 | ETA: 13:14:37
#   Epoch time: 2.17s | Avg: 1.80s
#   Total: 2.4083e-01 | Data(mse): 2.3861e-01
#   Misfit(RMS χ²): 9.031 | Rough: 7.33e+00 | Lam: 0.0003036
#   OT-distance(6D, view-only): 8.645310e-03
#   GradNorms: |g_d|=2.999e-05 | |λ·g_m|=1.696e-05
#  [Auto-Lambda] Epoch 250: Adjusted 3.04e-04 -> 2.72e-04 (ratio=8.056e-01)
#  [Auto-Lambda] Epoch 260: Adjusted 2.72e-04 -> 2.47e-04 (ratio=8.228e-01)
# Epoch 261/300 [  87.0%]
#   Elapsed: 0:07:49 | Remaining: ~0:01:10 | ETA: 13:14:37
#   Epoch time: 2.20s | Avg: 1.80s
#   Total: 2.4013e-01 | Data(mse): 2.3813e-01
#   Misfit(RMS χ²): 9.022 | Rough: 8.08e+00 | Lam: 0.0002472
#   OT-distance(6D, view-only): 8.759798e-03
#   GradNorms: |g_d|=2.634e-05 | |λ·g_m|=1.459e-05
#  [Auto-Lambda] Epoch 270: Adjusted 2.47e-04 -> 2.27e-04 (ratio=8.417e-01)
#  [Auto-Lambda] Epoch 280: Adjusted 2.27e-04 -> 2.10e-04 (ratio=8.599e-01)
# Epoch 281/300 [  93.7%]
#   Elapsed: 0:08:24 | Remaining: ~0:00:34 | ETA: 13:14:36
#   Epoch time: 2.21s | Avg: 1.79s
#   Total: 2.3957e-01 | Data(mse): 2.3769e-01
#   Misfit(RMS χ²): 9.013 | Rough: 8.92e+00 | Lam: 0.0002103
#   OT-distance(6D, view-only): 8.845027e-03
#   GradNorms: |g_d|=2.431e-05 | |λ·g_m|=1.315e-05
#  [Auto-Lambda] Epoch 290: Adjusted 2.10e-04 -> 1.97e-04 (ratio=8.775e-01)
# Epoch 300/300 [ 100.0%]
#   Elapsed: 0:08:57 | Remaining: ~0:00:00 | ETA: 13:14:34
#   Epoch time: 2.08s | Avg: 1.79s
#   Total: 2.3920e-01 | Data(mse): 2.3725e-01
#   Misfit(RMS χ²): 9.005 | Rough: 9.88e+00 | Lam: 0.0001970
#   OT-distance(6D, view-only): 8.896449e-03
#   GradNorms: |g_d|=2.345e-05 | |λ·g_m|=1.312e-05
# Inversion completed.
# MSE inversion done
# 1e-10 0.40076340695730983

# %%
# 5b) MSE 结果绘图
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()
# Out:
# Model structural similarity (SSIM): 0.8959

# %%
# 6b) 保存 MSE 结果
mse_run_dir = logger.save_from_inverter(inv, run_name="mse_21_1shift0.15")
history_mse = list(inv.loss_history)
print(f"MSE run saved: {mse_run_dir}")
# Out:
# ============================================================
# Saving results to: test_results/ccmm2d1/2026-07-06_13-14-58_mse_21_1shift0.15
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.8959
# /home/liuxr/MTinv_OT3/src/mt2d_inv/plotting/inversion.py:682: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axes = plt.subplots(
#   ✓ data_fitting: 21 plots saved to test_results/ccmm2d1/2026-07-06_13-14-58_mse_21_1shift0.15/figures/data_fitting (21 stations)
#   ✓ Figures saved to test_results/ccmm2d1/2026-07-06_13-14-58_mse_21_1shift0.15/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d1/2026-07-06_13-14-58_mse_21_1shift0.15
#   Final RMS χ²: 9.0050
#   RMSE: 0.2452
#   MAPE: 9.40%
# ============================================================
#
# MSE run saved: test_results/ccmm2d1/2026-07-06_13-14-58_mse_21_1shift0.15

# %%
# 7) OT vs MSE 对比（收敛曲线 + 视电阻率四线合一 + 伪断面）
plot_ot_mse_convergence(history_ot, history_mse, target_misfit=1.05)

plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=0,
    mode="xy",
)
plot_rho_fitting_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    station_idx=0,
    mode="yx",
)

plot_ot_mse_pseudosection_from_npz(
    ot_run_dir / "apparent_resistivity.npz",
    mse_run_dir / "apparent_resistivity.npz",
    mode="xy",
)
# Out:
# /home/liuxr/MTinv_OT3/src/mt2d_inv/plotting/pseudosection.py:171: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# {'inversion_axes': array([[<Axes: title={'center': 'True'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#          <Axes: title={'center': 'OT inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>,
#          <Axes: title={'center': 'MSE inverted'}, xlabel='Distance (km)', ylabel='Period (s)'>]],
#        dtype=object),
#  'observed_axes': <Axes: title={'center': 'Observed (rhoxy)'}, xlabel='Distance (km)', ylabel='Period (s)'>}
