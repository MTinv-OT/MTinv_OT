# %% [markdown]
# # COMMEMI 2D-1（21 台站）OT vs MSE 联合反演对比（noise=0.01）
#
# 使用 `MT2DTrueModels.create_commemi_2d1` 生成标准模型，在相同合成观测数据上依次运行：
#
# 1. **6D OT**（`mode="6dot"`，`data_loss_scale=10000`）
# 2. **MSE**（`mode="mse"`，`data_loss_scale=30`）
#
# 最后绘制两条 **RMS χ² 下降曲线** 于同一图中对比。

# %%
import os
import sys
import torch
from pathlib import Path
import numpy as np

def _find_project_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / "src" / "mt2d_inv" / "__init__.py").is_file():
            return p
    raise RuntimeError("Cannot find project root (expected src/mt2d_inv/__init__.py)")

root_path = str(_find_project_root(Path.cwd()))
if root_path not in sys.path:
    sys.path.insert(0, root_path)

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

from src.mt2d_inv import MT2DInverterWeightedCost, MT2DTrueModels
from src.mt2d_inv.io import ExperimentLogger
from src.mt2d_inv.plotting import (
    plot_ot_mse_convergence,
    plot_ot_mse_convergence_from_dirs,
    plot_rho_fitting_from_npz,
    plot_ot_mse_pseudosection_from_npz,
)

logger = ExperimentLogger(
    model_tag="ccmm2d4",
    output_root=Path("test_results"),
)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Running on {device}")
print(f"Project root: {root_path}")
# Out:
# Running on cuda
# Project root: /home/liuxr/论文绘图

# %%
# 1) Build COMMEMI 2D-1 true model
yn, zn, nza, sig_true = MT2DTrueModels.create_commemi_2d4(
    nza=10,
    device=device, 
)

# 2) Survey setup
freqs = torch.logspace(0, -3.5, 30, device=device)
stations = torch.linspace(-15000.0, 15000.0, 21, device=device)

print(f"Grid (nz, ny): {(len(zn)-1, len(yn)-1)}")
print(f"Stations: {len(stations)}, Freqs: {len(freqs)}")
# Out:
# Grid (nz, ny): (40, 40)
# Stations: 21, Freqs: 30

# %%
# 3) Inverter + synthetic data (shared by both runs)
inv = MT2DInverterWeightedCost(
    yn=torch.tensor(yn, dtype=torch.float64, device=device),
    zn=torch.tensor(zn, dtype=torch.float64, device=device),
    nza=nza,
    freqs=freqs,
    stations=stations,
    device=device,
    random_seed=123,
    te_weight=1.0,
    tm_weight=1.0,
    data_loss_scale=10000,
)
inv.set_forward_operator()
inv.sig_true = sig_true
inv.create_synthetic_data(
    noise_level=0.01,
    noise_type="gaussian",
)
inv.noise_floor = 0.026
inv._build_rms_chi2_cache()  # 关键：必须重建 RMS 缓存
inv.initialize_model(initial_sigma=0.01)
inv.plot_initial_model(
    clip_to_stations=True,
    ylim=[50, 0],
    synthetic_figwidth_scale=2.0,
)
# Out:
# ✓ Random seed set: 123
# ✓ Sinkhorn (custom cost): blur=0.0100, scaling=0.9
# ✓ Sinkhorn OT Loss (weighted): w_s=1.0, w_f=1.0, w_d=(1.0, 1.0, 1.0, 1.0), blur=0.0100, scale=0.9, reach=None
# Generating 2D MT synthetic data...
# ✓ XY mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ YX mode error propagation completed
#    rho(log10) noise mean: 0.0087
#    phi(normalized) noise mean: 0.0064
# ✓ 2D data error propagation completed
# Computing data weights (Target Noise: 1.0%)
#   - Resistivity Error Floor: 1.0%
#   - Phase Error Floor:       0.500 deg
# ✓ MSE data weights normalized (mean): scale=5.842733e+01
# ✓ Synthetic data generated
#   -> Impedance noise level: 1.0% (gaussian)
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m

# %% [markdown]
# ## OT 反演（6dot）

# %%
# 4a) OT inversion (6dot)
inv.data_loss_scale = 20000
inv.initialize_model(initial_sigma=0.01)
final_sigma_ot = inv.run_inversion(
    n_epochs=400,
    mode="6dot",
    progress_interval=20,
    current_lambda=0.3,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
history_ot = list(inv.loss_history)
print("OT inversion done")
print(final_sigma_ot.min().item(), final_sigma_ot.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/400 [   0.2%]
#   Elapsed: 0:00:02 | Remaining: ~0:10:05 | ETA: 22:00:59
#   Epoch time: 1.52s | Avg: 1.52s
#   Total: 1.3538e+03 | Data(6dot): 1.3538e+03
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 45.814 | Rough: 0.00e+00 | Lam: 0.3000000
#   OT-distance(6D, view-only): 6.768785e+01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
# Epoch 21/400 [   5.2%]
#   Elapsed: 0:00:31 | Remaining: ~0:09:21 | ETA: 22:00:44
#   Epoch time: 1.47s | Avg: 1.48s
#   Total: 5.2104e+02 | Data(6dot): 5.1845e+02
#   Misfit(RMS χ²): 33.359 | Rough: 8.63e+00 | Lam: 0.3000000
#   OT-distance(6D, view-only): 2.592273e+01
#   GradNorms: |g_d|=1.184e+00 | |λ·g_m|=3.096e-02
# Epoch 41/400 [  10.2%]
#   Elapsed: 0:01:01 | Remaining: ~0:08:52 | ETA: 22:00:45
#   Epoch time: 1.51s | Avg: 1.48s
#   Total: 1.7146e+02 | Data(6dot): 1.6620e+02
#   Misfit(RMS χ²): 23.978 | Rough: 1.75e+01 | Lam: 0.3000000
#   OT-distance(6D, view-only): 8.309998e+00
#   GradNorms: |g_d|=4.949e-01 | |λ·g_m|=3.494e-02
# Epoch 61/400 [  15.2%]
#   Elapsed: 0:01:31 | Remaining: ~0:08:23 | ETA: 22:00:46
#   Epoch time: 1.50s | Avg: 1.49s
#   Total: 4.7474e+01 | Data(6dot): 4.0736e+01
#   Misfit(RMS χ²): 12.557 | Rough: 2.25e+01 | Lam: 0.3000000
#   OT-distance(6D, view-only): 2.036784e+00
#   GradNorms: |g_d|=1.521e-01 | |λ·g_m|=4.845e-02
#  [Auto-Lambda] Epoch 70: Adjusted 3.00e-01 -> 2.83e-01 (ratio=8.881e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 2.83e-01 -> 2.24e-01 (ratio=6.253e-01)
# Epoch 81/400 [  20.2%]
#   Elapsed: 0:02:01 | Remaining: ~0:07:54 | ETA: 22:00:46
#   Epoch time: 1.50s | Avg: 1.49s
#   Total: 1.6272e+01 | Data(6dot): 1.1513e+01
#   Misfit(RMS χ²): 6.296 | Rough: 2.13e+01 | Lam: 0.2235590
#   OT-distance(6D, view-only): 5.756276e-01
#   GradNorms: |g_d|=3.599e-02 | |λ·g_m|=2.334e-02
#  [Auto-Lambda] Epoch 100: Adjusted 2.24e-01 -> 2.08e-01 (ratio=8.640e-01)
# Epoch 101/400 [  25.2%]
#   Elapsed: 0:02:31 | Remaining: ~0:07:24 | ETA: 22:00:47
#   Epoch time: 1.60s | Avg: 1.49s
#   Total: 9.6019e+00 | Data(6dot): 5.3890e+00
#   Misfit(RMS χ²): 3.946 | Rough: 2.03e+01 | Lam: 0.2078030
#   OT-distance(6D, view-only): 2.694487e-01
#   GradNorms: |g_d|=2.765e-02 | |λ·g_m|=1.615e-02
#  [Auto-Lambda] Epoch 120: Adjusted 2.08e-01 -> 1.74e-01 (ratio=6.985e-01)
# Epoch 121/400 [  30.2%]
#   Elapsed: 0:03:00 | Remaining: ~0:06:55 | ETA: 22:00:47
#   Epoch time: 1.50s | Avg: 1.49s
#   Total: 6.2241e+00 | Data(6dot): 2.7273e+00
#   Misfit(RMS χ²): 1.701 | Rough: 2.01e+01 | Lam: 0.1736796
#   OT-distance(6D, view-only): 1.363643e-01
#   GradNorms: |g_d|=1.618e-02 | |λ·g_m|=9.773e-03
#  [Auto-Lambda] Epoch 130: Adjusted 1.74e-01 -> 1.26e-01 (ratio=5.246e-01)
# Epoch 141/400 [  35.2%]
#   Elapsed: 0:03:30 | Remaining: ~0:06:25 | ETA: 22:00:47
#   Epoch time: 1.53s | Avg: 1.49s
#   Total: 4.9204e+00 | Data(6dot): 2.3250e+00
#   Misfit(RMS χ²): 1.362 | Rough: 2.06e+01 | Lam: 0.1257953
#   OT-distance(6D, view-only): 1.162478e-01
#   GradNorms: |g_d|=2.456e-02 | |λ·g_m|=6.467e-03
#  [Auto-Lambda] Epoch 160: Adjusted 1.26e-01 -> 1.04e-01 (ratio=6.837e-01)
# Epoch 161/400 [  40.2%]
#   Elapsed: 0:04:00 | Remaining: ~0:05:56 | ETA: 22:00:48
#   Epoch time: 1.49s | Avg: 1.49s
#   Total: 4.3791e+00 | Data(6dot): 2.2225e+00
#   Misfit(RMS χ²): 1.333 | Rough: 2.07e+01 | Lam: 0.1040186
#   OT-distance(6D, view-only): 1.111252e-01
#   GradNorms: |g_d|=8.175e-03 | |λ·g_m|=5.258e-03
#  [Auto-Lambda] Epoch 170: Adjusted 1.04e-01 -> 8.43e-02 (ratio=6.563e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 8.43e-02 -> 6.62e-02 (ratio=6.179e-01)
# Epoch 181/400 [  45.2%]
#   Elapsed: 0:04:30 | Remaining: ~0:05:26 | ETA: 22:00:48
#   Epoch time: 1.39s | Avg: 1.49s
#   Total: 3.5412e+00 | Data(6dot): 2.1289e+00
#   Misfit(RMS χ²): 1.273 | Rough: 2.13e+01 | Lam: 0.0662424
#   OT-distance(6D, view-only): 1.064472e-01
#   GradNorms: |g_d|=6.005e-03 | |λ·g_m|=3.446e-03
#  [Auto-Lambda] Epoch 190: Adjusted 6.62e-02 -> 5.22e-02 (ratio=6.201e-01)
#  [Auto-Lambda] Epoch 200: Adjusted 5.22e-02 -> 4.06e-02 (ratio=6.052e-01)
# Epoch 201/400 [  50.2%]
#   Elapsed: 0:05:00 | Remaining: ~0:04:56 | ETA: 22:00:48
#   Epoch time: 1.51s | Avg: 1.49s
#   Total: 2.9377e+00 | Data(6dot): 2.0363e+00
#   Misfit(RMS χ²): 1.187 | Rough: 2.22e+01 | Lam: 0.0405811
#   OT-distance(6D, view-only): 1.018141e-01
#   GradNorms: |g_d|=3.394e-03 | |λ·g_m|=2.181e-03
# Epoch 221/400 [  55.2%]
#   Elapsed: 0:05:30 | Remaining: ~0:04:26 | ETA: 22:00:48
#   Epoch time: 1.52s | Avg: 1.49s
#   Total: 2.9004e+00 | Data(6dot): 1.9594e+00
#   Misfit(RMS χ²): 1.116 | Rough: 2.32e+01 | Lam: 0.0405811
#   OT-distance(6D, view-only): 9.796812e-02
#   GradNorms: |g_d|=7.228e-03 | |λ·g_m|=2.246e-03
# Epoch 241/400 [  60.2%]
#   Elapsed: 0:06:00 | Remaining: ~0:03:57 | ETA: 22:00:49
#   Epoch time: 1.52s | Avg: 1.49s
#   Total: 2.8794e+00 | Data(6dot): 1.9135e+00
#   Misfit(RMS χ²): 1.078 | Rough: 2.38e+01 | Lam: 0.0405811
#   OT-distance(6D, view-only): 9.567253e-02
#   GradNorms: |g_d|=1.001e-02 | |λ·g_m|=2.272e-03
#  [Auto-Lambda] Epoch 250: Adjusted 4.06e-02 -> 3.54e-02 (ratio=7.600e-01)
# Epoch 261/400 [  65.2%]
#   Elapsed: 0:06:30 | Remaining: ~0:03:27 | ETA: 22:00:49
#   Epoch time: 1.49s | Avg: 1.49s
#   Total: 2.7397e+00 | Data(6dot): 1.8791e+00
#   Misfit(RMS χ²): 1.049 | Rough: 2.43e+01 | Lam: 0.0353772
#   OT-distance(6D, view-only): 9.395453e-02
#   GradNorms: |g_d|=4.575e-03 | |λ·g_m|=2.010e-03
#   [Early stop] RMS χ² = 1.049 < 1.05, epoch = 260
# Inversion completed.
# OT inversion done
# 1e-10 0.11349554203881966

# %%
# 5a) OT result plots
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()

ot_run_dir = logger.save_from_inverter(inv, run_name="ot21_noise0.01")
print(f"OT run saved: {ot_run_dir}")
# Out:
# Model structural similarity (SSIM): 0.3725
# ============================================================
# Saving results to: test_results/ccmm2d4/2026-08-18_21-57-36_ot21_noise0.01
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.3725
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d4/2026-08-18_21-57-36_ot21_noise0.01/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d4/2026-08-18_21-57-36_ot21_noise0.01/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d4/2026-08-18_21-57-36_ot21_noise0.01
#   Final RMS χ²: 1.0491
#   RMSE: 0.4436
#   MAPE: 13.04%
# ============================================================
#
# OT run saved: test_results/ccmm2d4/2026-08-18_21-57-36_ot21_noise0.01

# %% [markdown]
# ## MSE 反演

# %%
# 4b) MSE inversion (same synthetic data, reset model)
inv.data_loss_scale = 300
inv.initialize_model(initial_sigma=0.01)
final_sigma_mse = inv.run_inversion(
    n_epochs=500,
    mode="mse",
    progress_interval=20,
    current_lambda=0.3,
    use_adaptive_lambda=True,
    lr=0.03,
    update_interval=10,
    norm_type="L2",
    alpha=0.5,
    use_depth_weights=True,
    rms_chi2_stop=1.05,
    profile_timing=False,
)
history_mse = list(inv.loss_history)
print("MSE inversion done")
print(final_sigma_mse.min().item(), final_sigma_mse.max().item())
# Out:
# ✓ Model initialization complete: Uniform.
#   - Air layer fixed: nza=10, air_sigma=1.00e-10 S/m
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# ✓ Optimizer: AdamW, lr=0.03, weight_decay=0.0
# Epoch 1/500 [   0.2%]
#   Elapsed: 0:00:01 | Remaining: ~0:11:11 | ETA: 22:09:16
#   Epoch time: 1.35s | Avg: 1.35s
#   Total: 3.1174e+02 | Data(mse): 3.1174e+02
#   [Cost weights] w_s=1.000, w_f=1.000, w_d=(1.0, 1.0, 1.0, 1.0)
#   Misfit(RMS χ²): 45.814 | Rough: 0.00e+00 | Lam: 0.3000000
#   OT-distance(6D, view-only): 6.768785e+01
#   GradNorms: |g_d|=nan | |λ·g_m|=nan
# Epoch 21/500 [   4.2%]
#   Elapsed: 0:00:29 | Remaining: ~0:11:23 | ETA: 22:09:56
#   Epoch time: 1.46s | Avg: 1.43s
#   Total: 1.2406e+02 | Data(mse): 1.2224e+02
#   Misfit(RMS χ²): 28.684 | Rough: 6.09e+00 | Lam: 0.3000000
#   OT-distance(6D, view-only): 3.776900e+01
#   GradNorms: |g_d|=4.242e-01 | |λ·g_m|=2.230e-02
# Epoch 41/500 [   8.2%]
#   Elapsed: 0:00:58 | Remaining: ~0:10:55 | ETA: 22:09:56
#   Epoch time: 1.45s | Avg: 1.43s
#   Total: 4.4499e+01 | Data(mse): 4.1281e+01
#   Misfit(RMS χ²): 16.671 | Rough: 1.07e+01 | Lam: 0.3000000
#   OT-distance(6D, view-only): 1.834170e+01
#   GradNorms: |g_d|=2.336e-01 | |λ·g_m|=2.775e-02
# Epoch 61/500 [  12.2%]
#   Elapsed: 0:01:27 | Remaining: ~0:10:27 | ETA: 22:09:58
#   Epoch time: 1.43s | Avg: 1.43s
#   Total: 1.4249e+01 | Data(mse): 1.0764e+01
#   Misfit(RMS χ²): 8.520 | Rough: 1.16e+01 | Lam: 0.3000000
#   OT-distance(6D, view-only): 7.367834e+00
#   GradNorms: |g_d|=4.984e-02 | |λ·g_m|=3.414e-02
#  [Auto-Lambda] Epoch 70: Adjusted 3.00e-01 -> 2.81e-01 (ratio=8.800e-01)
#  [Auto-Lambda] Epoch 80: Adjusted 2.81e-01 -> 2.07e-01 (ratio=5.410e-01)
# Epoch 81/500 [  16.2%]
#   Elapsed: 0:01:56 | Remaining: ~0:10:02 | ETA: 22:10:02
#   Epoch time: 1.93s | Avg: 1.44s
#   Total: 5.8223e+00 | Data(mse): 3.6249e+00
#   Misfit(RMS χ²): 4.945 | Rough: 1.06e+01 | Lam: 0.2070071
#   OT-distance(6D, view-only): 2.806902e+00
#   GradNorms: |g_d|=2.495e-02 | |λ·g_m|=1.366e-02
#  [Auto-Lambda] Epoch 100: Adjusted 2.07e-01 -> 1.89e-01 (ratio=8.346e-01)
# Epoch 101/500 [  20.2%]
#   Elapsed: 0:02:25 | Remaining: ~0:09:33 | ETA: 22:10:01
#   Epoch time: 1.42s | Avg: 1.44s
#   Total: 3.7164e+00 | Data(mse): 1.6157e+00
#   Misfit(RMS χ²): 3.300 | Rough: 1.11e+01 | Lam: 0.1891145
#   OT-distance(6D, view-only): 1.455706e+00
#   GradNorms: |g_d|=1.634e-02 | |λ·g_m|=9.144e-03
#  [Auto-Lambda] Epoch 110: Adjusted 1.89e-01 -> 1.63e-01 (ratio=7.464e-01)
#  [Auto-Lambda] Epoch 120: Adjusted 1.63e-01 -> 1.24e-01 (ratio=5.805e-01)
# Epoch 121/500 [  24.2%]
#   Elapsed: 0:02:54 | Remaining: ~0:09:04 | ETA: 22:10:02
#   Epoch time: 1.44s | Avg: 1.44s
#   Total: 2.4464e+00 | Data(mse): 9.5354e-01
#   Misfit(RMS χ²): 2.536 | Rough: 1.20e+01 | Lam: 0.1244794
#   OT-distance(6D, view-only): 9.953339e-01
#   GradNorms: |g_d|=8.678e-03 | |λ·g_m|=5.763e-03
#  [Auto-Lambda] Epoch 130: Adjusted 1.24e-01 -> 9.60e-02 (ratio=5.945e-01)
#  [Auto-Lambda] Epoch 140: Adjusted 9.60e-02 -> 7.70e-02 (ratio=6.443e-01)
# Epoch 141/500 [  28.2%]
#   Elapsed: 0:03:22 | Remaining: ~0:08:35 | ETA: 22:10:01
#   Epoch time: 1.45s | Avg: 1.44s
#   Total: 1.6713e+00 | Data(mse): 6.3788e-01
#   Misfit(RMS χ²): 2.074 | Rough: 1.34e+01 | Lam: 0.0770401
#   OT-distance(6D, view-only): 6.995750e-01
#   GradNorms: |g_d|=5.797e-03 | |λ·g_m|=3.616e-03
#  [Auto-Lambda] Epoch 150: Adjusted 7.70e-02 -> 6.23e-02 (ratio=6.545e-01)
#  [Auto-Lambda] Epoch 160: Adjusted 6.23e-02 -> 5.09e-02 (ratio=6.660e-01)
# Epoch 161/500 [  32.2%]
#   Elapsed: 0:03:51 | Remaining: ~0:08:06 | ETA: 22:10:01
#   Epoch time: 1.44s | Avg: 1.44s
#   Total: 1.2121e+00 | Data(mse): 4.6005e-01
#   Misfit(RMS χ²): 1.762 | Rough: 1.48e+01 | Lam: 0.0508636
#   OT-distance(6D, view-only): 5.140617e-01
#   GradNorms: |g_d|=3.928e-03 | |λ·g_m|=2.444e-03
#  [Auto-Lambda] Epoch 170: Adjusted 5.09e-02 -> 4.17e-02 (ratio=6.721e-01)
#  [Auto-Lambda] Epoch 180: Adjusted 4.17e-02 -> 3.48e-02 (ratio=6.952e-01)
# Epoch 181/500 [  36.2%]
#   Elapsed: 0:04:19 | Remaining: ~0:07:38 | ETA: 22:10:01
#   Epoch time: 1.45s | Avg: 1.44s
#   Total: 9.0856e-01 | Data(mse): 3.5030e-01
#   Misfit(RMS χ²): 1.537 | Rough: 1.61e+01 | Lam: 0.0347686
#   OT-distance(6D, view-only): 3.915889e-01
#   GradNorms: |g_d|=2.886e-03 | |λ·g_m|=1.726e-03
#  [Auto-Lambda] Epoch 200: Adjusted 3.48e-02 -> 2.90e-02 (ratio=6.962e-01)
# Epoch 201/500 [  40.2%]
#   Elapsed: 0:04:48 | Remaining: ~0:07:09 | ETA: 22:10:01
#   Epoch time: 1.46s | Avg: 1.44s
#   Total: 7.8079e-01 | Data(mse): 2.8635e-01
#   Misfit(RMS χ²): 1.390 | Rough: 1.70e+01 | Lam: 0.0290100
#   OT-distance(6D, view-only): 3.182237e-01
#   GradNorms: |g_d|=2.270e-03 | |λ·g_m|=1.463e-03
#  [Auto-Lambda] Epoch 210: Adjusted 2.90e-02 -> 2.43e-02 (ratio=6.995e-01)
#  [Auto-Lambda] Epoch 220: Adjusted 2.43e-02 -> 2.05e-02 (ratio=7.113e-01)
# Epoch 221/500 [  44.2%]
#   Elapsed: 0:05:17 | Remaining: ~0:06:40 | ETA: 22:10:01
#   Epoch time: 1.43s | Avg: 1.44s
#   Total: 6.1150e-01 | Data(mse): 2.4569e-01
#   Misfit(RMS χ²): 1.287 | Rough: 1.79e+01 | Lam: 0.0204629
#   OT-distance(6D, view-only): 2.693422e-01
#   GradNorms: |g_d|=1.807e-03 | |λ·g_m|=1.051e-03
#  [Auto-Lambda] Epoch 230: Adjusted 2.05e-02 -> 1.75e-02 (ratio=7.350e-01)
#  [Auto-Lambda] Epoch 240: Adjusted 1.75e-02 -> 1.48e-02 (ratio=7.160e-01)
# Epoch 241/500 [  48.2%]
#   Elapsed: 0:05:46 | Remaining: ~0:06:12 | ETA: 22:10:01
#   Epoch time: 1.45s | Avg: 1.44s
#   Total: 4.9273e-01 | Data(mse): 2.1454e-01
#   Misfit(RMS χ²): 1.203 | Rough: 1.87e+01 | Lam: 0.0148445
#   OT-distance(6D, view-only): 2.310636e-01
#   GradNorms: |g_d|=1.340e-03 | |λ·g_m|=7.832e-04
#  [Auto-Lambda] Epoch 250: Adjusted 1.48e-02 -> 1.31e-02 (ratio=7.740e-01)
# Epoch 261/500 [  52.2%]
#   Elapsed: 0:06:15 | Remaining: ~0:05:43 | ETA: 22:10:02
#   Epoch time: 1.45s | Avg: 1.44s
#   Total: 4.4764e-01 | Data(mse): 1.9249e-01
#   Misfit(RMS χ²): 1.139 | Rough: 1.95e+01 | Lam: 0.0130601
#   OT-distance(6D, view-only): 2.033128e-01
#   GradNorms: |g_d|=2.203e-03 | |λ·g_m|=7.050e-04
#  [Auto-Lambda] Epoch 270: Adjusted 1.31e-02 -> 1.20e-02 (ratio=8.391e-01)
#  [Auto-Lambda] Epoch 280: Adjusted 1.20e-02 -> 1.09e-02 (ratio=8.341e-01)
# Epoch 281/500 [  56.2%]
#   Elapsed: 0:06:44 | Remaining: ~0:05:15 | ETA: 22:10:02
#   Epoch time: 1.46s | Avg: 1.44s
#   Total: 3.9819e-01 | Data(mse): 1.7893e-01
#   Misfit(RMS χ²): 1.099 | Rough: 2.01e+01 | Lam: 0.0109263
#   OT-distance(6D, view-only): 1.861235e-01
#   GradNorms: |g_d|=1.162e-03 | |λ·g_m|=5.942e-04
# Epoch 301/500 [  60.2%]
#   Elapsed: 0:07:13 | Remaining: ~0:04:46 | ETA: 22:10:03
#   Epoch time: 1.43s | Avg: 1.44s
#   Total: 3.9338e-01 | Data(mse): 1.6954e-01
#   Misfit(RMS χ²): 1.069 | Rough: 2.05e+01 | Lam: 0.0109263
#   OT-distance(6D, view-only): 1.739526e-01
#   GradNorms: |g_d|=1.303e-03 | |λ·g_m|=5.991e-04
#  [Auto-Lambda] Epoch 310: Adjusted 1.09e-02 -> 1.02e-02 (ratio=8.800e-01)
#  [Auto-Lambda] Epoch 320: Adjusted 1.02e-02 -> 9.08e-03 (ratio=7.855e-01)
# Epoch 321/500 [  64.2%]
#   Elapsed: 0:07:42 | Remaining: ~0:04:17 | ETA: 22:10:03
#   Epoch time: 1.47s | Avg: 1.44s
#   Total: 3.5184e-01 | Data(mse): 1.6324e-01
#   Misfit(RMS χ²): 1.049 | Rough: 2.08e+01 | Lam: 0.0090844
#   OT-distance(6D, view-only): 1.658327e-01
#   GradNorms: |g_d|=8.549e-04 | |λ·g_m|=4.986e-04
#   [Early stop] RMS χ² = 1.049 < 1.05, epoch = 320
# Inversion completed.
# MSE inversion done
# 1e-10 0.09203247711690708

# %%
# 5b) MSE result plots
inv.plot_loss_history()
inv.plot_model_comparison(
    cmap="jet_r",
    clip_to_stations=True,
    ylim=[50, 0],
    vmin=1,
    vmax=3,
    synthetic_figwidth_scale=2.0,
)
inv.plot_data_fitting()
inv.plot_1d_profiles(depth_limit_km=50)
inv.plot_gradient_history()

mse_run_dir = logger.save_from_inverter(inv, run_name="mse21_noise0.01")
print(f"MSE run saved: {mse_run_dir}")
# Out:
# Model structural similarity (SSIM): 0.3308
# ============================================================
# Saving results to: test_results/ccmm2d4/2026-08-18_22-06-00_mse21_noise0.01
# ============================================================
#   ✓ summary.csv
#   ✓ history.csv
#   ✓ config.json
#   ✓ timing.json
#   ✓ meta.json
#   ✓ final_model.npz
#   ✓ static_shift.json
#   ✓ apparent_resistivity.npz
# Model structural similarity (SSIM): 0.3308
#   ✓ model_comparison.png/.pdf
#   ✓ initial_model.png/.pdf
#   ✓ data_fitting: 7 plots saved to test_results/ccmm2d4/2026-08-18_22-06-00_mse21_noise0.01/figures/data_fitting (21 stations)
#   ✓ profiles_1d.png/.pdf
#   ✓ Figures saved to test_results/ccmm2d4/2026-08-18_22-06-00_mse21_noise0.01/figures
#
# ============================================================
# Results saved successfully!
#   Location: test_results/ccmm2d4/2026-08-18_22-06-00_mse21_noise0.01
#   Final RMS χ²: 1.0493
#   RMSE: 0.4777
#   MAPE: 14.62%
# ============================================================
#
# MSE run saved: test_results/ccmm2d4/2026-08-18_22-06-00_mse21_noise0.01

# %% [markdown]
# ## OT vs MSE：RMS χ² 下降曲线对比

# %%
# 6) Combined RMS χ² convergence (OT vs MSE)
plot_ot_mse_convergence(
    history_ot,
    history_mse,
    target_misfit=1.05,
    log_y=True,
)
# Out:
# <Axes: title={'center': 'RMS χ² & OT distance (monitor)'}, xlabel='Epoch', ylabel='RMS χ²'>
